# %%
# !pip install transformers
# !pip install sentencepiece
# !pip install rouge
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.2-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 4.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 36.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 14.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.21.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 5.0 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from rouge) (1.15.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 3.2 MB/s
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.21.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.12.1+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.13.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.9.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.12.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.24.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=e8f97069147d39b033ee172e18b4c043a6ac83e105a29c809fd58eda9a026ab0
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.2.2

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, PegasusForConditionalGeneration, AutoModelForSequenceClassification, AutoModel
import torch
import pandas as pd
from tqdm import tqdm
import requests
import nltk
from nltk.translate.bleu_score import sentence_bleu
from rouge import rouge
import pandas as pd

# %% [markdown]
# # Loading test pairs from combined dataset(PAWS+TaPaco)

# %%
test_combined_en = pd.read_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/dataset_comb_test_en.csv')

# %%
test_combined_en
# Out:
#                                                     Text  \
# 0      The Chapel and Hall were both fully funded by ...
# 1                                     This isn't my key.
# 2                                     He is a biologist.
# 3           I haven't read all the books on the shelves.
# 4                    He is able to run faster than I am.
# ...                                                  ...
# 11924  Many provinces and states organize regional an...
# 11925                           He still has not called.
# 11926                        We'll certainly invite Tom.
# 11927                             Tom called the police.
# 11928                  Tom is too afraid to do that now.
#
#                                               Paraphrase lan
# 0      The chapel and the room were both fully funded...  en
# 1                                  This key is not mine.  en
# 2                                      He's a biologist.  en
# 3      It's not as if I had read all the books on the...  en
# 4                              He can run faster than I.  en
# ...                                                  ...  ..
# 11924  Many provinces and states organize regional an...  en
# 11925                              He hasn't called yet.  en
# 11926                       We'll definitely invite Tom.  en
# 11927                               Tom called the cops.  en
# 11928                   Tom is too old to be doing that.  en
#
# [11929 rows x 3 columns]

# %%
test_combined_en = test_combined_en[['Text']][:5000]

# %%
test_combined_en
# Out:
#                                                    Text
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
# [5000 rows x 1 columns]

# %% [markdown]
# # Evaluation metrics code

# %% [markdown]
# ## Lexical scores

# %% [markdown]
# ### Rouge scores

# %%
def rouge_score(candidate,reference,ngram=1 ,metric='f'):
  from rouge import Rouge
  rouge = Rouge()

  if ngram == 1:
    ngram = 'rouge-1'
  elif ngram == 2:
    ngram = 'rouge-2'
  elif ngram == 'l':
    ngram = 'rouge-l'

  all_scores = rouge.get_scores(candidate.lower(), reference.lower())
  
  return all_scores[0][ngram][metric]

# %% [markdown]
# ### BLEU

# %%
nltk.download('punkt')
def bleu_score(candidate, reference, ngram=1):
  from nltk.translate.bleu_score import sentence_bleu

  if ngram == 1:
    ngram = (1,0,0,0)
  if ngram == 2:
    ngram = (0,1,0,0)
  if ngram == 3:
    ngram = (0,0,1,0)
  if ngram == 4:
    ngram = (0,0,0,1)
  
  candidate = nltk.word_tokenize(candidate.lower())
  reference = nltk.word_tokenize(reference.lower())
  
  return sentence_bleu([reference], candidate, weights=ngram)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### Jaccard similarity

# %%
def jaccard_similarity(candidate, reference, ngram=1):
  import nltk
  nltk.download('punkt', quiet=True)

  candidate = nltk.word_tokenize(candidate.lower())
  reference = nltk.word_tokenize(reference.lower())

  if ngram != 1:
    candidate = nltk.ngrams(candidate, n=ngram)
    reference = nltk.ngrams(reference, n=ngram)

  candidate = set(candidate)
  reference = set(reference)
  intersection = len(list(candidate.intersection(reference)))
  union = (len(candidate) + len(reference)) - intersection
  
  return float(intersection) / union

# %% [markdown]
# ## Semantics evaluation models

# %%
# Load model from HuggingFace Hub
paraphrase_xlm_r_multilingual_tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
paraphrase_xlm_r_multilingual_model = AutoModel.from_pretrained('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/550 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading sentencepiece.bpe.model:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/8.68M [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.04G [00:00<?, ?B/s]

# %%
# Necessary to run the model of the cell above to run this function
def cosine_similarity(sentence1, sentence2):
  from transformers import AutoTokenizer, AutoModel
  import torch


  #Mean Pooling - Take attention mask into account for correct averaging
  def mean_pooling(model_output, attention_mask):
      token_embeddings = model_output[0] #First element of model_output contains all token embeddings
      input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
      return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


  # Sentences we want sentence embeddings for
  sentences = [sentence1, sentence2]


  # Tokenize sentences
  encoded_input = paraphrase_xlm_r_multilingual_tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

  # Compute token embeddings
  with torch.no_grad():
      model_output = paraphrase_xlm_r_multilingual_model(**encoded_input)

  # Perform pooling. In this case, max pooling.
  sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

  return float(torch.cosine_similarity(torch.tensor(sentence_embeddings[0].reshape(1,-1)), torch.tensor(sentence_embeddings[1].reshape(1,-1))))

# %% [markdown]
# #PEGASUS

# %% [markdown]
# ## PEGASUS paraphrase inference

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, PegasusForConditionalGeneration
import torch
import pandas as pd
from tqdm import tqdm

model_identifier = 'tuner007/pegasus_paraphrase'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'

pegasus_tokenizer = AutoTokenizer.from_pretrained(model_identifier)

pegasus_model = PegasusForConditionalGeneration.from_pretrained(model_identifier).to(torch_device)

# %%
def get_response_pegasus(input_text,num_return_sequences,num_beams):
  batch = pegasus_tokenizer([input_text],truncation=True,padding='longest',max_length=60, return_tensors="pt").to(torch_device)
  translated = pegasus_model.generate(**batch,max_length=60,num_beams=num_beams, num_return_sequences=num_return_sequences, temperature=1.5)
  tgt_text = pegasus_tokenizer.batch_decode(translated, skip_special_tokens=True)
  return tgt_text

# %%
pegasus_paraphrases = []
for original_sentence in tqdm(test_combined_en['Text']):
  paraphrases = get_response_pegasus(original_sentence,1,1)
  pegasus_paraphrases.append(paraphrases[0])
# Out:
# 100%|██████████| 5000/5000 [18:48<00:00,  4.43it/s]

# %%
pegasus_paraphrases
# Out:
# ['The Chapel and Hall were designed by Butterfield and funded by William Gibbs.',
#  "This isn't my key.",
#  'He is a Biologist.',
#  "I haven't read all the books.",
#  'He is able to run faster than I am.',
#  'Arnold was sent to Skenesboro and Asa Douglas to secure boats when Samuel Herrick arrived.',
#  'Jon Uren, marketing director of Warner Music Europe, said that the song had " early" support across Europe.',
#  'Tom left after Mary.',
#  'She has lived in that town for five years.',
#  'I think wine is good.',
#  'What are you smiling at?',
#  'The Nationalist parties and other liberal groups said that they would not participate in the elections.',
#  'Tom asked if he was not disturbed.',
#  'Tom changed his clothes.',
#  'The Toronto Maple Leafs have been a franchise for 54 years, the 64th season being the 1980 - 81 season.',
#  "I've dated a person who was crazy.",
#  '13 ranchos were granted in the state of California during the time when it was a province of independent Mexico.',
#  "Tom thinks I'm dumb.",
#  'Thank you for your warning.',
#  'Where did she learn to dance?',
#  'I talk fast.',
#  "The FBI's John E. Douglas is the one who created the character of Holden Ford.",
#  'The two terms are being used in other parts of the country.',
#  'They told everyone that they were suspicious.',
#  'That is a donkey.',
#  'Tom is going to be at the party.',
#  "I can't say anything in English.",
#  'Good, no absences.',
#  'The districts that serve Center City are the 17th, 9th and 6th.',
#  'Sunday is after Saturday.',
#  'She will have been married to him for ten years.',
#  'The conclusions are that we are all ideas of the one perfect spiritual Mind and divine spirit, not a material body.',
#  'It is resistant to mildew and gives good yields.',
#  "She doesn't know anything about your family.",
#  'She wore a red blouse and black skirt.',
#  'Rebecca stays in Summer Bay during the school holidays after Donald explained everything about Bobby and Morag.',
#  'I speak Italian.',
#  'The Ttaru is a river in Romania.',
#  'I have to be done with it tomorrow.',
#  'I saw that he was well.',
#  'Tom sleeps for eight hours.',
#  'The son of Georges Merle became a painter.',
#  "I'm sure she won't come to see you.",
#  'I waited for a call all weekend.',
#  'San Pedro Springs Park is located in the town of San Antonio in the U.S. state of Texas.',
#  "I can't tell you who is on the list because I haven't seen it.",
#  'My body hurts.',
#  "I didn't call because I had a cold.",
#  "Tom said it's impossible.",
#  'Antony was buried in the church of Carew on November 7th.',
#  "People shouldn't abuse animals.",
#  'The constituency is located on the right bank of the River Afan, near the mouth of theSwansea Bay.',
#  'The thermal regime of the quantum Oscillator is important to achieve.',
#  'Why is Tom not eating?',
#  "Victoria S. Bull was introduced as Vicki's sister in 2001 but has been missing for many years.",
#  'You can believe what you want.',
#  'The former station North East was located north of Seymour at the junction of the Shepparton and Mangalore lines.',
#  'Would you like me to stay?',
#  "Why don't you wear clothes?",
#  "I think it's a great idea.",
#  'I met her last winter.',
#  'The San Jose campus relocated to California in the year 2016',
#  'Tom lives outside of the city.',
#  'He finally made up his mind to propose.',
#  'I forgot my PIN number.',
#  'The letter was sent to Montpellier by Toulouse on April 10, 1562.',
#  'Bill Malina and Rice assisted with additional mixing.',
#  'The residents were upset with the noise.',
#  'I have no one to blame but myself.',
#  'She has a heart disease.',
#  'Tom is stuck up.',
#  "You can't eat the money.",
#  'The Canton trading station was the site of a clash between Americans and Chinese.',
#  "Some people take a bath every day, while others don't.",
#  'Are you going to come tomorrow?',
#  'The responsibility for the Werris Creek to North Star line was transferred to the ARTC in July 2011.',
#  'Only six episodes from the third and fourth series are in the archives.',
#  'Tom is not scared of spiders.',
#  'He did what he could for his children.',
#  'The JieT is a river in Romania.',
#  'Tom is still being expelled.',
#  'Wine makes a man happy.',
#  'He was not upset.',
#  'This will be the best.',
#  'The service was discontinued on December 15th, 2010 after it was discontinued in the summer of 2008.',
#  'We need a little time to think.',
#  'The school is connected to the secondary department of the school that was built for the disabled.',
#  'The authors of the works on which these notes are based are also Galanthologists.',
#  'This is the biggest dog.',
#  "I'll be taking Tom's place.",
#  'I have enough money to buy a car.',
#  'I tried to get away.',
#  'Mudzuri defeated Amos Midzi in the March 2002 mayoral election by a large margin, receiving 262,275 votes against 56,796 votes for Midzi.',
#  'I did the work against my will.',
#  "Let's talk about it.",
#  'The whelks marine and the sea snail, Buccinum parvulum, are true gastropods.',
#  'What kind of songs are popular?',
#  'Is he swimming?',
#  'Tom may be confused.',
#  'The author spoke our mother tongue.',
#  'The tournament was held in San Francisco for two years.',
#  'What a beautiful place!',
#  'How did you meet?',
#  'Kathy Lloyd was born in Northern Ireland and grew up in the area of Netherton, Bootle.',
#  'Tom decided to join us.',
#  'Tom will try.',
#  'The cat ran after the dog.',
#  'It was recorded in November of 1961.',
#  'Tom is sleeping.',
#  'Eddie DeLange wrote the music and Jimmy Van Heusen wrote the lyrics for "Darn That Dream", published in 1939.',
#  'How are we going to get home?',
#  'I agree with your proposal.',
#  'Tom is anxious.',
#  'The former Lorraine Hannemann of Manhattan, New York, and her husband, the former John Maughan, live in Honolulu.',
#  'I have stools that are hard.',
#  'I found something.',
#  'She is concerned about her health.',
#  'I am humor me.',
#  'The corps was pulled out of the First Army two weeks before the invasion by the Third Army.',
#  'The navy olives are a species of dwarf sea snail and small gastropods.',
#  "I'm thinking about changing majors.",
#  'Tom must have had reasons.',
#  'Who would have predicted this?',
#  'He came to Serbian ajkai in 1739 as a renowned speaker after being a victim of religious persecution.',
#  'The car was sold in many different markets.',
#  'I went to see a movie.',
#  'The main campus of the college is located in Whangarei.',
#  'Is there a store near here?',
#  'Owen Bradley recorded a song for the 1964 album by By Request.',
#  'The loyalists camped on the west side of the river while the army of Cornwalli camped on the east side.',
#  'David Miller and Ross Hunter produced Back Street.',
#  'What is your area of expertise?',
#  'The school case has pictures of Danielle, Nadine and Mark.',
#  'The development of Bas 90 began in the 1970s and was implemented in the 1980s.',
#  'It has improved greatly.',
#  "His son's death was a great shock.",
#  'It is only found in China and in the Lake Dianchi.',
#  'I saw that it snowed for four days in the first month of the year.',
#  'She gave him all the money that she had.',
#  "They won't bring him back.",
#  'The British Transport Police was created on July 1st, 2004.',
#  'Scouting in Malaysia was first introduced in Malaya in 1908 as an experimental troop in Penang.',
#  'Louise Fitzhugh wrote Suzuki Beane in 1961, and it was illustrated by Sandra Scoppettone.',
#  'I need you for a second.',
#  "I'm not your teacher anymore.",
#  'The teams play in the semi-finals in second place in the pools and first place in the other pool.',
#  'Mount Sis is a place in Turkey called Sis Da Yaylas.',
#  'What do you not get?',
#  'Mary looks pretty.',
#  'The city of Sanjauli is located in the district of the Himalayas.',
#  '" All about the Evil" features Patrick Bristow, Mink Stole and Brown.',
#  'The Presbyterian doctrine is reformed and the government is theological.',
#  'I think she likes him.',
#  'The windows should have been washed.',
#  'I would be happy to drive your new Toyota.',
#  'The village and village development committee is called Linkuwa Pokhari.',
#  'I am reading a book.',
#  "Let's play soccer.",
#  'I like your eyes!',
#  "Tom hasn't been caught yet.",
#  'It was predictable.',
#  'He broke his wrist.',
#  '3M agreed to change the name of Acquire.',
#  'He has not been involved in the fraud scheme.',
#  'He worked on the legs of the table.',
#  'I think that is inevitable.',
#  "You're the reason I came.",
#  "You're not going anywhere.",
#  'The county has a total area of which land and water make up 17.6%.',
#  'I was involved in the election of Emperor Ferdinand in 1619 and the election of Emperor Matthias in 1612',
#  'Jules de Blosseville named the mountain after Marie Henri Daniel Gauthier, a French naval officer.',
#  'He died before I arrived.',
#  'I have time.',
#  "I don't know why I'm tired.",
#  'The Grand Island of the south is considered to be Salina.',
#  'Esperanto is a fun language to learn.',
#  'Pueraria montana is a plant that grows in several places in Europe, including Switzerland and Italy.',
#  'The taxi was paid for by Layla.',
#  'There are many student organizations on the campus.',
#  'Thirty members are counted by the association.',
#  'Michael Chang won the final 3 by a score of 6 -- 6 -- 3 -- 7 -- 5.',
#  'What is your favorite genre?',
#  'The movie was better than I had anticipated.',
#  'My friend fasts.',
#  'The Jelgava District of Latvia has an administrative unit called Lielplatone parish.',
#  'He crept into the castle town as a peasant.',
#  'The new leader of Qoyunlu was Agha Mohammad Khan, his brother.',
#  'He works at the office with me.',
#  'He was trained in New York with a friend in 1869.',
#  'The Sara of the south was the only one that was effective.',
#  'That might be serious.',
#  'I seem to have a temperature.',
#  'Peter Maag was a Swiss conductor and was born in 1919.',
#  'These articles are not subject to duty.',
#  'The French were defeated.',
#  'She lost to Zimbabwe 50-25, to Tanzania 84-16, and to South Africa 58-24.',
#  "I hope that doesn't happen again.",
#  'Tom and Mary are not happy.',
#  'Martha married a man named George I. Eisenhauer after Anna was found.',
#  'I dug up one.',
#  'In the week before the first race, Barwa Addax driver Josef Krl was replaced by Dani Clos.',
#  "Tom doesn't think you should have done that.",
#  'I need my employees to be loyal.',
#  'The children need you.',
#  'Please let Tom Mary know.',
#  "I'm not sure if I'm hearing this correctly.",
#  'She is older than him.',
#  'I heard that you did that.',
#  'The A cells produce a substance called glucagon which mobilizes the hepatic glycogen and the enterochromaffin cells produce a substance called serotonin which stimulates the contraction of the smooth muscles.',
#  'They had a neighborhood ally in Brian and Phillip.',
#  'She was not funny for lunch.',
#  'I thought that Tom might break the contract.',
#  'People are not always rational.',
#  "Father doesn't allow me to drive.",
#  "Tom said he wouldn't sing.",
#  'The first freefall and the first drop tower were marketed by Giovanola.',
#  'There are a number of facilities in and around the area.',
#  'The British consul-general for the Ionian Islands was Wright.',
#  'To avoid such deadlock conditions, a potential protocol for the use of sensitive flow control signals must be used.',
#  'Are you happy with the result?',
#  'The Hepialidae family includes the Aenetus blackburnii, which is a common species in Australia.',
#  'What made you think it would come here?',
#  'The snow melted when the weather got nicer.',
#  'I had never seen a rugby match like that before.',
#  'The European Baseball Championship will be held in 2009, and Italy was one of the countries that qualified.',
#  'What did you think about the party?',
#  'I have to fix it.',
#  'We will carry you.',
#  'The roof was blown off.',
#  'The storm killed two people in the state.',
#  "You're worth a lot of money.",
#  'Tom has finished his lunch.',
#  'Why are you shouting?',
#  "I don't have to wear glasses anymore.",
#  'Jarymowycz was a lecturer at the Royal Military College and was a frequent author of letters to the editor.',
#  'He was born in Gosforth, Northumberland, but moved to the Wiseton Estate near Retford, Nottinghamshire, when his father found work there.',
#  'Tom was interested in what he was hearing.',
#  "She doesn't pay much attention to how she dresses.",
#  'This is not a good sign.',
#  'Albert Pyun, who had previously worked at Cannon, was brought on board and worked with the original script that started at Cannon.',
#  'He died at his home in Trenton in 1942 and is buried in Bridgeton at the Old Broad Street Presbyterian Church.',
#  "I know what you're planning.",
#  "Tom isn't going to help us.",
#  'The Messent Peak and the Brodie Peak are in the Bristly Peaks.',
#  'Barbara Kwarc is a Polish actress, comedian and celebrity who was born on June 19 1953.',
#  'In the 1990s, new teaching sites were opened in Ivrea, Biella, Alessandria, and Vercelli.',
#  'The original Barron Collier Bridge was the one that was replaced in 1931, followed by the current Gilchrist Bridge that crosses the Peace River.',
#  'Webmention was published in the community and was developed as a W3C work draft.',
#  'Pedro was in the care of a man called Sebastian.',
#  "I don't mind you staying here.",
#  'They make up a quarter of the population in both Klaipda and Vilnius.',
#  "Tom's heart was broken.",
#  'Kate is very nice.',
#  'I might be able to help.',
#  'The car is parked.',
#  "Jimmy Webb's work was inspired by the arrangement later.",
#  'A guide led visitors around the museum.',
#  'The south coast of Livingston Island is located between South Bay and False Bay.',
#  'Tom and Mary are adults.',
#  "You should be careful that you don't offend Tom.",
#  "I'm not drunk.",
#  "We're not afraid of anything.",
#  "I don't want to meet with him again.",
#  'I was free last Sunday.',
#  'Tell me about your day.',
#  'He lives with his wife and their children in Noah and Mabel.',
#  'Tom got it wrong.',
#  "She's a tease.",
#  'She wants someone to help her.',
#  'It was very hot.',
#  'Substitutes include ceramic, carbon, metal, and aramid fibers.',
#  'You look tired.',
#  'The job would be difficult.',
#  'They said that they were nervous.',
#  'The town of Corozal is in the Sucre department of northern Colombia.',
#  "I didn't talk to him.",
#  'I started to cry as well.',
#  'The wind is blowing.',
#  'I can accept that.',
#  'I need something cold to drink.',
#  'Maria Maria Vittoria Rossa Argento is an Italian actress, singer, model, activist and film director.',
#  "I'll get in touch with you soon.",
#  "His old car isn't worth anything.",
#  'The Greek text is the basis of the New Testament, which is more English than the Subliteral.',
#  'The person is now 100 percent Hawkgirl.',
#  'Tom is persistent.',
#  "Tom's father left his family.",
#  'What is it about?',
#  'We have to do this together.',
#  'The weather became cold after a few warm days.',
#  "Let's go and see them.",
#  'Tom wanted to know what happened.',
#  'The title and lyrics refer to the painting "Mona Lisa" by Leonardo da Vinci.',
#  'She traveled to Russia, Russia, Italy, Italy, France, Scotland, Scotland, Scotland, Scotland, and in 1923 to Iceland.',
#  'No comment.',
#  "Tom found Mary's house.",
#  'The two of us are not together anymore.',
#  'Mary said that she was wrong.',
#  'You have to work.',
#  'The site is for people who are still curious and still crazy after all these years.',
#  'His son won a Brownlow medal and his grandson played for South Melbourne.',
#  'I will never do that again.',
#  'Mike Parlett is an English jazz saxophonist and producer.',
#  'Tom was persuasive.',
#  'I was trying to locate Tom.',
#  'Carl Smestad was the son of a Norwegian industrialist and grandson of a Norwegian industrialist.',
#  'Lie on the table.',
#  "Let's go for coffee.",
#  'Tom has a lot of books.',
#  'The average life span of the Japanese is increasing.',
#  "I don't want to tell them the truth.",
#  'Both Tom and Mary want it.',
#  'You made a good decision.',
#  'The Pascu River is a part of the Valea Voenilor River.',
#  'Ask Tom if he will do that.',
#  'White succeeded the Chief Justice in 1921.',
#  'They are related to each other.',
#  'William de Middleton was a medieval Bishop of Norfolk.',
#  'Tom and Mary kept their relationship a secret from their parents.',
#  'No passengers were hurt.',
#  'The word is mum.',
#  'The performance of the LOD is compared in the table.',
#  'He is two years older than me.',
#  'The first railway station in Wellington was at Pipitea Point.',
#  'She burst into tears when she heard the news.',
#  "It's difficult to stop smoking.",
#  'The new device costs an arm and a leg.',
#  'Tom died in Boston.',
#  'Mount Filberg is a mountain located southwest of Mount Cobb on the west coast of Canada.',
#  'Only a small percentage of natural diamonds are of this type.',
#  "He's the tallest in our class.",
#  'You can come if you want.',
#  'Tom got up and left.',
#  'Mr Wilson is angry.',
#  'George X and Manny Rodriguez were announced as the SpikeTV Spanish commentators for the premier boxing champion.',
#  'He joined the San Diego Sockers in the Professional Arena Soccer League.',
#  'They said they will laugh.',
#  'This is the problem.',
#  'Bill brought me a book.',
#  'I asked them if they heard wedding bells when I saw them.',
#  'Count Harrach reported that the last words of the man were "Sophie,Sophie!"',
#  'He died ten years ago.',
#  'The domain abstract language for specific tree linting is based on the ideas from Model Checking for Tree Logic.',
#  'Pérez worked for Telemundo where she anchored and produced entertainment segments.',
#  'It is also home to the unincorporated towns of Calpella, Potter Valley and Talmage.',
#  "Don't disturb the others.",
#  'Ardning is a district in the Austrian province of Liezen.',
#  'Popeye was named by him.',
#  'The simple complex is formed by technetium and the isostructural salt.',
#  'The fortress was besieged by French troops for a second time in December and April of 1814.',
#  'The pain was very bad.',
#  'Eduardo Rivadavia of AllMusic gave it 4.5 stars and said it was a " creative breakthrough".',
#  'Lucas is a clever person.',
#  'I love your city.',
#  'Tom was seated.',
#  'The NBA season was 43 years old in 1988.',
#  "You're very good at this.",
#  'The island of Hopewell, Charles City County, Virginia, is also known as the "Shirley Hundred Island" and is a historic home and archaeological sites.',
#  'I would like to try on this dress.',
#  'We are working hard.',
#  'How is this going to end?',
#  'This is not the norm.',
#  'The musician Wajahat Attre composed the soundtrack with lyrics by Noor Jehan and Mehnaz and sung by Hazin Qadri.',
#  'The Final FESPIC Games had 18 venues, 9 of which were in Selangor.',
#  'The symbol of sr is Schlfli, which is the hyperbolic tiling of the single plane.',
#  'I built it.',
#  "She's conceited, as is common for teenagers from 13 to 19",
#  "I can, although I can't really speak the language of the city.",
#  'This is a war.',
#  'Where did you park the car?',
#  'He wanted it.',
#  'He was based in North Yorkshire from 1996 to 1999 after completing his university education.',
#  'Josh Billings was the pen name of Henry Wheeler Shaw, the son of his father.',
#  'He played in 53 games for the Piedmont League in the 1920s and 1930s, with a 26 - 19 record.',
#  'They said they were not busy.',
#  'Go upstairs and sleep.',
#  'It caught me by surprise.',
#  'The language of the configurations in which the Hesse configuration is found has the notation 912.',
#  "I'm calling from Tom's phone.",
#  'Tom stood still.',
#  'I should have told someone.',
#  'Tom is trustworthy.',
#  "I can't raise our child by myself.",
#  'I went there yesterday.',
#  'I want her to win.',
#  'Matter can be either solid or liquid.',
#  'It is 7 miles south of Bangor and 3 miles northwest of Llanberis.',
#  'Opposite the First Church of Christ, Scientists, Beverly Hills, California is 142 South Rexford Drive.',
#  'The Mid Wales Hospital was a mental health hospital in Talgarth, Wales.',
#  'Steve Reicher is a professor of social psychology and former head of the school of psychology at the University of St. Andrew.',
#  'Tom was thirty years old.',
#  'The interpreter gives her interpretation.',
#  'He just left.',
#  'He lost his stuff.',
#  'He wanted me to pay the money back at once.',
#  'He is a poet at birth.',
#  'He is a specialist in music.',
#  'The album " Deathstar Rising" cracked the new album top 10 and reached the number 8 spot in the first week of March 2011.',
#  'Tom will explain.',
#  'I am not happy with the result.',
#  'He is likely to win the speech contest.',
#  'I would like you to meet my brother Sam.',
#  'I will never be able to play again.',
#  'The National Audubon Society has a camp in Maine.',
#  'They promised to come.',
#  "I've seen you before.",
#  "You're expected to arrive by 2:30.",
#  'It is easy to learn English.',
#  'This is not real.',
#  'She unwraps a gift.',
#  'Spencer Machacek was traded by the Pittsburgh Pirates to the Columbus Blue Jackets in exchange for Thompson.',
#  'On September 23, "Myles C. Fox" reached Yokosuka and departed San Diego.',
#  "That's all it is.",
#  'He said he was going to be late.',
#  'The Earls of Mornington lived in the Dublin social season Georgian residence of Mornington House.',
#  'John Jacob Astor was one of the richest people in history and he was one of the first people to settle in North America.',
#  'McG and Ilene Chaiken produced the main role of ABC - Drama - Pilot "Westside" in 2013.',
#  'She asked me to do that.',
#  'I like to watch sports.',
#  'Can I help?',
#  'The poor man has no family.',
#  'The winds were strong.',
#  'Tom nodded and left.',
#  'Insatiably greedy.',
#  'I got a autograph from a famous singer.',
#  'Chabrian Jattan is a village in Mirpur tehsil of the Mirpur District of Pakistan.',
#  'He said he was thirsty.',
#  "Don't let it get to you!",
#  'I am not aware of the plan.',
#  'The vultures were above the dead body.',
#  "Tom looks like he's having fun.",
#  'The official language is Hindi, while the local language is Bhojpuri.',
#  "He's not real.",
#  "You don't know what is Esperanto.",
#  'Are you not afraid of ghosts?',
#  'Lilly will be on the World Curling Tour in her first season with the new teammates.',
#  "Tom knew that Mary wouldn't win.",
#  'The library is a dream in architectural beauty and a model in the interior, according to a newspaper article.',
#  'She was the second daughter and the youngest of four children born to Philander and Mary Weeks.',
#  'Ask if he comes.',
#  'I want his head.',
#  'The term " j " is always provided regardless of how complex the RC network becomes.',
#  'We tried that.',
#  'Dehgh is a village in Bojnord County, North - Khorasan - Province, Iran, in the Badranlu Rural District of Central District.',
#  'Jones lives with his wife, son, and three daughters in London.',
#  "Don't let a good opportunity go to waste.",
#  'That film is really interesting.',
#  'We got to the summit.',
#  "I didn't get a wink of sleep last night.",
#  "This isn't the last train?",
#  'You can wait for the cows to come home.',
#  'Have you ever seen a river?',
#  'The Portuguese language is different to the Brazilian one.',
#  'The magazine was released in London by Gerald Duckworth and Company.',
#  'Lepel was a quiet regional center in 1913, it had lost its strategic and economic importance.',
#  "We could've done it.",
#  'The Goodwill family had a child named Thomas Thomas.',
#  'Tom will probably be upset.',
#  'These are the enzymes that can oxidize prochiral substrates.',
#  "Don't put me in this.",
#  "I've never said that.",
#  'Tom made us leave.',
#  'Mary is the laziest of her schoolmates.',
#  'He was sure of that.',
#  "I've done nothing special.",
#  'How long does it take to get to the train station?',
#  'I walked alone.',
#  'When water is boiled, it becomes steam.',
#  'Tom turned off the lights.',
#  'I am very happy to visit VNU.',
#  'Tom seems to have a lot of money.',
#  'These allegations are not true.',
#  'She tried to kill herself.',
#  "They don't show up.",
#  'I think I was followed.',
#  'I am ready to die.',
#  'Dragan Umievi is a Serbian ice hockey player who is Swedish descent.',
#  'Tom said it was your fault.',
#  'I brush it off.',
#  'Tom advised you to follow it.',
#  'Get on your horse.',
#  'I have a sharp knife.',
#  'The band toured through Japan, the United States and England.',
#  'Peter andNatasha were the parents of Simon, as was his sister, author and actress, Irina.',
#  'I wonder if Tom is happy.',
#  'At "Shine 8 ", Valkyrie defeated the other teams in an eight man - team match.',
#  'In most European countries, political parties are factual associations.',
#  'An American is a competitor in the synchronized swimming and Olympic championship.',
#  'The first recorded Irish presence in Newfoundland was in 1536 when Irish fishermen from Cork traveled to Canada.',
#  'The tire is not high.',
#  "Do you think I'm to blame?",
#  'Look for rock slides.',
#  'Susie J. Clarke married Brown in Massachusetts on December 30th, 1888.',
#  'Tom needs some help.',
#  'Tom was going to defend his title against Frank Trigg.',
#  'Tom will probably be very hungry.',
#  'The teacher told us about the dictionary.',
#  'Everything is connected to something else.',
#  'Tom was thinking about Mary a lot.',
#  'The Boston Red Sox and Cincinnati Reds played a series in Havana.',
#  "I'm happy no one is around.",
#  'The new route leads from Gothenburg via Norway to the city of Newcastle.',
#  'I was at a theater.',
#  'This process is similar to a map projection.',
#  'I met the queen.',
#  'Did you kiss him?',
#  'I had no idea that you were coming.',
#  'It was making me crazy.',
#  'The old building became the Lower School while the new building became the Upper School.',
#  'This mistake is easy to overlook.',
#  'Tom and I know Mary.',
#  'Something happened that was not expected.',
#  'Tom looked straight at me.',
#  'The debate was presented by Jessica Soho and Mike Enriquez of GMA News and John Nery of Inquirer.net.',
#  "I'll sing.",
#  'Dennis is sentenced to die with Hugh and Barnaby.',
#  'The River Comina is a river in Romania.',
#  "I'm proud.",
#  'Miovi left Sweden to avoid arrest in order to join the Serbian organized crime group.',
#  "I'll answer you tomorrow.",
#  "Tom doesn't like romance.",
#  'The Russian and central Asian populations were split into two species, one being the Chinese species.',
#  'My bike is missing.',
#  "I haven't seen him in a while.",
#  'Tom sat across from Mary.',
#  'Were you able to get what you needed?',
#  'Tom says he did nothing wrong.',
#  'The trip was delayed because of the rain.',
#  'The logo is similar to that of the Buffalo Sabres.',
#  'I can walk to school in 10 minutes.',
#  'The intersection of the Central Western Line and the Rockhampton line was named Emu Park.',
#  'They were talking all night.',
#  'You should buy him some new toys.',
#  'The son of a man who died in Paris became a painter.',
#  'Vermont South is bordered to the north byMitcham, to the west by Nunawading and Forest Hill, to the south by Wantirna and Ringwood, and to the east by the ocean.',
#  'Espuelas worked on the accounts of Weight Watchers and General Foods Gevalia.',
#  'They were dancing.',
#  'You seemed interested.',
#  "I don't know what it is.",
#  'Edward Everett bought the manuscript in 1819 from America to Constantinople.',
#  'Prodrive will enter the World Championship in the Rallycross category with a car from the brand, a Renault Mégane.',
#  'I need some things.',
#  'Do you have a room of your own?',
#  'Tom gave me something.',
#  'I like coffee more than tea.',
#  "Don't forget about death.",
#  "Tom didn't sound confident.",
#  "I wouldn't do that.",
#  'The basic meaning of acting for is the same as acting for, except that it means that the original occupant of the position is still in control.',
#  'I get a lot of email.',
#  'The series was written by Matt Mariska and Andy Sipes.',
#  'Can I do anything?',
#  'I fell asleep while watching tv',
#  'The ice show was toured through most European countries, including Germany, Italy, the Netherlands, Switzerland, Hungary, Czechoslovakia, Belgium, France and Spain.',
#  'Tom and I are both professors.',
#  'The husband was named Percy W. Adams and the wife was named Gwendoline Wright.',
#  'Hatherley joined the band of KT Tunstall in 2010 and played lead guitar.',
#  'Drew Springer, Jr., a Republican from Muenster in Young County, has represented the county in the Texas House of Representatives.',
#  'He applied for admission to the club.',
#  'He is correct.',
#  'By that time, a high proportion of slaves in Delaware had been freed.',
#  'There was a full moon last night.',
#  "I'm not sure if Tom will be able to do that.",
#  'No one said anything.',
#  'Where are my boots?',
#  "I'm on vacation.",
#  'I want some tea with you.',
#  'Alejandro Lerner wrote all the songs except " A Place Where We Belong" co-written by Graham Russell.',
#  'Milk is a good drink.',
#  'Is Tom to blame?',
#  'I came early to get a good seat.',
#  'There are four types of databases, which are:curated databases, predictive databases, literature databases and integrative databases.',
#  'Have they found him?',
#  'Since 1976, New Jersey did not vote for the same candidate in Pennsylvania.',
#  "You could've done better.",
#  'There were no flowers or trees on the streets of his town.',
#  'How does she raise her children?',
#  "You're conscientious.",
#  'He sailed to Belfast in 1933 to join his parents.',
#  'The balance was put into the accumulator when the card was read into the car.',
#  'The human embryo has the necessary anatomy for development.',
#  "Someone must've followed us here.",
#  'The Nvidia TITAN V was announced on December 7.',
#  'Why should I study French?',
#  'Tom passed away suddenly.',
#  'She lost both of her parents.',
#  "Valerin's castle is seized, he is killed and the queen is released.",
#  'Tom will probably wake up.',
#  'A New Zealand civil servant, author, fine hunter and collector of New Zealand recreational art, Thomas Edward Donne died in 1945.',
#  "They said they're bored.",
#  'You hold me in your arms.',
#  'Joe was born in Massachusetts on March 27 1929 and grew up in Quincy.',
#  'This is gorgeous.',
#  'Tom and Mary said they are not upset.',
#  'The Lehigh River is a waterway in the United States.',
#  "He's from Austria.",
#  'She was not hurt.',
#  'I apologize for dragging you into this.',
#  'The white males are immature.',
#  'Tom is having a hard time making ends meet.',
#  'Do you like beer?',
#  'He is looking for fame.',
#  'He was the son of Shmuel Binyamin Sofer and the grandson of Ksav Sofer.',
#  'Tom should have waited for me.',
#  'I saw him cry.',
#  'She is a better leader than he is.',
#  'Tom works there.',
#  'The 1975\'s sixth single from their self-titled debut was " Robbers".',
#  'Samata Express is a fast train that runs between Visakhapatnam and New Delhi.',
#  'Birds are flying.',
#  'Adult birds have white bodies with a black wing patch, a thin dark bill, and red legs and feet.',
#  'That was a dumb question.',
#  'Something has gone wrong with it.',
#  "I'll tell him you came by.",
#  'Natalia has been appointed as a conductor professor by the Royal College of Music.',
#  'The map is here.',
#  'The club owner, along with Phillippe Mexes, Kevin, Prince Boateng and Mario Balotelli, announced their departure on May 25th, 2016',
#  "Don't make sudden moves.",
#  'The theatre usually opens at this time.',
#  'It is endemic to California in the central Sierra Nevada.',
#  "They didn't know who they were supposed to meet.",
#  'Tom knew that I was happy.',
#  'The lake is three miles long.',
#  'I would be willing to take that chance.',
#  'The busway route A connects the two airports.',
#  'Tom has written several books.',
#  "It's easy to answer that question.",
#  'Chandra is looking for a partner for his wife, and talks about the marriage of Meena have begun.',
#  'That was a disappointment.',
#  'I love talking with him.',
#  'Tom is not ready yet.',
#  'A golden key opens all doors.',
#  'One billion people are in the same boat.',
#  'I hear you have stopped smoking.',
#  'According to the writings of Fritz Heider, people tend to regard behavior in two ways: the cause of situational factors or dispositional factors.',
#  'Stvl is a castle in Sweden.',
#  'The characteristic function is an alternative way to describe a random variable.',
#  "My mother says I'm handsome.",
#  'Arequipa is a coastal area of Peru and is prone to earthquakes.',
#  'Tom ate some cookies.',
#  'Tom is somewhat similar to his father.',
#  "I will not tell anyone you're in Australia.",
#  'He is delightful.',
#  'The dividends have increased the total return on average equity by about 3%.',
#  "It's raining.",
#  'The new stadium was inaugurated on August 21, 1974 after being built for 4 years.',
#  "I'm not a real person.",
#  'Alexander Rigby bought the great existing Plough of Lygonia patent in 1643, which included Cape Elizabeth.',
#  'The results of the study showed that the winner effects were shown when established non-experienced chicks were placed against dominant chicks.',
#  'I went to bed at twelve.',
#  'A civic activist and politician inLithuania, Tadas Langaitis is a member of the Seimas.',
#  'You are not in her league.',
#  "Tom doesn't smoke anymore.",
#  'Tom is going to succeed.',
#  'Terry was born in Fairfax, Iowa and died in Cedar Rapids.',
#  'The constituency was one of the safest in the Labour party.',
#  'It was designed by Little Rock architect Harold A. Berry.',
#  "Tom didn't show.",
#  "I'm looking forward to hearing from you.",
#  'Miniature versions of historical buildings and structures are presented by the CCV.',
#  'Tom answered the question correctly.',
#  'He banged the door in anger.',
#  'Tom is going to do that tomorrow.',
#  'I drink coffee.',
#  'The Golden Mile is a stretch of road between the western border of Chiswick and Syon Lane.',
#  'Tom looked like he was in top shape.',
#  'He moved back with his parents.',
#  "I'm four years old today.",
#  'The metropolitan statistical area includes Union County and the combined statistical area of Anderson and the Greenville.',
#  "I've known Tom for a long time.",
#  "I'm not afraid of anything.",
#  "I've read all those books.",
#  "We're going to have to do that.",
#  'He lost the final to Andrey Balanov.',
#  "Robert of Torigni said that Humphrey's mother was Duvelina, sister of the Duke of Normandy.",
#  "Tom doesn't need to be concerned anymore.",
#  'Queen Victoria traveled from Gloucester to Swindon by train.',
#  'It is located on the modern Natchez Trace, Mile 180.7, at the historic Natchez Trace Parkway in Mississippi.',
#  'The Portland -- South Portland -- Biddeford is part of the Maine Metropolitan Statistical Area.',
#  "I'm afraid you will get lost.",
#  "I'm really hung over and you could lower your voice.",
#  "Beer is the first thing we'll start with.",
#  "Colonel Ray and Lieutenant Colonel Koski died on New Year's Eve.",
#  'Green and Tom Jones have all recorded songs written by O.V. Wright.',
#  'There is an alternate.',
#  'I was so lonely.',
#  'You are either with or against us.',
#  'Stephen Hendry defeated Peter Ebdon in the final to win the title for the first time.',
#  "Tom's parents were both teachers.",
#  'Major General Nathan Mugisha took over as commander of the African Union Mission in South Sudan on July 7, 2009.',
#  "You're a great cook.",
#  'The agreement with Bolivia was applied on August 4, 2016 and not denounced until February 4, 2017).',
#  'Has she arrived?',
#  'You have no right to judge these people.',
#  'A Terran operative, named Alexis Anders, has survived a plane crash in the Hellers a week earlier, according to a conversation between her supervisor, Cholayna Ares, and her coworker, Magda Lorne.',
#  'Give me a chance.',
#  'Mount Morris Township is in Illinois.',
#  'Archdale is a residential area in the Starmount.',
#  'The incident was first reported by international media, but not by the state-controlled Iranian media.',
#  'Someone was murdered.',
#  'It is important to sleep.',
#  "It's not a disease.",
#  'He thinks that the writer should first prove himself, while he thinks Elbow is too acceptable.',
#  'TJ Trinidad, Biboy Ramirez, Eric Fructuos, Rico Robles, Joem Bascon, Jordan Hererra, Rico Barrera, and Michael Roy Jornales were involved.',
#  'We hope you visit Boston.',
#  "I haven't eaten anything yet.",
#  'On the Baltic coast of Germany, on 5 September 1774, was born a boy named Caspar David Friedrich.',
#  'Lake Bordaglia is located in the province of Udine, Italy.',
#  "I don't know if it is good or not.",
#  'The boundaries were Pearl Street to Grier Avenue and South Broad Street.',
#  'Tom is doing well now.',
#  'The Beliu River is a river in Romania.',
#  'We clear the futon in the morning.',
#  'She cried bitterly.',
#  'The headquarters of the Maryland Department of Transportation are in Anne Arundel County.',
#  'Living in the town is different from living in the country.',
#  "Most languages will give a default class class if the programmer doesn't provide a class class.",
#  'Ahmet Davutoglu, the Turkish Prime Minister, argued that Turkey would not support the EU-Turkey agreement if the EU weakened visa conditions by June 2016',
#  'The Japanese government helped build a new bridge at Phnom Penh on the Neak Leung to Ho Chi Minh Highway 1 in 2015.',
#  'I met him this morning.',
#  'Please take the dishes away.',
#  'He played for the Brooklyn Dodgers and New York Giants.',
#  'The Urechioiu River is a body of water in Romania.',
#  'Tom ate his food.',
#  'The first formal description of the species was in 1856 from material collected by James Drummond.',
#  'The town of Rongcheng is where the government of Qingyang County is located.',
#  'He has won many prizes for his work, including the European " freestyle" campaign for Nike.',
#  'I got a noisemaker for a gift.',
#  'Dave Denine is a provincial politician in Newfoundland and Labrador, Canada, who worked as Minister of Intergovernmental Affairs in the former Canadian cabinet.',
#  "Tom said he didn't feel anything.",
#  'Tom is a teacher.',
#  'My friend lives there.',
#  'Tom will be there tomorrow.',
#  'Give me the pleasure of being quiet.',
#  'He was born and raised in British Columbia, Canada, and died in a Canadian province.',
#  "I don't have anything to give you.",
#  'Tom said Mary likes to dance.',
#  "What color is Tom's hair?",
#  'Tell Tom how you feel.',
#  'We must help him.',
#  'They said that they are angry.',
#  'Michel Martin said that the leader of the party,Shane Ross, had contacted her the previous day and that she would meet the following week.',
#  'To avoid potential deadlock conditions, a sensible protocol for the use of transmission flow control signals must be used.',
#  'I asked everyone the same question.',
#  'They are talking.',
#  'After retiring from Lucknow, Mohsin Zaidi lived in Delhi for nearly four decades.',
#  'His invention deserves attention.',
#  'The first schools in the area were built for 400 black students and 60 white students.',
#  'Euacidalia brownsvillea is found in Texas and Hawaii.',
#  "It's not certain if he'll come.",
#  'I am a computer hacker and I have installed a program on your computer.',
#  'Tom forced his way in and sat down.',
#  'We split the loot into three different ways.',
#  'Do you know how to drive?',
#  'This victory was repeated in an Oldsmobile in 2003 with Reuter, Tiemann, Strycek, and Scheider.',
#  'I heard a noise.',
#  'Tom and Mary are not talking to each other.',
#  'Penn State defeated Philadelphia, 19-7, at Pennsylvania.',
#  'The two stations are not interchangeable, they are located along different parts of Pudian Road.',
#  "I'm in the kitchen.",
#  'The family Neolepetopsidae has a true limpet, a true mollusk, and a sea snail.',
#  'He went to Canada to sign with the Toronto Falcons of the National Soccer League after he finished his career in Poland.',
#  'He died in Germany and is buried in Corsica.',
#  "You have to deposit three months' rent.",
#  'Do you have an appointment?',
#  "I don't like flying.",
#  'Metin stnda, Bahadr Baruter, Erdil Yaarolu, and Seluk Erdem founded it in 2002.',
#  'Tom and Mary are ready.',
#  'You should write things down.',
#  "George M. Beebe was chosen as president and that's when Lester B. Faulkner became chairman.",
#  'Our grandfather was a linguist.',
#  "She doesn't like sad songs.",
#  'The shape of the audiogram is used to categorize loss.',
#  'Lone Star Comics sold off three of their stores in July of 2013).',
#  'Zina Garrison and Sherwood Stewart were the defending champions but lost in the second round to Jim and Jana.',
#  'Djurgrdens IF U18 beat Malm FF U18 with 3 -- 0',
#  'This will be his car.',
#  'The soundtrack was written by Tony Aheibam and the texts were written by Raju Mikoncha.',
#  'It was taken to Australia where it is widespread today.',
#  'Sarah Hendrickson, Sara Takanashi, Coline Mattel, and Evelyn Insam were the women who were the favorites.',
#  "We're not crazy.",
#  'Beverly Hills railway station is located at the South Line Airport on the Sydney Trains Network, with Riverwood in the west and Narwee to the east.',
#  'Davies was a socialist at the LSE and lived with Jomo Kenyatta.',
#  "She said she couldn't speak the language.",
#  'Mary is a musician.',
#  'People feel afraid.',
#  'You can invite anyone you want.',
#  'Tom wore a tie.',
#  'His friend runs a grocery store.',
#  'Kumara Sambhavam is a 1969 Indian and Tamil film.',
#  'The children werebaptized by their father, Sami.',
#  "Tom didn't understand.",
#  'He made the situation worse.',
#  'White porcelain or white porcelain decorated with iron underglaze, copper-blue underglaze, red underglaze and cobalt are examples of ceramics.',
#  'The Cincinnati Reds and Boston Red Sox played a series in Havana.',
#  'He thinks he is a person.',
#  'He said that he is not busy.',
#  "Why don't you admit your mistake?",
#  'The main partners of the festival are Parmigiani Fleurier, Vaudoise, and the other ones.',
#  "It's popular with senior citizens.",
#  'Everyone was worried.',
#  'I got these earrings from my grandmother.',
#  'Jack is the most studious boy in our class.',
#  'The tree has no fruit.',
#  'The man got christened.',
#  'His ambition is not limited.',
#  'Dr. Carter is in Africa for several months and works in the AIDS clinic.',
#  "We're moving next month.",
#  'I saw Tom hit Mary.',
#  'The winner of the Best of 3 race rose to the gold medal race, while the other two drivers went to the bronze medal race.',
#  'He was presented with a medal in the hospital.',
#  'Tom began whistling.',
#  'Do you know each other?',
#  'Tom was wrong.',
#  'The Penser Joch is a high mountain pass in Jaufenpass, northern Italy, close to the South Tyrol.',
#  'Would you like to attend my party?',
#  'In the United States, the production of the MY13 model year was limited to 6,000 units for the cult brand, Scion.',
#  'The troops had a lot of weapons.',
#  'I never learned to swim.',
#  'The services between the Aerodromes of Nanaimo Harbour and the International Water Airport were operated by the same company.',
#  'The show requires a small set and a small cast of 6 actors, as well as a solo violinist who is present on stage throughout the performance.',
#  'Is this your first trip abroad?',
#  'The south side of High Street is west of Fifth Avenue.',
#  'Communication is needed to progress.',
#  'My father used to say that time is precious.',
#  "I don't bother with people like him.",
#  'Jimmy Arias defeated the man named Agassi.',
#  "Tom doesn't know what will happen.",
#  'Tom was going to do that by himself.',
#  'My school grades were average.',
#  'They said they are busy.',
#  'A painter can be hurt.',
#  'How do you say "@" in your language?',
#  'Grahame Clark proposed a system of stone tool technologies in 1969 and it was outlined by Lawrence Barham and Peter Mitchell.',
#  'Tom should never have done that.',
#  "We're eating apples.",
#  'In 1944, Cozens was promoted to Lieutenant-General and later appointed assistant chief to Ronald Scobie.',
#  'It was formed by three people.',
#  'Put on a happy face',
#  'Abbott killed Mary.',
#  "We're going to do that tomorrow.",
#  'They said that they would win.',
#  "I don't think Tom is busy.",
#  "I'm trying to get her to accept me.",
#  "I'm not good at Arabic.",
#  'In the state elections of November 1856, 81 Republicans, 31 Democrats and 8 Americans were elected to the Assembly.',
#  'The official language of Hindi is Bhojpuri.',
#  'You have to buy a ticket to get on the bus.',
#  'I am calling my brother.',
#  "I think it's a lie.",
#  'The final 6 -- 2, 6 -- 4 was won by Anabel Medina Garrigues and Virginia Ruano Pascual.',
#  'I have never seen you so angry.',
#  'There are nearly 2,000 islands along the coastline, of which about three quarters are not inhabited.',
#  'Let me under your umbrella.',
#  'I could speak German with ease.',
#  'The dress becomes you.',
#  'Balkl is a village in the district Gmhacky.',
#  'The test above does not distinguish between more complex distributions.',
#  'Tom is dyeing his hair.',
#  'It failed again a few years later, but opened again.',
#  "I don't think it's fun.",
#  'The East Indians arrived in Jamaica on 13 May.',
#  'Billy Childish, Jake Chapman, Billy Childish, and Joshua Compston are included in the project.',
#  "It's hard to keep friends.",
#  'Tom made some good suggestions.',
#  'Good morning, Tom.',
#  'The third album was released in 2003 on Dragonfly.',
#  'Young girls want slim figures.',
#  'Mary put on her wedding dress.',
#  'Station F was founded in 1947 by the British Dependencies Survey on Winter Island.',
#  'He is known for his work on complex and erotic origami models, called "Pornigami"',
#  'Have you traveled recently?',
#  'The citizens have a legitimate right to have public libraries.',
#  'He broke the window.',
#  "We didn't see him.",
#  "I'm taking him to the hospital.",
#  'It will be all right.',
#  'What did Tom look like?',
#  'It was formed by three people.',
#  'The tournament was held in San Francisco for two years.',
#  'Tom is worried about that.',
#  'The team has played teams in recent years such as Iowa, Rutgers, Hawaii, State of Mississippi, Nebraska, Connecticut, Syracuse and Pittsburgh.',
#  'After an attack on the State of Zhao, troops from the states of Chu and Qin united to attack but were defeated.',
#  'The whole body hurts me.',
#  "That's what matters.",
#  "Tom wouldn't help me.",
#  'The students are having a break.',
#  'The National Film Award for Best Actress went to Indrani Halder.',
#  "We're brothers.",
#  'The people are angry.',
#  "Let's drink coffee.",
#  "Let's wait for the rain to stop.",
#  'The weather is warm in the winter and cold in the summer.',
#  'They captured him.',
#  'I have to go alone.',
#  'George, John Francis, and Charles Fenton Mercer were all related to the man named Mercer.',
#  'The factory team of Pramac Ducati had a new rider in the 2015 season.',
#  'The SAS curve is a long term line called the EAS curve.',
#  'The 3rd Compilation - Album, their 1st Live album and their 9th total album were released by the Kottonmouth Kings on August 12th, 2003',
#  'The family Gelechiidae is found in Assam, India.',
#  'Margaret was the daughter of Edmund and Hannah Craske.',
#  'He came back before eight.',
#  'Tom is talking to Mary.',
#  'Something bad is going to happen.',
#  'The person was so sorry.',
#  'I wish I knew what was happening.',
#  'The second Peabody Hotel opened in 1986 in the area of the Magic City.',
#  'Are you going to kill me?',
#  'They have a good relationship.',
#  'There are holes in the veranda for fastening wooden pillars.',
#  'I own that black one.',
#  'Everything has been improved.',
#  'He had an operation.',
#  'The district of El Marsa is located in Algeria.',
#  'Tom has had many different jobs.',
#  'Tom is correct.',
#  'Tom put out the fire himself.',
#  'The teacher is likely to be angry.',
#  'Your one year stay in Germany was useful.',
#  'It looks familiar.',
#  'I need a coffee.',
#  'This partnership was the first of more than 100 runs for a team that was seven runs down for less than 100.',
#  'The Saladas department is in Argentina.',
#  'I was forced to take medicine.',
#  'I want you to use it.',
#  'Iran, Syria, Sudan, and North Korea are on the list.',
#  'James Horlick was the brother of William Horlick.',
#  'The new facility had four sections, including an academic wing, student services wing, and two athletic wings with classrooms.',
#  "They swore that they wouldn't cry.",
#  'You should help your friends.',
#  'It is divided into two parts by the Sarawak district.',
#  'Tom and I are not going to go together.',
#  'The series was only available in Wal-Mart Canada, but was eventually sold online.',
#  'My parents are dead.',
#  'The institutions they founded were small and did not offer the higher degrees of medicine and theology.',
#  'The first stage of the new rocket, the Falcon 9, was successfully landed on land for the twentieth time on its first flight.',
#  'I should accompany you.',
#  "Tom can't join us.",
#  'Since then, it has been fine.',
#  'The South Charlotte area is called Starmount and it is a residential area.',
#  'He has a hat on.',
#  'I hope I did the right thing.',
#  'Conlan Carter was an actor who appeared in " The Law and Mr. Jones" and " Combat!',
#  'I know you are skeptical.',
#  'Tom is a garbage collector.',
#  'It will be over soon.',
#  'Tom is not busy.',
#  "I don't envy him.",
#  'Is there any zakuska?',
#  'The species can be found in the Atlantic Ocean, Gulf of Mexico, and Caribbean Sea.',
#  'Husbands and wives should be supported.',
#  'You can trust me.',
#  'This soup is bad for fish.',
#  'Gidoni was elected to the Veneto Regional Council after Tosi was excluded from the elections.',
#  'Have you ever seen an animal fly?',
#  'The open space is covered by the same or similar protocol specifications.',
#  'The southwestern corner of Fulton County is bordered to the west by Franklin County and to the south by Washington County in the state of Maryland.',
#  'The last edition in which cyclists were used on national teams was 1969',
#  "It's snowing in Paris.",
#  "She doesn't want to judge him.",
#  'Lpez Obrador said that on July 17th, 2006 in a radio interview with Miguel ngel Granados Chapa.',
#  'I know that Tom is happy.',
#  'She told me that she would be in Paris in August.',
#  'TATP is a white powder, according to some witnesses.',
#  'Max Franz was the ruler of the university and the spa quarter of Bad Godesberg.',
#  'Does the room have a bath?',
#  "There's nothing to see.",
#  'I would rather be at home.',
#  'Tom thought Mary was annoyed.',
#  "Don't tell him about it.",
#  'I should have invited Tom.',
#  '" Vishwaroopam" is undoubtedly rests on the genius of Kamal Haasan, stated the author of " Rediff ".',
#  'Active medication was the most preferred method of treatment.',
#  'He was taken to the hospital with chest pains.',
#  'The Turkish Cypriot side of the Karpas Peninsula contains the village of Galinoporni.',
#  'Dean and Litwin collaborated on a song and a story for the cat, but they ended up working with each other.',
#  'Tom is talking to someone.',
#  "These aren't fish.",
#  'Rabbi Levi said that God showed Jacob all the signs on the night he was born.',
#  'I eat fruit.',
#  'After the partition of India in 1947, Bade Ghulam returned to his hometown of Kasur, Pakistan, but then moved to India permanently in 1957.',
#  'I never told you anything.',
#  "Let's drink some tea.",
#  "I've never met anyone like you before.",
#  'All people are good.',
#  'Joe decided to join the escape plan.',
#  'The definition can be extended as follows.',
#  'How is Tom related to you?',
#  "The NBA season was in the 70's.",
#  'I hated him.',
#  "I don't know what it is.",
#  'Tom likes fishing.',
#  'The county has a total area of land and water.',
#  "We've been helping him.",
#  "We're all on the same page.",
#  'Writing with chalk is not very important.',
#  'He was the captain of South Africa when they played the British Isles in August of 1891.',
#  'Tom kept running.',
#  'The factory team of Pramac Ducati had a new rider in the 2015 season.',
#  '"Purple Clover" is a site for people who are still cool and curious after all those years.',
#  ...]

# %%
test_combined_en['Pegasus_paraphrases'] = pegasus_paraphrases

# %% [markdown]
# ## Computing metrics over pegasus paraphrases

# %%
Jaccard_1 = []
bleu_1 = []
bleu_2 = []
bleu_3 = []
rouge_l = []


for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['Pegasus_paraphrases'][n]
  #lexical-syntactical variation metrics
  rouge_l.append(rouge_score(candidate, reference,ngram='l' ,metric='f'))
  bleu_1.append(bleu_score(candidate, reference, ngram=1))
  bleu_2.append(bleu_score(candidate, reference, ngram=2))
  bleu_3.append(bleu_score(candidate, reference, ngram=3))
  Jaccard_1.append(jaccard_similarity(candidate, reference, ngram=1))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 100%|██████████| 5000/5000 [00:08<00:00, 582.18it/s]

# %%
test_combined_en['bleu_1'] = bleu_1
test_combined_en['bleu_2'] = bleu_2
test_combined_en['bleu_3'] = bleu_3
test_combined_en['rouge_l'] = rouge_l
test_combined_en['jaccard_1'] = Jaccard_1

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                     Pegasus_paraphrases    bleu_1    bleu_2  \
# 0     The Chapel and Hall were designed by Butterfie...  0.751477  0.520254
# 1                                    This isn't my key.  1.000000  1.000000
# 2                                    He is a Biologist.  1.000000  1.000000
# 3                         I haven't read all the books.  0.687289  0.589105
# 4                   He is able to run faster than I am.  1.000000  1.000000
# ...                                                 ...       ...       ...
# 4995             Tom and Mary said they are not hungry.  0.888889  0.750000
# 4996                      I went swimming in the ocean.  0.857143  0.666667
# 4997                                 I'm not surprised.  0.818731  0.614048
# 4998          I think you could have been more patient.  0.888889  0.750000
# 4999                          Tom denied that he cried.  0.833333  0.600000
#
#         bleu_3   rouge_l  jaccard_1
# 0     0.375739  0.720000   0.800000
# 1     1.000000  1.000000   1.000000
# 2     1.000000  1.000000   1.000000
# 3     0.572741  0.857143   0.800000
# 4     1.000000  1.000000   1.000000
# ...        ...       ...        ...
# 4995  0.571429  0.800000   0.800000
# 4996  0.600000  0.833333   0.750000
# 4997  0.272910  0.857143   0.833333
# 4998  0.571429  0.800000   0.800000
# 4999  0.500000  0.800000   0.714286
#
# [5000 rows x 7 columns]

# %%
cosine_similarities = []
for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['Pegasus_paraphrases'][n]
  cosine_similarities.append(cosine_similarity(candidate, reference))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 100%|██████████| 5000/5000 [14:46<00:00,  5.64it/s]

# %%
cosine_similarities
# Out:
# [0.8988051414489746,
#  1.0000001192092896,
#  0.8168563842773438,
#  0.9121456146240234,
#  1.0,
#  0.7893121242523193,
#  0.8503328561782837,
#  0.8887044191360474,
#  0.9668281078338623,
#  0.9876384735107422,
#  0.9667176604270935,
#  0.6730732321739197,
#  0.9039831161499023,
#  1.0,
#  0.844748854637146,
#  0.7692811489105225,
#  0.7111097574234009,
#  0.9360570311546326,
#  0.8799909949302673,
#  0.8875881433486938,
#  1.0,
#  1.0000001192092896,
#  0.844257116317749,
#  1.0,
#  0.9472200870513916,
#  0.7992904186248779,
#  0.7912304997444153,
#  0.9999998807907104,
#  0.7217419147491455,
#  0.9954740405082703,
#  0.941727340221405,
#  0.7682729363441467,
#  0.9974835515022278,
#  0.779451310634613,
#  0.8364477753639221,
#  0.7618537545204163,
#  0.8319986462593079,
#  0.744911789894104,
#  0.777145504951477,
#  0.9999999403953552,
#  0.889611005783081,
#  1.0,
#  0.884306788444519,
#  0.7846093773841858,
#  0.8910635709762573,
#  0.9633488655090332,
#  0.6988840103149414,
#  0.5736786127090454,
#  0.6559237837791443,
#  0.9999999403953552,
#  0.503696858882904,
#  0.9999999403953552,
#  0.8405603170394897,
#  1.0,
#  0.6740432381629944,
#  0.7470985651016235,
#  0.6145732998847961,
#  0.8787804841995239,
#  0.8097026944160461,
#  0.9999999403953552,
#  0.48667019605636597,
#  0.8197133541107178,
#  ...]

# %%
len(cosine_similarities)
# Out:
# 5000

# %%
test_combined_en['cosine_similarities'] = cosine_similarities

# %%
test_combined_en

# %%
test_combined_en.to_csv('/content/drive/MyDrive/working_directory/tfm/models evaluation/pegasus_evaluation.csv', index=False)

# %%
test_combined_en['bleu_1'].describe()
# Out:
# count    5.000000e+03
# mean     7.142181e-01
# std      2.117976e-01
# min      3.775135e-11
# 25%      5.643211e-01
# 50%      7.245769e-01
# 75%      8.750000e-01
# max      1.000000e+00
# Name: bleu_1, dtype: float64

# %%
test_combined_en['bleu_2'].describe()
# Out:
# count     5.000000e+03
# mean      5.473337e-01
# std       2.807887e-01
# min      8.399956e-319
# 25%       3.333333e-01
# 50%       5.014747e-01
# 75%       7.223982e-01
# max       1.000000e+00
# Name: bleu_2, dtype: float64

# %%
test_combined_en['bleu_3'].describe()
# Out:
# count     5.000000e+03
# mean      4.322730e-01
# std       3.326158e-01
# min      8.399956e-319
# 25%       1.791328e-01
# 50%       3.585562e-01
# 75%       6.250000e-01
# max       1.000000e+00
# Name: bleu_3, dtype: float64

# %%
test_combined_en['rouge_l'].describe()
# Out:
# count    5000.000000
# mean        0.703858
# std         0.212835
# min         0.000000
# 25%         0.545455
# 50%         0.714286
# 75%         0.880000
# max         1.000000
# Name: rouge_l, dtype: float64

# %%
test_combined_en['jaccard_1'].describe()
# Out:
# count    5000.000000
# mean        0.698851
# std         0.204917
# min         0.050000
# 25%         0.545455
# 50%         0.684211
# 75%         0.857143
# max         1.000000
# Name: jaccard_1, dtype: float64

# %%
test_combined_en['cosine_similarities'].describe()
# Out:
# count    5000.000000
# mean        0.867727
# std         0.121969
# min        -0.035636
# 25%         0.793547
# 50%         0.887522
# 75%         0.978057
# max         1.000000
# Name: cosine_similarities, dtype: float64

# %% [markdown]
# Cosine similarity filters + Counts

# %%
test_combined_en_filter1= test_combined_en[test_combined_en['cosine_similarities'] > 0.5]

# %%
test_combined_en_filter2= test_combined_en[test_combined_en['cosine_similarities'] > 0.7]

# %%
test_combined_en_filter3= test_combined_en[test_combined_en['cosine_similarities'] > 0.9]

# %%
print(len(test_combined_en_filter1),len(test_combined_en_filter2),len(test_combined_en_filter3))
# Out:
# 4962 4510 2360

# %% [markdown]
# # T5

# %% [markdown]
# ## T5-large high quality paraphrase inference

# %%
#Installing correct versions of dependencies to run the model correctly
# !pip install transformers==4.10.2
# !pip install sentencepiece==0.1.96
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers==4.10.2 in /usr/local/lib/python3.7/dist-packages (4.10.2)
# Requirement already satisfied: huggingface-hub>=0.0.12 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (0.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (3.8.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (0.0.53)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (4.64.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (0.10.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (2022.6.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.10.2) (4.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.12->transformers==4.10.2) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.10.2) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.10.2) (3.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.10.2) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.2) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.10.2) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece==0.1.96 in /usr/local/lib/python3.7/dist-packages (0.1.96)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from tqdm import tqdm

# %%
t5_model = AutoModelForSeq2SeqLM.from_pretrained("ramsrigouthamg/t5-large-paraphraser-diverse-high-quality")
t5_tokenizer = AutoTokenizer.from_pretrained("ramsrigouthamg/t5-large-paraphraser-diverse-high-quality")
# Out:
# Downloading config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.75G [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/1.81k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/1.74k [00:00<?, ?B/s]

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print ("device ",device)
t5_model = t5_model.to(device)
# Out:
# device  cuda

# %%
# Beam Search
def get_response_t5(input_text,num_return_sequences,num_beams):
  text = "paraphrase: "+input_text + " </s>"

  encoding = t5_tokenizer.encode_plus(text,max_length = 128, padding=True, return_tensors="pt")
  input_ids,attention_mask  = encoding["input_ids"].to(device), encoding["attention_mask"].to(device)

  t5_model.eval()
  beam_outputs = t5_model.generate(
      input_ids=input_ids,attention_mask=attention_mask,
      max_length=128,
      early_stopping=True,
      num_beams=num_beams,
      num_return_sequences=num_return_sequences)
  
  paraphrased = []
  for beam_output in beam_outputs:
      sent = t5_tokenizer.decode(beam_output, skip_special_tokens=True,clean_up_tokenization_spaces=True)[19:]
      paraphrased.append(sent)
  return paraphrased

# %%
t5_paraphrases = []
for original_sentence in tqdm(test_combined_en['Text']):
  paraphrases = get_response_t5(original_sentence,1,1)
  t5_paraphrases.append(paraphrases[0])
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2340: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   "`max_length` is ignored when `padding`=`True` and there is no truncation strategy. "
# 100%|██████████| 5000/5000 [58:39<00:00,  1.42it/s]

# %%
t5_paraphrases
# Out:
# ['William Gibbs funded the Chapel and Hall, which was also designed by Butterfield.',
#  "This isn't my only thing.",
#  'He is a biologist.',
#  "I haven't read any of the books on the shelves.",
#  "He's able to run faster than I am.",
#  'Arnold had already been sent from Skenesboro and Asa Douglas to Panton with sections to secure boats when Samuel Herrick arrived on the scene.',
#  'The song also received " early " dazzling support across Europe," according to Jon Uren, Warner Music Europe\'s marketing manager.',
#  'After Mary, Tom was dismissed.',
#  'She has been living in the town for five years.',
#  'I think the wine is delicious.',
#  'What are you dreaming about?',
#  'However, nationalist parties, as well as other liberal parties, have announced that they would not attend the elections in July.',
#  'Tom said he would not be concerned with being disturbed.',
#  'Tom changed his clothes.',
#  "The 1980-81 Toronto Maple Leafs season was the 54th season of the franchise, the Maple Leafs' 64th season.",
#  "I've dated a lunatic.",
#  'The following 13 ranchos were granted in Napa County during the period 1836 to 1846, when California was a province of independent Mexico.',
#  "I'm an idiot, according to Tom.",
#  'Thank you for your warning.',
#  'Where did she learn to dance?',
#  'I talk fast.',
#  "Holden Ford's character is based on FBI Agent John E. Douglas, and Bill Tench is based on a pioneer - FBI Agent Robert K. Ressler.",
#  'In fact, the two terms are now being used in other areas of the country.',
#  'They told everyone that they were suspicious.',
#  "It's not a horse, but a donkey.",
#  'Tom is planning to attend your party.',
#  "I can't express myself in English very well.",
#  "It's a good thing that there are no missing people.",
#  'The three patrols - districts serving Center City - are the 17th, 9th, and 6th districts.',
#  'The Sunday comes after a long weekend.',
#  "She'll soon be married to him for ten years.",
#  'The findings show that we are all aware of the one true spiritual Mind and divine Spirit, not a physical body.',
#  'Blauburger has good yields and is particularly vulnerable to " Botrytis cinerea "," but is not immune to mildew.',
#  'She has no idea about your family.',
#  'She was dressed in a red blouse and a black skirt.',
#  'Rebecca remains in Summer Bay for the school holidays after Donald shared everything about Bobby and Morag.',
#  'I speak only Italian.',
#  "The river Tătaru is a tributary of Romania's Buzăiel River.",
#  "I can't wait until tomorrow.",
#  'I noticed him at once that he was ill at ease.',
#  'Tom usually sleeps for eight hours.',
#  'Georges Merle died in Paris in 1881, and his son Hugues Merle later became a painter.',
#  "I'm positive that she will not be around to see you.",
#  'All weekend, I was waiting for a critical call.',
#  'San Pedro Springs Park is located in Bexar County, Texas, in the United States state of Texas.',
#  "Since I haven't seen the list yet, I can't tell you who's on the list.",
#  'My whole body aches.',
#  "I didn't call him because I had a cold.",
#  "It's impossible, Tom told me.",
#  'Antony died on November 6th, 1620, and was buried in the church of Carew on November 7th.',
#  "People shouldn't abuse animals.",
#  'The constituency is located in South Wales, and is located on the right bank of the River Afan near the mouth in Swansea Bay.',
#  "Mechanical noise effects on the device are negligible on the device, and it is critical to establish the Quantum Oscillator's thermal regime.",
#  'Why is Tom not eating?',
#  'Victoria S. Bull (" Victor") was born in 2001 as Vicki\'s sister, but she has been unemployed for many years.',
#  'Believe what you want.',
#  'At the junction of the Mangalore and Shepparton lines, the former station North East was located north of Seymour.',
#  'Would you like me to stay?',
#  "Why don't you wear some clothes on?",
#  "I think it's a good idea.",
#  'Last winter, I met her.',
#  'The San Jose, California campus was relocated to Milpitas, California, in 2016.',
#  'Tom lives outside the city.',
#  "He'd already decided to propose to her at a long time.",
#  "I've forgotten my PIN number!",
#  'On April 10, 1562, a copy of the letter arrived in Montpellier.',
#  "Bill Malina's additional mixing was carried out by him, with support from Rice and Ghazi Hourani.",
#  'The residents had screamed over the noise.',
#  'I have no one to blame but myself.',
#  'She has a heart disease.',
#  "Isn't Tom stuck up?",
#  "You can't eat the money.",
#  'China 1843 - After a confrontation between Americans and Chinese, sailors and Marines from St. Louis were landed at the Canton trading station.',
#  'Some people take a bath every day, while others do not.',
#  'Is it likely that you will be back tomorrow?',
#  "The Werris Creek to North Star line's responsibility was transferred from the Country Rail Infrastructure Authority to the ARTC in July 2011.",
#  'Only six episodes from the third and fourth series survived, two from the first and one from the second, and one from the final series.',
#  "Tom isn't afraid of spiders.",
#  'He did what he could for his children.',
#  'The JieT is a tributary of the River Slivei in Romania.',
#  "Tom hasn't been banned yet.",
#  'The heart of a man is nourished by wine.',
#  'He was not dissatisfied.',
#  'This will be the best ever.',
#  'On July 30th, 2008, the beta version of the Windows Live FrameIt service was released.',
#  'We just need a little time.',
#  'The school is affiliated with the secondary school of the autistic school Ysgol Plas Brondyfryn, which was built in 2003.',
#  'The botanist Aaron Davis and the gardeners John Grimshaw and Matt Bishop are among the authors of the works on which these notes are based.',
#  'No other breed is bigger than this one.',
#  "I'll be taking Tom's place.",
#  'I have enough funds to buy a car.',
#  'I tried to escape.',
#  'Mudzuri defeated ZANU-PF candidate Amos Midzi in the March 2002 mayoral election by a wide margin, receiving 262,275 votes against 56,796 votes for Midzi.',
#  'I did the job against my will.',
#  "Let's discuss the subject.",
#  'Buccinum parvulum is a species of sea snail, a true gastropod mollusk in the Buccinidae family, and it is a species of whelks marine.',
#  'What kind of songs are in fashion these days?',
#  'Is he swimming?',
#  'Tom may be confused.',
#  'The author turned the fairy tale into our mother tongue.',
#  'In 2006 in San Francisco, where the tournament had been held for two years, it was revived.',
#  'What a stunning spot!',
#  'How did the two of you meet?',
#  'Kathy Lloyd was born in Carrickfergus, Northern Ireland, and she grew up in Netherton, Bootle, where she attended the Warwick Bolam High School.',
#  'Tom wanted to join us.',
#  'Tom will try it out.',
#  'After the dog, I saw a cat running after it.',
#  'It was first recorded by Irma Thomas in November 1961 and was produced by Allen Toussaint.',
#  'Tom is asleep, as well as Tom.',
#  '" Darn That Dream" is a common song with music by Eddie DeLange and lyrics by Jimmy Van Heusen, which was released in 1939.',
#  'How can we get home?',
#  'I accept your plan.',
#  "Isn't Tom trepid, isn't he?",
#  'Maughan and his wife, Lorraine Hannemann of Manhattan, New York, live in Honolulu, Hawaii.',
#  'I have hard stools.',
#  'I found out something.',
#  'She is worried about her health.',
#  'Humor me.',
#  "The corps was taken out of the First Army and placed in Omar Bradley's Third Army two weeks before the invasion.",
#  'The olivella kifos is a species of dwarf mollusk in the Olivellidae family, similar to the navy olives.',
#  "I'm considering moving to the majors.",
#  'Tom must have had his reasons.',
#  "Who'd have predicted this?",
#  'He came from Serbian ajkai in Komárom in 1739 as a renowned speaker ( "slavni propovednik") during religious persecutions.',
#  'In various countries, the car was sold with different names.',
#  'Yesterday, I went to see the movies.',
#  "Raumanga is a suburb of Raumanga in New Zealand's Northland region. Northland Polytechnic's main campus is located in Whangarei.",
#  'Is there a supermarket near here?',
#  'Owen Bradley has released " Thank Schoen" from her 1964 album " By Request," which was produced by Brenda Lee.',
#  "The loyalists had camped on the west side of the Catawba River, while General Charles Cornwalli's army camped on the east side.",
#  'Back Street was a 1961 film directed by Universal Pictures, produced by David Miller and Ross Hunter.',
#  'What is your field of expertise?',
#  'In the school case, Danielle, Nadine, and Mark have seen their pictures.',
#  "Bas 90's development began in the 1970s and was fully operational in the 1980s.",
#  'It has greatly improved over what it was like before.',
#  "His son's death was a shocking shock.",
#  'It is exclusive to Yunnan and its tributaries in Lake Dianchi, China.',
#  'I saw that it snowed for four days from the 14th to the 17th in the first month of the year.',
#  'She gave him all the money she had.',
#  'He will not be released.',
#  'A Police Authority for the British Transport Police was established on July 1, 2004.',
#  'Scouting in Malaysia (now YMCA) was first introduced in 1908 as an experimental troop in Penang before it spread throughout the peninsula.',
#  'Suzuki Beane is a humor book published in 1961 by Louise Fitzhugh and illustrated by Sandra Scoppettone.',
#  'I need you for a second.',
#  "I'm no longer your tutor.",
#  'The teams finish second in the pools, the first places from the other pool.',
#  'Mount Sis is also a plateau in Turkey that has been dubbed " Sis Da Yaylas."',
#  "What don't you get?",
#  "Doesn't Mary look pretty?",
#  "Shimla is a major suburb of Sanjauli, India's Shimla district.",
#  'Cassandra Peterson appeared in "All About the Evil" of Peaches Christ with Patrick Bristow, Mink Stole, and Brown.',
#  'The Presbyterian doctrine has been "reformed," according to the government, and the government is "theological."',
#  'I think she likes him.',
#  'The windows should have been washed by now.',
#  'Please allow me to drive your latest Toyota.',
#  "In Khotang District of eastern Nepal's Sagarmatha Zone, Linkuwa Pokhari is a member of the village and Village Development Committee.",
#  "I haven't finished reading this book.",
#  "Let's play soccer.",
#  'I love your eyes!',
#  "Tom hasn't been caught yet.",
#  'It was predictable.',
#  'He fractured his left wrist.',
#  'In Acquire and Sackson, 3M decided to change the name.',
#  'He has not been interested in the ruse scheme, to my knowledge.',
#  "He repaired the table's legs.",
#  "I think it's inevitable.",
#  "I'm here because you're the reason.",
#  "You're going nowhere.",
#  'According to the US Census Bureau, the county has a total area, of which land and ( 17.6 percent) are water.',
#  "I was involved in Emperor Matthias' coronation in 1612 and his election of Emperor Ferdinand in 1619.",
#  'Jules de Blosseville drew the mountain after French naval officer Marie Henri Daniel Gauthier comte de Rigny (1782-1835) comte de Rigny.',
#  'He died before his arrival.',
#  'I have some time.',
#  "I'm not sure why I'm so ill.",
#  'Salina is regarded as the Grand Island (of Nebraska) of the south by the Louis and Clarke Adventures.',
#  'Esperanto is a fun word to learn.',
#  '" Pueraria montana" is growing in several regions of Switzerland and Italy near Lake Maggiore and Lake Lugano.',
#  'Layla paid for the taxi.',
#  'On campus, there are several student organizations, religious organisations, and student involvement clubs.',
#  'The group now has thirty members.',
#  'Michael Chang won the final 3 — 6 — 3 — 5 against Renzo Furlan.',
#  'What is your favorite music?',
#  'The film was a lot better than I expected it to be.',
#  'During Lent, my friend fasts.',
#  'The Lielplatone parish is an administrative unit of the Jelgava Municipality (before the 2009 legislative reforms, the Jelgava District was a separate entity). Latvia.',
#  'He crept into the castle town disguised as a peasant.',
#  "Agha Mohammad Khan, his brother, was appointed Qoyunlu's new chieftain due to his castration.",
#  'He works with me at the office.',
#  'He was educated in Dresden, Leipzig, later in 1865, and after a short stay in Weimar, he and Franz Liszt moved to New York in 1869.',
#  'Only the Sara of the south was ruled effectively; the French presence in the Islamic north and east was negligible.',
#  'That could be serious.',
#  'I seem to have a fever.',
#  'Ernst Peter Maag (Peter Maag) (ten May 1919 – 16 April 2001) was a Swiss conductor.',
#  'These articles are all exempt from service.',
#  'At Waterloo, the French were defeated.',
#  'She lost 50-25 to Zimbabwe, 84-16 to Tanzania, and 58-24 to South Africa during the tournament.',
#  "I hope this doesn't happen again.",
#  'Both Tom and Mary are dissatisfied.',
#  'Martha married George I. Eisenhauer after Anna was discovered.',
#  'I dug one up.',
#  "Barwa Addax driver Josef Král was replaced by Dani Clos in the week leading up to the first race, while Ocean Racing Technology's Jon Lancaster was also replaced.",
#  "Tom doesn't think you should've done that.",
#  'My employees must be treated with absolute loyalty.',
#  'The children are in need of you.',
#  'Please call Tom Mary.',
#  "I can't believe I'm hearing this.",
#  'She is a good deal older than he is.',
#  'I heard you did that.',
#  'The A cells produce glucagon, which mobilizes the hepatic glycogen, and serotonin is produced by the enterochromaffin cells, which promotes the contraction of the smooth muscles.',
#  'They had a neighborhood allies, including the collopys (Brian Collopy and Phillip Collopy).',
#  'She was in no mood for lunch.',
#  'I was under the assumption that Tom was going to break the deal.',
#  "People aren't always rational.",
#  "I can't drive because my father doesn't allow me to drive.",
#  'Tom said he would not be able to sing.',
#  'The first freefall (intamin) and the first drop tower were also sold by Giovanola.',
#  'The provincial B.J., Vorster Hospital, a public library, and a Lutheran mission museum are among the medical and pharmaceutical establishments in or near Kareedouw.',
#  'Wright, a British consul general for the republic of the Seven Islands (Ionian Islands), appeared from 1800 to 2004.',
#  'However, a potential protocol for the use of specific flow control signals must be followed in order to prevent such deadlock situations.',
#  'Are you happy with the result?',
#  "Aenetus blackburnii (Blackburn's ghost moth) is a moth of the Hepialidae family, which is spread from Australia, where it is widely distributed.",
#  'What brought it in your head to arrive here now?',
#  'As spring arrived, the snow melted away.',
#  'I had never seen such a thrilling rugby match as one I saw yesterday.',
#  'Italy qualified for the 2009 European Baseball Championship from the 2007 series.',
#  'How did you like the party?',
#  "I've got to get it fixed.",
#  "We'll carry you.",
#  'Our roof was blown off.',
#  'In the state, one individual was killed by the hurricane indirectly and two others were killed in a flash.',
#  "You're worth gold.",
#  'Tom has already had his lunch.',
#  'Why is everyone screaming?',
#  'I no longer have to wear glasses.',
#  'Jarymowycz, a lecturer at the Royal Military College, was a regular author of letters to the editor.',
#  'Born in Gosforth, Northumberland, as a child, he moved south to the Wiseton Estate near Retford, Nottinghamshire, where his father found work there.',
#  'Tom listened with a keen interest.',
#  "She doesn't pay much attention to how she dresses.",
#  'This is not a good sign.',
#  'Albert Pyun, a former Cannon, was brought on board and began working with the Tolkin script, which had originated at Cannon.',
#  'He died in Trenton on July 23rd, 1942 and is buried at the Old Broad Street Presbyterian Church and Cemetery in Bridgeton.',
#  "I know what you're planning.",
#  "Tom isn't going to be able to help us today.",
#  'The Messent Peak and the Brodie Peak are among the Brist Peaks on the Bristly Peaks.',
#  'Barbara Kwarc, nicknamed Barbara Kwarc (born June 19th, 1953), is a Polish actress, comedian, and actress.',
#  'In the 1990s, new teaching centers were established in Ivrea, Mondove, Biella, Alessandria, and Vercelli.',
#  'The original Barron Collier Bridge in 1931 was replaced by the original Barron Collier Bridge, followed by the new Barron Collier Bridge and the Gilchrist Bridge, which crossed the Peace River.',
#  'Webmention was first released in the IndieWebCamp community and was released as a W3C work draft on January 12, 2016.',
#  'Pedro, along with many other children in the custody of a man named Sebastian, died soon.',
#  "I don't mind if you stayed here.",
#  'They account for 13 percent of the population of Klaipda, with 28 percent in Vilnius.',
#  "Tom's heart was broken.",
#  'Kate is a natural performer.',
#  'I may be able to assist.',
#  'The car is parked at the gate.',
#  "Jimmy Webb's work was also inspired by the scheme later in life, according to reports.",
#  'The tour was led by a tour guide.',
#  "The Hurd Peninsula is sandwiched between South Bay and False Bay on the south coast of Livingston Island, Antarctica's South Shetland Islands.",
#  'Tom and Mary are no longer children.',
#  'Be sure not to offend Tom.',
#  "I'm not that inebriated.",
#  'We are not cowards.',
#  "I don't want to meet with him again.",
#  'Last Sunday, I was able to be free.',
#  'Describe your daily life.',
#  'He and his partner Lucy and their children live in Noah and Mabel.',
#  'Tom got it wrong.',
#  "She's a tease.",
#  'She needs someone to help her.',
#  'It was a hot night.',
#  'Asbestos substitutes now include ceramic, carbon, metal, and aramid fibers, such as Twaron or Kevlar.',
#  'You seem to be drained.',
#  'It would be difficult to work.',
#  'They screamed because they were afraid.',
#  "Corozal is a town and municipality in northern Colombia's Sucre department.",
#  "I didn't know him.",
#  'I started to cry too.',
#  'The wind is strong.',
#  'I can accept that.',
#  'I am thirsty, so please give me something cold to drink.',
#  'Maria Maria Vittoria Rossa Argento (born September 20th, 1975 in Aria Asia Argento) is an Italian actress, singer, model, and film producer.',
#  "I'll be in touch with you shortly.",
#  "His old clunker isn't worth anything.",
#  'The condensive Greek text forms the basis of the condensive New Testament, which is more idiomatic in its English than in its hyperliteral Subscription.',
#  'Kendra Saunders is now a 100 percent Hawkgirl.',
#  "Tom is persistent, isn't he?",
#  "Tom's father walked out on his family.",
#  'What is it really about?',
#  'We have to do this together.',
#  'The weather became colder after a string of warm days.',
#  "Let's see them.",
#  'Tom wanted to know the cause of the accident.',
#  'The title and lyrics refer to Leonardo da Vinci\'s renaissance portrait " Mona Lisa."',
#  'She went to Russia, Finland, Italy, France, Scotland, Scotland, Estonia, Germany, and Iceland in 1923.',
#  'No comment was made.',
#  "Tom had no trouble finding Mary's house.",
#  "We're finally alone.",
#  'Mary was mistakenly told that she had been mistaken.',
#  'You have to work.',
#  '" Purple Clover" describes the website as being for people who are "still cool, still curious, and still crazy after all these years.',
#  "Herbie Matthews' son, who later competed with South Melbourne, received a Brownlow Medal and his grandson of the same name later played with South Melbourne.",
#  'I promise you that I will never do that again.',
#  'Mike Parlett (also known as Michael J. Parlett) is an English jazz saxophonist and radio moderator.',
#  'Tom was very convincing.',
#  'I was trying to find Tom.',
#  'Carl Smestad (May 8th, 1888 - June 29th, 1962) was a Norwegian industrialist, son of Reidar Smestad and grandson of Jacob Olssn Smestad.',
#  'On the examining table, lie on the examination table.',
#  "Let's go for a cup of coffee.",
#  'Tom has a lot of books.',
#  'According to a new survey, the average life span of the Japanese is still increasing.',
#  "I don't want to lie to them.",
#  'Both Tom and Mary want it.',
#  'You made a good decision.',
#  'The Valea Voenilor River is a tributary of the Pascu River.',
#  "If you ask Tom if he'll do it, he'll do it.",
#  'Taft served as Chief Justice until his death in 1921, when he was replaced by White.',
#  'They are related to each other.',
#  'William de Middleton (or William Middleton, whose death occurred on August 1 or September 1288) was a medieval Bishop of Norwich.',
#  'Tom and Mary kept their personal information from their parents.',
#  'No passengers were hurt.',
#  "Mum's the word.",
#  'The following table compares the results of the LOD - capable rendering and a brute - detail technique (full force).',
#  'He is senior to me by two years.',
#  "The first railway workshops in the Wellington area were located near Pipitea Point, Wellington's first railway station.",
#  'She burst into tears as she heard the news.',
#  "It's impossible to quit smoking.",
#  'The latest tablet runs on an arm and a leg.',
#  'Tom died in Boston in 2013.',
#  'Mount Cobb is a mountain on Vancouver Island, British Columbia, Canada, east of Gold River and southwest of Mount Filberg.',
#  'Only one percent of natural diamonds are of this sort, and the majority of them are of the blue to gray variety.',
#  'He is the tallest in our class.',
#  'If you like, you can come.',
#  'Tom woke up and went away.',
#  'Mr Wilson is furious with Dennis.',
#  'On Spike TV, SAP announced George X and Manny Rodriguez as the SpikeTV Spanish commentators for Premier Boxing Champions in 2015.',
#  'He played for the San Diego Sockers in 2009, and he was a member of the Professional Arena Soccer League.',
#  "They'll laugh, according to them.",
#  'This is the real issue.',
#  'Bill brought me the book.',
#  '"Do I hear wedding bells?" I asked them on a date.',
#  'Franz Ferdinand\'s last words, as Count Harrach recalled, were " Sophie, Sophie."',
#  "He's been dead for ten years.",
#  "Based on Model Checking for Computation Tree Logic's concepts, Infer also has a domain abstract language for specific syntax tree linting.",
#  'Pérez also worked with Telemundo, where she anchored and produced an entertainment segment for Telemundo Internacional.',
#  'It is also home to the unincorporated towns of Redwood Valley, Calpella, Potter Valley, and Talmage.',
#  "Don't upset the others.",
#  'Ardning is a municipality in the Austrian province of Liezen.',
#  'Popeye was his dog when he was born.',
#  'The potassium salt is isostructural with a simple structure.',
#  "French troops under General Zoller's command from 22 December 1813 to 14 April 1814, the fortress was once more besieged before the Bavarian garrison capitulated.",
#  'The agony was agonizing.',
#  '"AllMusic" actress Eduardo Rivadavia called " Restless and Wild" with 4.5 of 5 actors and praised it as a "creative breakthrough."',
#  'Lucas is a nifty clog.',
#  'I adore your city.',
#  'Tom stayed seated.',
#  'The 1988 National Basketball Association was the 43rd NBA season.',
#  "You're an expert at this.",
#  'Hopewell, Charles City County, Virginia, also known as Shirley Hundred Island, is an island and a historic home and archaeological site located near Eppes Island, Virginia.',
#  "I'd like to try on this dress.",
#  "We're working hard.",
#  'How can this be over?',
#  'This is unusual.',
#  'Wajahat Attre, a musician, produced the music, with lyrics by Noor Jehan, and Mehnaz and sung by Hazin Qadri.',
#  'The Final FESPIC Games featured 18 venues in Selangor, 7 in Kuala Lumpur, and 1 in Putrajaya and Negeri Sembilan respectively.',
#  'The dull hexagonal tiling of the single plane has a hyperbolic tiling, which is Schläfli - the symbol of sr ( 6,6 ).',
#  'I made it.',
#  "She's conceived that it's quite normal for teenagers aged 13 to 19.",
#  "Yes, I can, but I can't really speak Shanghainese.",
#  'This is war.',
#  'Where did you park the car?',
#  'He wanted it.',
#  'He was based in Harrogate, North Yorkshire, from 1996 to 1999 after completing his university studies at Cardiff University and Rouen, France.',
#  'Henry Wheeler Shaw (1818-1885) became a well-known humorist under the pen name Josh Billings.',
#  'He also appeared in 53 games for the Piedmont League (Greensboro Patriots) with a 26- 19 record over the course of the seasons 1928 to 1929.',
#  "They said they weren't busy.",
#  'Go upstairs and go to bed.',
#  'It took me by surprise.',
#  'Each line has three points, so the Hesse configuration has the notation 912 in the language of configurations.',
#  "I'm calling from Tom's cell phone.",
#  'Tom sat quietly.',
#  'I should have warned someone.',
#  "Tom is trustworthy, isn't he?",
#  "I can't raise our children by myself.",
#  'I went there yesterday.',
#  'I want her to win.',
#  'Matter can be solid, gaseous, or liquid.',
#  'It is about 4 miles east of Caernarfon, 7 miles south of Bangor, and 3 miles northwest of Llanberis.',
#  'It is located in Beverly Hills, California, at 142 South Rexford Drive, opposite the First Church of Christ, Scientists.',
#  'Mid Wales Hospital, originally the Brecon and Radnor Joint Counties Lunatic Asylum, was a psychiatric hospital in Talgarth, Wales.',
#  'Stephen D Reicher (Stephen D Reicher) is a Professor of Social Psychology and former Head of the School of Psychology at the University of St Andrews.',
#  'At that time, Tom was thirty years old.',
#  'The interpreter gives her personal interpretation.',
#  'He just left.',
#  "He's lost all of his possessions.",
#  'He begged that I pay the money back at once.',
#  'He is a poet by birth.',
#  'He is a Baroque music and contemporary music specialist.',
#  'In the first week of March 2011, the Finnish album " Deathstar Rising" debuted in the top ten and climbed to #8 in the first week.',
#  'Tom will explain.',
#  'I am not happy with the end result at all.',
#  'It is likely that he will win the speech competition.',
#  "Wendy, I'd like to meet my brother Sam.",
#  "I'll never be able to play again.",
#  "The National Audubon Society's Hog Island chapter has a center and camp.",
#  "They had a dream that they'd arrived.",
#  "I've seen you somewhere.",
#  "By 2:30, you're supposed to be here by 2:30.",
#  'English is a basic language that is straightforward to learn.',
#  'This is unfortunate.',
#  'She unwraps her birthday gift.',
#  'Spencer Machacek was traded by the Penguins to the Columbus Blue Jackets in exchange for Thompson on February 6th, 2014.',
#  '"Myles C. Fox" arrived in Yokosuka on September 23rd and departed San Diego on October 8.',
#  "Yea, that's all it is.",
#  'He said he was going to be late.',
#  "The Earls of Mornington's residence in Dublin was located in Mornington House during the Dublin social season.",
#  "The Astors settled in North America, first appearing in Germany in the 18th century with John Jacob Astor, one of the world's richest people.",
#  'In 2013, signed beals for ABC\'s main role, Drama - Pilot "Westside," which was developed by McG and produced by Ilene Chaiken.',
#  'I did that, which she begged me to do.',
#  'I love to watch a baseball game.',
#  'Can I stay and help?',
#  'There are no relatives of the poor man.',
#  'The high winds were blowing.',
#  'Tom nodded his head and left.',
#  'Insatiably cynical.',
#  "I've got a famous singer's autograph.",
#  "Chabrian Jattan is a village in Mirpur Tehsil, Pakistan's Mirpur District.",
#  'He was thirsty, according to him.',
#  "Don't fuck it up!",
#  "I'm completely unaware of the scheme.",
#  'The dead body was surrounded by vultures.',
#  'Tom seems to be having a good time.',
#  'The official language in Bhojpuri is Bhojpuri, while the local language is Hindi.',
#  "He's a fake.",
#  "So you don't know what Esperanto is?",
#  'Are you afraid of ghosts?',
#  'Lilly will be on the World Curling Tour for her first season with new teammates Sarah Potts, Oye-Sem Won Briand, and Tirzah Keffer.',
#  'Mary would not win, Tom knew it would not win.',
#  'According to a newspaper article that details the case, "the library is a dream in architectural appearance and a model in interior."',
#  "She was Philander Montague Wright's second daughter and the youngest of four children born of him and his partner, Mary Weeks (Bracket ) Wright.",
#  "When you ask him if he's here, he says no.",
#  'I want his head.',
#  'Regardless of how complicated the RC network becomes, the open circuit time linear procedure yields the same result in " j."',
#  "We've already tried it.",
#  'Dehgh (also romanized as Dehgh) is a village in Bojnord County, Iran, located in the Badranlu Rural District of Central District.',
#  'In London, Jones, his son Nathan, and his three children, Ella, Coral, and Holly are among his three children.',
#  "Don't pass up a good opportunity.",
#  'The film is really interesting.',
#  "We've finally arrived at the summit.",
#  "Last night, I didn't get a wink of sleep.",
#  "This isn't the last train, is it?",
#  "You can't wait until the cows return home.",
#  'Have you ever seen a red river?',
#  'The Portuguese Portuguese Portuguese are quite different from the Portuguese ones.',
#  'The magazine was based in Paris but Gerald Duckworth and Company in London had it published.',
#  'Lepel had lost its strategic and economic importance in 1913 and was a quiet regional center.',
#  'We may not have guessed.',
#  'Thomas Thomas was the youngest child of the farmers Fred and Elizabeth Goodwill.',
#  'Tom will probably weep.',
#  'These enzymes are capable of enantioselective oxidation of prochiral substrates.',
#  "Don't put me in the middle of this.",
#  "I've never said that!",
#  'We were told by Tom that we should leave.',
#  'Mary is the luest of her classmates.',
#  'He reassured me.',
#  "I've done nothing extraordinary.",
#  'How long does it take to the train station by taxi?',
#  'I walked alone.',
#  'When it is boiled, water turns to steam.',
#  'Tom turned off the lights.',
#  "I'm so excited to visit VNU.",
#  'Tom seems wealthy.',
#  'These allegations are untrue.',
#  'She attempted suicide.',
#  "They aren't here.",
#  'I suspect I was followed by someone.',
#  "I'm about to die.",
#  'Dragan Umievi (born October 9th, 1984) in Dubica, SFR Yugoslavia, is a Serbian ice hockey player of Swedish descent.',
#  'It was your fault, Tom.',
#  'I just brush it off.',
#  "You should've followed Tom's instructions.",
#  'Get on your horse.',
#  'I have a sharp knife.',
#  'Hopkins spent six months with the band in Japan, the United States, and England.',
#  'Simon Brook is the son of director Peter Brook and actress Natasha Parry, and his sister, actress and writer Irina Brook, is the actress and author Irina Brook.',
#  'I wonder if Tom is content.',
#  'Valkyrie beat Amazing Kong, Mia Yim, Christina von Eerie, and Angelina Love in an eight-man team match at " Shine 8."',
#  'Political parties are often political parties in most European countries, and they are legitimate organisations.',
#  'Margot A. Thien (born December 29th, 1971 in San Diego, California) is an American American swimmer competing in the synchronized swimming and Olympic championship.',
#  'The first recorded Irish presence in the area of present-day Newfoundland dates back to 1536, when Irish fishermen from Cork migrated to Canada.',
#  'The tire is worn down.',
#  'Is it to blame?',
#  'Look out for rock slides.',
#  'Susie J. Clarke married Brown in Ayer, Massachusetts, on December 30th, 1888.',
#  'Tom needs some assistance.',
#  'Tom Watson was supposed to defend his Middleweight Championship against Frank Trigg.',
#  'Tom will almost certainly be starving.',
#  'This dictionary was given to us by the instructor.',
#  'Everything is connected to everything.',
#  'A lot of Tom was worried about Mary.',
#  'In Havana, the Boston Red Sox and Cincinnati Reds played another series.',
#  "I'm glad no one is around.",
#  'The combined singular route now connects Gothenburg, Norway, to Newcastle, leading directly from Gothenburg via Kristiansand.',
#  'I was at a movie theater.',
#  'This process is the photographic equivalent of a cylindrical map projection in cartography.',
#  'I remember that I once met the queen.',
#  'Did you kiss him?',
#  'I had no idea that you were coming.',
#  'It was driving me insane.',
#  'The new grammar school was named the Upper School, while the old building became the Lower School.',
#  'This kind of mistake is impossible to overlook.',
#  'Mary is a mystery to both Tom and I.',
#  'Something strange happened.',
#  'Tom looked straight at me.',
#  'The anchors, Jessica Soho and Mike Enriquez of GMA News and John Nery, editor of "Inquirer.net," led this discussion.',
#  "I'll sing.",
#  "Dennis is arrested and sentenced to die with Hugh and Barnaby. Barnaby is pardoned despite Gabriel Varden's efforts.",
#  'The Slănic River in Romania is a tributary of the River Comina.',
#  "Nonetheless, I'm extremely proud.",
#  'Mioviovi was in Sweden, where he was involved in organised crime prior to his arrival in Serbia in 2002, and he left the country to prevent arrest.',
#  "I'll answer you tomorrow.",
#  'Tom says he is not interested in romance.',
#  'Some writers divide the species into two groups, naming the Russian and central Asian populations as " Fallopia aubertii" and the Chinese species as " F. baldschuanica."',
#  'My bike was stolen.',
#  "I haven't seen him in days.",
#  'Tom took a seat across from Mary.',
#  'Were you able to get everything you need?',
#  'Tom says he did nothing wrong.',
#  'Due to the rain, the trip was postponed.',
#  "The Bearcats' old jersey is similar to that of the Florida Panthers of the NHL.",
#  'I can walk to school in ten minutes.',
#  'Emu Park was also the crossroads of Central Western Line and the Rockhampton line.',
#  'They stayed up all night talking about it.',
#  'You should buy him new toys.',
#  'Hugues Merle died in Paris in 1881, but his son Georges Merle became a painter as well.',
#  'Vermont South is bordered by Mitcham, Nunawading and Forest Hill to the west, and Ringwood to the east, and Wantirna and Ringwood are the southern Vermonts.',
#  'Espuelas worked on the Wunderman, General Foods Gevalia, and Weight Watchers accounts while at American Express.',
#  'They danced.',
#  'You seemed to be curious.',
#  "I'm not sure what it is.",
#  'Edward Everett, a scholar from America, moved from America to Constantinople in 1819, as well as six other manuscripts (Lectionary 296, Lectionary 298, Lectionary 298).',
#  'Prodrive revealed in February 2017 that they would compete in the FIA - Rallycross World Championship in 2018 with a Renault Mégane for Guerlain Chicherit.',
#  "I'm going to need some.",
#  'Is there a room of your own?',
#  'Tom told me something.',
#  'I like coffee more than tea.',
#  "Don't forget the death.",
#  "Tom didn't appear to be too positive about his decision.",
#  "I'd never do something like that.",
#  '"Acting for "has the same basic meaning as "acting," except that it indicates that the original occupant of the position is still officially holding office.',
#  'I keep getting spam emails.',
#  'Mike Roberts wrote the series and Matt Mariska and Andy Sipes wrote it.',
#  'Can I do anything?',
#  'While watching television, I fell asleep.',
#  'The Viennese ice revue toured through most European countries, including Germany, Italy, Switzerland, Hungary, Czechoslovakia, Czechoslovakia, Belgium, France, and Spain.',
#  'Both Tom and I are scholars.',
#  'Percy W. Adams married Gwendoline Wright.',
#  'Hatherley joined KT Tunstall in 2010, playing lead guitar and replacing Sam Lewis.',
#  'Drew Springer, Jr., a businessman from Muenster, Young County, has been representing Cooke County in the Texas House of Representatives since January 2013.',
#  'He applied for membership in the riding club.',
#  'He is quite correct, as a matter of fact.',
#  'By then, three-quarters of the slaves in Maryland had been released, and a large number of slaves in Delaware had been freed.',
#  'Last night, there was a full moon.',
#  "I'm not positive Tom will be able to do so.",
#  "Sami didn't say anything.",
#  'Where are my boots?',
#  "I'm on vacation.",
#  'Will you have some tea with me?',
#  'Alejandro Lerner wrote all songs except for Graham Russell\'s "A Place Where We Belong."',
#  'Milk is a refreshing drink.',
#  'Is Tom partially to blame?',
#  'I arrived early in order to guarantee a good seat.',
#  'Essentially, there are four main types of databases: curated databases, predictive databases, literature databases, and integrative databases.',
#  'Has anyone found him yet?',
#  'This was the first time since 1976 that New Jersey did not vote for the same candidate as the neighboring Pennsylvania.',
#  "You should've done it better.",
#  'There were no flowers or trees on the streets of his town.',
#  'How does she bring up her children?',
#  "You're conscient.",
#  'After studying in Shanghai, he sailed to Belfast in 1933 in order to join his parents.',
#  'When the card was read into the vehicle, it was inserted into the accumulator.',
#  'Males in Dyadic natural males do not have the anatomy required for human embryonic and foetal development.',
#  "Somebody must've followed us here.",
#  'The Nvidia TITAN V vs. NVIDIA officially announced the Nvidia TITAN V on December 7th, 2017.',
#  'Why should I study French?',
#  'Tom died suddenly.',
#  'Both her parents died.',
#  "Valerin's castle is confiscated, he is killed, and the queen is released.",
#  'Tom will almost certainly be up.',
#  'Thomas Edward Donne (1860-1945) was a New Zealand civil servant, author, fine hunter, and collector of Maori antiquities and New Zealand recreational art.',
#  "They're bored, according to them.",
#  'Hold me in your arms.',
#  'Joe was born in Somerville, Massachusetts, on March 27th, 1929, and he grew up in Quincy, Massachusetts.',
#  'This is stunning.',
#  "Tom and Mary aren't mad, according to them.",
#  "Mahoning Creek is a tributary of the Lehigh River in Pennsylvania's Schuylkill and Carbon - County.",
#  "He's Austrian.",
#  'Aside from the terror, she was not hurt.',
#  "I'm sorry that I pulled you into this.",
#  "The white males' pterostigmata is almost immature.",
#  'Tom is having trouble getting to the end of the meeting.',
#  'Is it possible to drink beer?',
#  'He is hungry for success.',
#  'He was the son of Shmuel Binyamin Sofer (\' Moses Sofer ) and grandson of Ksav Sofer (the " Chasam Sofer ).',
#  "Tom should've waited for me.",
#  'I heard him cries.',
#  'She is a more effective leader than he is.',
#  'Tom works there.',
#  '" Robbers" is an English rock band\'s fourth album and their sixth single from their self-titled debut on May 26, 2014.',
#  'The Samata Express train in New Delhi runs between Visakhapatnam and Hazrat Nizamuddin and is operated by East Coast Railway.',
#  'There are flying birds in the sky.',
#  'Adult birds have white wing patches, a thin black bill, and red legs and feet.',
#  'That was a stupid question.',
#  "Something's happened to it.",
#  "I'll tell him you came by.",
#  'Natalia has been appointed as a conductor professor by the Royal College of Music, alongside Maestro Peter Stark.',
#  'Here is a map.',
#  "Silvio Berlusconi, the club's founder, and Phillippe Mexes, Kevin - Prince Boateng, and Mario Balotelli announced their resignation on May 25th, 2016.",
#  "Don't make sudden changes.",
#  'At this time, the theatre had not opened.',
#  "It is native to California and is found in eastern Madera County's central Sierra Nevada.",
#  "They didn't even know who they were supposed to meet.",
#  'I knew that I was content, so Tom knew it was happy.',
#  'The lake is three miles wide.',
#  "I'd be able to take the risk.",
#  'Parkway to Luton Airport is also connected by bus route A from Luton to Dunstable.',
#  'Tom has written several books.',
#  "It's simple to answer that question.",
#  "Chandra has started looking for a Jodi for Chandra, and talks about Meena's marriage have started, and Chandra has begun looking for a Jodi for Chandra.",
#  'It was a dissatisfaction.',
#  'Nothing is more enjoyable to me than to talk to him.',
#  "Tom isn't ready yet.",
#  'All doors are opened by a golden key.',
#  'One billion people speak English.',
#  "I see you've quit smoking.",
#  'People tend to think about behavior in one of two ways: the cause of situational causes or dispositional factors, according to Fritz Heider.',
#  "Stävlö, or Stäflö, is a castle in Sweden's municipality of Kalmar.",
#  'The characteristic function provides an alternative way to describe a random variable.',
#  "I'm very handsome, according to my mother.",
#  "Earthquakes are common in Peru, particularly in Arequipa, Peru's coastal area.",
#  'Tom ate my cookies.',
#  'Tom has a similar appearance to his father.',
#  "I won't tell anyone that I'm in Australia.",
#  'He is delightful.',
#  'The dividends have increased the overall "real" return on average equity to the double, which is about 3.2 percent.',
#  "It's pouring down rain.",
#  'The new stadium was built for four years, but it was inaugurated on August 21st, 1974.',
#  "I'm just a tourist.",
#  'Alexander Rigby, an English parliamentarian, bought the great old Plough of Lygonia patent in 1643, which covered the entire area, including Cape Elizabeth.',
#  'In a study by Drummond, winner effects were shown when established non-experienced chicks were placed against dominant chicks.',
#  "Last night, I went to bed at twelve o'clock.",
#  'Tadas Langaitis, a Lithuanian politician and member of the Seimas since November 2016, is a civic and civic activist who works in Lithuanian social and civic projects.',
#  'You are not in her league.',
#  "Tom doesn't smoke anymore.",
#  'Tom is sure to succeed.',
#  'Terry was born in Fairfax, Iowa, and died in Cedar Rapids, Iowa.',
#  "The constituency in Dunfermline East was one of Labour's most secure seats, like Scotland.",
#  'It was designed by Little Rock architect Harold A. Berry and Dallas, Texas Architect F. Eugene Withrow in international style.',
#  "Of course, Tom wasn't there.",
#  "I'm looking forward to hearing from you.",
#  'The CCV has miniature versions of famous historical buildings and structures, as well as local customs.',
#  'Tom answered the question correctly.',
#  'In rage, he barred the door.',
#  'Tom is considering doing it tomorrow.',
#  'I like coffee.',
#  "The stretch from Chiswick's western border to Syon Lane ( Gillette Corner ) is known as the Golden Mile, with several notable Art Deco shops included.",
#  'Tom seemed to be in good shape.',
#  'He and his parents returned to their parents.',
#  'Today is the fourth anniversary of my birth.',
#  'Union County is included in the Spartanburg, SC Metropolitan Statistical Area, which is also included in the Greenville — Spartanburg — Anderson, SC combined statistical area.',
#  "I've been following Tom all his life.",
#  "I'm not afraid of anything.",
#  "I've read all of those books.",
#  "We're going to have to do it.",
#  'He defeated Kakhaber Zhvania but lost the final to Andrey Balanov.',
#  "According to Robert of Torigni, Humphrey's mother was Duvelina, the niece of Gunnora, Duke of Normandy's concubine Richard I.",
#  'Tom no longer has to be concerned anymore.',
#  'Queen Victoria went from Gloucester to Swindon by train on September 29, 1849.',
#  'It is located on the historic Natchez Trace Parkway in Mississippi, USA, and is located on the new Natchez Trace, Mile 180.7.',
#  'Kittery Point is located in the Portland, South Portland, Maine Metropolitan Statistical Area.',
#  "I'm afraid you'll get lost.",
#  "Could you please lower your voice? I'm really hung over.",
#  "Let's get to the beer.",
#  "Colonel Ray died in 1989, and Lieutenant Colonel Koski died on New Year's Eve, 1989.",
#  'Hodges, as well as Green and Tom Jones, have all written by Syl Johnson, O.V. Wright.',
#  'Alternate.',
#  'I was so lonely.',
#  'You are either with us or against us.',
#  'Stephen Hendry won the title and defeated Peter Ebdon 9-8 in the final for the first time.',
#  "Both Tom's parents were teachers.",
#  'On July 7, 2009, Major General Nathan Mugisha was named as the head of AMISOM after Major General Francis Okello was fired.',
#  "You're a natural cook.",
#  'Bolivian President Robert August 2016 signed an agreement on August 4th, 2016 but not announced until February 4th, 2017.',
#  'Has she appeared?',
#  'You have no right to pass a verdict on these individuals.',
#  'Magda Lorne learns from her boss, Cholayna Ares, that a Terran operative, Alexis Anders, survived a plane crash in the Hellers a week earlier.',
#  'Give me a try.',
#  'Mount Morris Township is located in Ogle County, Illinois.',
#  'Archdale is a residential neighborhood in the Starmount (South Boulevard near Arrowood and South Charlotte).',
#  'Originally, the incident was not reported by the state-controlled Iranian media, but it was first reported by international media.',
#  'Somebody was assassinated.',
#  'Sleep is absolutely vital to health.',
#  'It is not a virus.',
#  'Elbow is too popular, according to him, although he believes that the writer should first prove himself.',
#  'TJ Trinidad, Biboy Ramirez, Eric Fructuos, Rico Robles, Joem Bascon, Jordan Hererra, Rico Barrera, and Michael Roy Jornales were among the participants.',
#  'We hope you enjoy your stay in Boston.',
#  "I haven't had anything to eat today.",
#  "Caspar David Friedrich was born in Greifswald, Pomerania, Sweden, on Germany's Baltic coast.",
#  'Lake Bordaglia is a lake in Forni Avoltri, province of Udine, Friulia, Italy.',
#  "I'm not sure if it's good or not.",
#  "Its approximate boundaries were from Pearl Street to Grier Avenue and South Broad Street to what is now US 1 '9.'",
#  'Tom is now doing well.',
#  "The Beliu River, or Agriş River, is a tributary of Romania's Botfei River.",
#  'We clear the futon in the morning.',
#  'She wept bitterly.',
#  "Despite the fact that the Maryland Department of Transportation is headquartered in Baltimore, three of the department's subordinate companies have their headquarters in Anne Arundel County.",
#  'Living in the town is quite different from life in the United States.',
#  'Most languages will have a "default constructor" if the programmer does not have a constructor for an instantiable class.',
#  'However, Turkish Prime Minister Ahmet Davutoglu argued that if the EU did not weaken visa conditions by June 2016, Turkey would not accept the EU-Turkey deal.',
#  'With Japanese government support, another new bridge was built in Phnom Penh on the Neak Leung to Ho Chi Minh Highway 1 and opened in 2015.',
#  'This morning, I met him early in the morning.',
#  'Please do not take these dishes out.',
#  'He appeared for the Brooklyn Dodgers in 1942 and the New York Giants from 1946 to 1948.',
#  'The Uchio River in Romania is a tributary of the Burduja River.',
#  'Tom had everything on his plate.',
#  'Carl Meissner\'s book "Prodromus Systematis Regni Vegetabilis" first described the species in 1856, based on James Drummond\'s collection.',
#  'The government of Qingyang County is based in Rongcheng, China.',
#  'He has worked on several international music campaigns, including the European "Freestyle" campaign for Nike, which has received numerous awards, as well as commercial videos.',
#  'As a Purim gift, I received a noisemaker.',
#  'Dave Denine, a provincial politician from Newfoundland and Labrador, Canada, who served as Minister of Intergovernmental Affairs from 2007 to 2011 in the former Canadian cabinet from 2007-2011.',
#  "Tom said he didn't feel anything.",
#  'Right, Tom is a tutor.',
#  'My friend lives in that house.',
#  'Tom will be there tomorrow.',
#  'Keep it private, please.',
#  'He was born and raised in Vancouver, British Columbia, Canada, and died in Aylesbury, Saskatchewan, Canada.',
#  "I haven't got anything to tell you.",
#  'Mary, Tom, likes to dance.',
#  "What is Tom's hair color?",
#  'Tell Tom how you feel.',
#  'We must help him right away.',
#  "They're outraged, according to them.",
#  'Micheál Martin, one of them, said that Fianna Fáil leader Shane Ross had called her the day before and that she would meet the following week.',
#  'To prevent future deadlock situations, a safe protocol for the use of such transmission flow control signals must be followed.',
#  'I asked everybody the same question.',
#  'They are talking to each other.',
#  'Mohsin Zaidi lived in Delhi for nearly four decades before settling in Lucknow after his retirement.',
#  'His invention is worthy of note.',
#  'In 1883, the first schools in the area were built for 400 black students and 60 white students.',
#  'Euacidalia brownsvillea is a member of the Geometridae family, and it is found in North America, including Texas and Hawaii.',
#  "If he'll be back, it's uncertain.",
#  'I am a Trojan horse, so I have infected your Mac with Trojan horses.',
# ...
#  "I'm all thumbs in the kitchen.",
#  'Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Paraphrasedoutput: Para',
#  'When he finished his career in Poland, he moved to Canada to join the Toronto Falcons of the National Soccer League.',
#  "He died in Munich and is buried in Ajaccio, Corsica's northern cemetery.",
#  "In deposit, you are expected to pay three months' rent.",
#  'Is there an appointment?',
#  'I hate flying.',
#  'Metin Üstünda, Bahadr Baruter, Erdil Yaşarolu, and Selçuk Erdem established it in 2002.',
#  'Both Tom and Mary are set.',
#  'Make notes.',
#  "Lester B. Faulkner served as a temporary chairman until George M. Beebe's appointment as president.",
#  'When he was growing up, our grandfather learned five languages.',
#  "She doesn't like to sing a sad song.",
#  "The audiogram's shape categorizes sudden high-frequency loss (sensor phenotype) or flat loss (strial phenotype ).",
#  "Lone Star Comics' three remaining stores in Plano, Hurst, and Mest sold off three of their five remaining stores in July 2013.",
#  'Zina Garrison and Sherwood Stewart were the defending champions, but they were disqualified in the second round to Jana Novotná and Jim Pugh.',
#  'If U18 beat Malmö FF U18 by 3 -- 0 — Djurgrdens if U18 beat Malmö FF U18.',
#  'This will be his car.',
#  "The film's soundtrack was written by Jeetenkumar Naorem and Tony Aheibam, and Raju Mikoncha wrote the text.",
#  'It was taken to Australia, where today is common in Queensland, the Northern Territory, and New South Wales.',
#  'Sarah Hendrickson (USA), Sara Takanashi (Japan), Coline Mattel ( France ), and Evelyn Insam ( Italy) were the favorites among the women.',
#  'We are not crazy.',
#  "On the Sydney Trains Network, Beverly Hills' railway station is located at the South Line Airport, with Riverwood in the west and Narwee in the east.",
#  "Davies had worked with Jomo Kenyatta and absorbed Harold Laski's socialist views at the LSE.",
#  "She said she couldn't speak French because she couldn't.",
#  'Mary is a yodeler.',
#  'Why is everyone afraid?',
#  'You can invite whomever you like.',
#  'Tom and I tied for the first time.',
#  'His acquaintance owns a grocery store in the United States.',
#  'Kumara Sambhavam is a 1969 Indian Malayalam and Tamil film directed and produced by P. Subramaniam.',
#  'Sami baptized his children.',
#  "Tom didn't know what was wrong.",
#  'He made the situation worse.',
#  'Examples of ceramics include white porcelain or white porcelain, enamel-blue underglaze, red underglaze, and iron underglaze.',
#  'Another match between the Cincinnati Reds and the Boston Red Sox was played in Havana.',
#  'He seems to be someone, but in reality he is not one.',
#  "He said he isn't busy.",
#  "Why don't you admit your mistake?",
#  "Parmigiani Fleurier, Manor, Heineken, Vaudoise, and UBS are the festival's key sponsors.",
#  "It's a hit among senior citizens.",
#  'Everyone was worried.',
#  'These earrings came from my grandmother.',
#  'Jack is more studious than Jack in our class.',
#  'This tree bears no fruit.',
#  'Sami was baptized.',
#  'His aspirations have no limits.',
#  "Dr. Carter has been in Africa for many months and works in Kem's AIDS clinic.",
#  "Next month, we're moving house.",
#  'I saw Tom hitting Mary.',
#  'The winner of each semi-final (Best of 3 ) qualified for the gold medal competition, while the other two drivers advanced to the bronze medal competition.',
#  'A medal was flown from Hawaii to Guam and was presented in the hospital.',
#  'Tom started whistling a tune.',
#  'Do you guys know each other?',
#  'Tom was all wrong.',
#  'The Penser Joch (2211 m) is a high mountain pass in Jaufenpass, northern Italy, just south of the South Tyrol.',
#  'Would you like to attend my party?',
#  'Scion was given 10,000 units of the 2013 model year (MY13) production in the United States, while Subaru was limited to only 6,000 units.',
#  'The troops had a slew of arms.',
#  'I never learned to swim.',
#  'From Vancouver Harbour Water Aerodrome and Nanaimo Harbour Water Aerodrome to Vancouver International Water Aerodrome, Baxter Aviation operated services.',
#  'A small stage and a small cast of 6 actors, as well as a solo violinist who is on stage throughout the performance, are all necessary for productions of the show.',
#  'Is this your first trip to the United States?',
#  'For example, 351 W 5th Avenue is on the south side of Fifth Avenue, about west of Fifth Avenue.',
#  'Without communication, there will be no progress.',
#  'My father used to say that time is precious.',
#  "I don't usually worry about people like him.",
#  'Jimmy Arias defeated Andre Agassi by 6 -- 2 — 2 — 2.',
#  'Tom has no idea what will happen.',
#  'Tom had intended to do it by himself.',
#  'My school grades were average.',
#  'They said they are busier than ever.',
#  'Any painter can hurt a painter.',
#  'How can you say the word "@" in your language?',
#  'The African stone tooling technologies are divided into modes, as Grahame Clark outlined by Lawrence Barham and Peter Mitchell in 1969.',
#  'Tom may not have done that.',
#  "We're eating apples.",
#  'Cozens was promoted Lieutenant-General in April 1944 and later appointed Assistant Chief to General Ronald Scobie.',
#  'Olaf K., Robert N., and Astrid M. founded it in 1998.',
#  'Put on a cheerful smile.',
#  'Mary Abbott was killed by Abbott.',
#  "We're going to do it tomorrow.",
#  "They predicted that they'd likely win.",
#  "I don't think Tom is occupied.",
#  "I'm trying to find my inner strength.",
#  "I'm not very good at speaking Arabic.",
#  '81 Republicans, 31 Democrats, and 8 Americans were elected to the Assembly for the 1857 session in November 1856.',
#  'Bhojpuri is the local dialect, and Hindi is the official language.',
#  'To board the bus, you must buy a ticket.',
#  "I'm calling my brother.",
#  "It's hogwash, according to me.",
#  'In the final 6 -- 2 — 4 — 4 — 4 — Anabel Medina Garrigues and Virginia Ruano Pascual defeated Eleni Daniilidou and Jasmin Wöhr.',
#  "I've never been so ill.",
#  'Along the coast of Ireland, there are nearly 2,000 islands, of which three quarters are uninhabited.',
#  'Allow me in under your umbrella.',
#  'If only I could now speak German fluently!',
#  'The dress transforms you.',
#  "Balkl is a village in the Turkish province of Gümüşhac, Turkey's province of Amasya.",
#  'The above test does not distinguish between more complicated distributions, such as quantum and classical, or between fermionic and bosonic statistics.',
#  'Tom is dying his hair.',
#  'A few years ago, it was unsuccessful once more, but it soon opened again.',
#  "I don't see any joy in it.",
#  'The arrival of the East Indians in Jamaica on May 13 was commemorated at the Old Harbour Bay.',
#  'The initiative was funded by Tracey Emin, Angus Fairhurst, Billy Childish, Jake Chapman, Billy Childish, Billy Childish, Billy Childish, Billy Childish, Billy Childish, Billy Childish, Billy Childish, and Joshua Compston.',
#  "It's simple to find friends, but it's much more difficult to keep them.",
#  'Tom had a few good ideas.',
#  'Good morning, Tom.',
#  'In 2003, a third album, this time on Dragonfly, was released.',
#  "Young girls' desire for slim figures is high.",
#  'Mary wore her wedding dress.',
#  "On Winter Island, the station was established by the British Falkland Islands Dependencies Survey in 1947 as Station F or Argentine Islands.'",
#  'He is best known for the creation of various origami models, including erotic instrumentalists, spiders, and intricate origami works titled " Pornigami ".',
#  'Have you been to somewhere lately?',
#  "We believe it to be the citizens' legitimate right to have public libraries.",
#  'He broke it in this window.',
#  "We didn't know him.",
#  "I'm taking him to the hospital.",
#  "It'll be all right, come on.",
#  'What did Tom look like?',
#  'Astrid M., Robert N., and Olaf K. founded the organization in 1998.',
#  'In 2006 in San Francisco, where the tournament had been held for two years, it was revived.',
#  'Tom is worried about this.',
#  'The team has competed in recent years, including Iowa, Rutgers, Hawaii, State of Mississippi, Nebraska, Syracuse, and Pittsburgh in 2011.',
#  'After an assault on the State of Zhao, troops from Qin and Chu joined forces to attack Wei in 235 BCE, but the attack was unsuccessful.',
#  'The whole body hurts me!',
#  "That's what counts.",
#  "Tom won't help me.",
#  'The students are now having recess.',
#  'In 1998, Rituparna Sengupta and Indrani Halder received the National Film Award for Best Actress for the film.',
#  "We're brothers.",
#  'The people are outraged.',
#  "Let's take a break from coffee.",
#  "Let's wait for the rain to stop.",
#  'In winter, the weather is moderately warm in winter and in summer, it is cold in the summer.',
#  'He was apprehended by the authorities.',
#  'I have to go alone.',
#  "Mercer was George Mercer's brother, John Francis Mercer, and the father of Charles Fenton Mercer.",
#  'Andrea Dovizioso stayed with Ducati for the 2015 season, with Andrea Iannone joining the factory team from a Pramac Ducati.',
#  'The SAS curve ( Surprise Aggregate Supply ) is a vertical line drawn on the EAS curve, which is long-term ( Equilibrium Aggregate Supply ).',
#  "Classic Hits Live, on August 12, 2003, Kottonmouth Kings' 3rd Compilation - Album, their 1st Live album and their 9th total album.",
#  'Stenolechia zelosaris is a moth of the family Gelechidae, which is discovered in Assam ( India).',
#  'Margaret Craske was born in Norfolk, England, on November 26, 1892, the daughter of Edmund and Hannah Craske.',
#  'He came back before eight a.m.',
#  'Tom is on the phone with Mary.',
#  'Something bad is about to happen.',
#  'Sami was so sorry.',
#  'I wish I knew what was going on.',
#  'The Peabody Orlando, Florida, second Peabody Hotel, opened in 1986 as the second Peabody Hotel in Orlando, Florida.',
#  'Is it going to kill me?',
#  'They are treated with mutual admiration.',
#  'There are holes for fastening wooden pillars in front of the demolished veranda.',
#  'Mine is the black one.',
#  'Almost every part of the process has been updated.',
#  'He underwent an operation on his left leg.',
#  'Chlef Province, Algeria, El Marsa District is located in the district of Chlef Province, Algeria.',
#  'Tom has worked in a variety of industries.',
#  'Tom is absolutely correct.',
#  'Tom was able to put out the fire by himself.',
#  'With the students, the instructor is expected to get ill.',
#  'Your one-year stay in Germany was very helpful.',
#  'It seems that it is familiar.',
#  'Please pour me a cup of coffee.',
#  'In Bangladesh, this was the first partnership of more than 100 runs for a team of seven wickets down for less than 100 runs.',
#  "Saladas - Department is part of the Corrientes - Argentina's province.",
#  'I was forced to take medicine.',
#  'I want you to use it.',
#  'Iran, Syria, Sudan, and North Korea are among the countries on the list.',
#  'It was established on July 18th 1914 by pharmacist and businessman James Horlick, brother of William Horlick.',
#  'The new facility was divided into four sections: an academic wing, a student services wing, and two athletic wings with classrooms.',
#  "They swore that they'd never cry.",
#  'You should support your colleagues.',
#  'The Sarawak district of Limbang divides it into two parts.',
#  "Tom and I aren't planning to meet together.",
#  '"This collection was exclusive to Wal-Mart Canada, but it was eventually available in the Spawn Store online.',
#  'My father and mother are dead.',
#  'They may not have discovered them like universities; they were small and did not have the higher degrees in medicine and theology.',
#  'On its first flight, the Falcon 9, the successor rocket, landed its first stage on land for the 20th time.',
#  'I should go with you.',
#  "Tom can't join us.",
#  'Since then, it has been very fine.',
#  'Starmount is a residential neighborhood in the South Charlotte (South Boulevard of Arrowood and Archdale).',
#  'He has a hat on.',
#  "I'm hoping that I've done the right thing.",
#  'Conlan Carter, a former actor who appeared in the television series "The Law and Mr. Jones" with James Whitmore and " Combat! "',
#  "I know you're skeptical.",
#  'Tom is a garbage collector.',
#  'It will be over soon.',
#  "Tom isn't a whistle.",
#  "I don't envy him.",
#  'Is there any zakuska?',
#  'This species can be found in the Atlantic Ocean and in the Gulf of Mexico; in the Caribbean Sea from South Carolina to Brazil.',
#  'Both husbands and wives should live by each other throughout their lives.',
#  "I'm handling it. You can relax. You can rely on me.",
#  'This soup is smacking of fish.',
#  'Gidoni was elected to the Veneto Regional Council in Belluno, California, after Tosi was barred by the Federal Party.',
#  'Have you ever seen an elephant fly?',
#  'These are the commonly accepted or similar protocol specifications that cover the open space as AMQP:',
#  "In the state of Maryland, the township is located in Fulton County's southwestern corner, bordered by Franklin County and the Washington County to the south.",
#  'It was the last time cyclists from 1969 to 1970, when cyclists were included on national teams.',
#  "In Paris, it's snowing.",
#  "She doesn't want to judge him.",
#  'However, López Obrador said on July 17th, 2006, in a radio interview with Miguel ngel Granados Chapa on "Radio UNAM", he said : "López Obrador" explains the ngel Granados Chapa.',
#  'I know Tom is joking about it.',
#  'She told me that she would go to Paris in August.',
#  'TATP is a white crystalline powder, according to some.',
#  "Max Franz (born 1784 — 1794), who ruled the university and Bad Godesberg's spa quarter, was another notable king.",
#  'Is there a bath in the room?',
#  'There is nothing inside.',
#  "I'd rather be at home than at home.",
#  'Tom told me that he was furious because Mary was irritable.',
#  "Don't tell him about it.",
#  "I should've invited Tom.",
#  '"Rediff"\'s Radhika Rajamani said, "Vishwaroopam "unquestionably rests on Kamal Haasan, who is a natural performer."',
#  'Active medication was the most commonly used treatment strategy at the time.',
#  'He was seized with chest pains that had not been present for some time.',
#  'Galinoporni is a southern village in Cyprus, on the Turkish Cypriot side of the Karpas Peninsula.',
#  "Dean wrote a tale and a song for the cat, and the two began a friendship, but Litwin and Litwin's collaboration ended in 2012.",
#  'Tom is talking to Mary.',
#  "These aren't fish.",
#  'On the night, Rabbi Levi taught Jacob that God showed Jacob all the signs.',
#  'I eat fruit.',
#  'Bade Ghulam returned to Kasur, Pakistan, in 1947, but stayed there permanently in 1957.',
#  'I never concealed anything from you.',
#  "Let's take a break for some tea.",
#  "I've never met anyone like you.",
#  'Both people are good at the bottom of their hearts.',
#  "Joe is betrayed and has agreed to join Gallagher's escape scheme.",
#  'The definition can be expanded to include or nonstandard points (arbitrary):',
#  'How is Tom related to you?',
#  'The 1982-1983 NBA season was the 37th season of the National Basketball Association.',
#  'I hated him.',
#  "I'm not sure what it's about.",
#  'Tom likes fishing.',
#  'According to the US Census Bureau, the county has a total area of, of which is land, and (0.2 % ) is water.',
#  "We've been helping Tom.",
#  "We've all agreed on that.",
#  'Writing with chalk is pointless.',
#  'In Kimberley, he captained South Africa against the British Isles on August 29, 1891.',
#  'Tom continued running.',
#  'Andrea Dovizioso stayed with Ducati for the 2015 season, with Andrea Iannone joining the factory team from a Pramac Ducati.',
#  '" Purple Clover" refers to people who are "still cool, still curious, and after all those years are still crazy.',
#  ...]

# %%
test_combined_en['t5_paraphrases'] = t5_paraphrases

# %% [markdown]
# ## Computing metrics over T5 paraphrases

# %%
Jaccard_1 = []
bleu_1 = []
bleu_2 = []
bleu_3 = []
rouge_l = []


for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['t5_paraphrases'][n]
  #lexical-syntactical variation metrics
  rouge_l.append(rouge_score(candidate, reference,ngram='l' ,metric='f'))
  bleu_1.append(bleu_score(candidate, reference, ngram=1))
  bleu_2.append(bleu_score(candidate, reference, ngram=2))
  bleu_3.append(bleu_score(candidate, reference, ngram=3))
  Jaccard_1.append(jaccard_similarity(candidate, reference, ngram=1))
# Out:
#   0%|          | 1/5000 [00:00<21:40,  3.84it/s]/usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 100%|██████████| 5000/5000 [00:10<00:00, 457.49it/s]

# %%
test_combined_en['bleu_1'] = bleu_1
test_combined_en['bleu_2'] = bleu_2
test_combined_en['bleu_3'] = bleu_3
test_combined_en['rouge_l'] = rouge_l
test_combined_en['jaccard_1'] = Jaccard_1

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                          t5_paraphrases    bleu_1    bleu_2  \
# 0     William Gibbs funded the Chapel and Hall, whic...  0.654985  0.467846
# 1                             This isn't my only thing.  0.714286  0.500000
# 2                                    He is a biologist.  1.000000  1.000000
# 3       I haven't read any of the books on the shelves.  0.833333  0.727273
# 4                    He's able to run faster than I am.  0.900000  0.777778
# ...                                                 ...       ...       ...
# 4995    They are not hungry, according to Tom and Mary.  0.636364  0.300000
# 4996     I went swimming in the sea for the first time.  0.636364  0.500000
# 4997                                 I'm not surprised.  0.818731  0.614048
# 4998         I think you should have been more patient.  0.777778  0.625000
# 4999                          Tom denies that he cried.  1.000000  1.000000
#
#         bleu_3   rouge_l  jaccard_1
# 0     0.314896  0.518519   0.666667
# 1     0.400000  0.666667   0.625000
# 2     1.000000  1.000000   1.000000
# 3     0.600000  0.823529   0.750000
# 4     0.750000  0.823529   0.818182
# ...        ...       ...        ...
# 4995  0.111111  0.375000   0.538462
# 4996  0.444444  0.800000   0.700000
# 4997  0.272910  0.857143   0.833333
# 4998  0.428571  0.800000   0.636364
# 4999  1.000000  1.000000   1.000000
#
# [5000 rows x 7 columns]

# %%
cosine_similarities = []
for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['t5_paraphrases'][n]
  cosine_similarities.append(cosine_similarity(candidate, reference))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 100%|██████████|

#  0.9999999403953552,
#  1.0,
#  0.9999999403953552,
#  0.683423638343811,
#  1.0,
#  1.0,
#  0.8665000796318054,
#  0.8597298860549927,
#  0.9350938200950624,
#  0.9814664125442504,
#  0.8157621622085571,
#  1.0,
#  0.9375621676445008,
#  0.8878685832023621,
#  0.7996705770492554,
#  0.9572579860687256,
#  1.0000001192092896,
#  0.8196315765380859,
#  0.7093920707702637,
#  1.0000001192092896,
#  0.7624679207801819,
#  0.8324106335639954,
#  0.9567015767097472,
#  0.9901692867279052,
#  0.9460076093673706,
#  0.8985711932182312,
#  0.7682729363441467,
#  0.9999999403953552,
#  0.7375827431678772,
#  0.872399091720581,
#  0.899318516254425,
#  0.9437410831451416,
#  0.8821299076080322,
#  1.0,
#  0.9999999403953552,
#  0.907401978969574,
#  1.0,
#  0.835581362247467,
#  1.0,
#  0.947934865951538,
#  0.9911593198776244,
#  0.8137068748474121,
#  0.8486088514328003,
#  0.8153805136680603,
#  0.9999999403953552,
#  0.8625569343566895,
#  0.9999999403953552,
#  0.9490076303482056,
#  1.0,
#  0.8926069736480713,
#  0.9999999403953552,
#  0.975190818309784,
#  0.8979952931404114,
#  0.9409627318382264,
#  0.9799089431762696,
#  0.9499807357788086,
#  0.8576828241348267,
#  ...]

# %%
len(cosine_similarities)
# Out:
# 5000

# %%
test_combined_en['cosine_similarities'] = cosine_similarities

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                          t5_paraphrases    bleu_1    bleu_2  \
# 0     William Gibbs funded the Chapel and Hall, whic...  0.654985  0.467846
# 1                             This isn't my only thing.  0.714286  0.500000
# 2                                    He is a biologist.  1.000000  1.000000
# 3       I haven't read any of the books on the shelves.  0.833333  0.727273
# 4                    He's able to run faster than I am.  0.900000  0.777778
# ...                                                 ...       ...       ...
# 4995    They are not hungry, according to Tom and Mary.  0.636364  0.300000
# 4996     I went swimming in the sea for the first time.  0.636364  0.500000
# 4997                                 I'm not surprised.  0.818731  0.614048
# 4998         I think you should have been more patient.  0.777778  0.625000
# 4999                          Tom denies that he cried.  1.000000  1.000000
#
#         bleu_3   rouge_l  jaccard_1  cosine_similarities
# 0     0.314896  0.518519   0.666667             0.885096
# 1     0.400000  0.666667   0.625000             0.609502
# 2     1.000000  1.000000   1.000000             1.000000
# 3     0.600000  0.823529   0.750000             0.986313
# 4     0.750000  0.823529   0.818182             0.986092
# ...        ...       ...        ...                  ...
# 4995  0.111111  0.375000   0.538462             0.921720
# 4996  0.444444  0.800000   0.700000             0.926251
# 4997  0.272910  0.857143   0.833333             0.960693
# 4998  0.428571  0.800000   0.636364             0.945135
# 4999  1.000000  1.000000   1.000000             1.000000
#
# [5000 rows x 8 columns]

# %%
test_combined_en.to_csv('/content/drive/MyDrive/working_directory/tfm/models evaluation/t5_evaluation.csv', index=False)

# %%
test_combined_en['bleu_1'].describe()
# Out:
# count    5000.000000
# mean        0.801562
# std         0.171524
# min         0.000000
# 25%         0.705401
# 50%         0.833333
# 75%         0.941176
# max         1.000000
# Name: bleu_1, dtype: float64

# %%
test_combined_en['bleu_2'].describe()
# Out:
# count    5000.000000
# mean        0.628569
# std         0.273035
# min         0.000000
# 25%         0.444444
# 50%         0.625000
# 75%         0.841044
# max         1.000000
# Name: bleu_2, dtype: float64

# %%
test_combined_en['bleu_3'].describe()
# Out:
# count    5000.000000
# mean        0.512634
# std         0.331539
# min         0.000000
# 25%         0.250000
# 50%         0.500000
# 75%         0.769231
# max         1.000000
# Name: bleu_3, dtype: float64

# %%
test_combined_en['rouge_l'].describe()
# Out:
# count    5000.000000
# mean        0.714817
# std         0.218238
# min         0.000000
# 25%         0.571429
# 50%         0.727273
# 75%         0.888889
# max         1.000000
# Name: rouge_l, dtype: float64

# %%
test_combined_en['jaccard_1'].describe()
# Out:
# count    5000.000000
# mean        0.751659
# std         0.202830
# min         0.000000
# 25%         0.625000
# 50%         0.750000
# 75%         0.944444
# max         1.000000
# Name: jaccard_1, dtype: float64

# %%
test_combined_en['cosine_similarities'].describe()
# Out:
# count    5000.000000
# mean        0.922573
# std         0.095737
# min         0.464620
# 25%         0.860187
# 50%         0.969157
# 75%         1.000000
# max         1.000000
# Name: cosine_similarities, dtype: float64

# %% [markdown]
# Cosine similarity filters + Counts

# %%
test_combined_en_filter1= test_combined_en[test_combined_en['cosine_similarities'] > 0.5]

# %%
test_combined_en_filter2= test_combined_en[test_combined_en['cosine_similarities'] > 0.7]

# %%
test_combined_en_filter3= test_combined_en[test_combined_en['cosine_similarities'] > 0.9]

# %%
print(len(test_combined_en_filter1),len(test_combined_en_filter2),len(test_combined_en_filter3))
# Out:
# 4992 4856 3278

# %% [markdown]
# # BART

# %% [markdown]
# ## BART paraphrase inference

# %%
import torch
from transformers import BartForConditionalGeneration, BartTokenizer
bart_model = BartForConditionalGeneration.from_pretrained('eugenesiow/bart-paraphrase')
device = torch.device("cpu")
bart_model  = bart_model.to(device)
bart_tokenizer = BartTokenizer.from_pretrained('eugenesiow/bart-paraphrase')
# Out:
# Downloading config.json:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/332 [00:00<?, ?B/s]

# %%
def get_response_bart(input_text):
  batch = bart_tokenizer(input_text, return_tensors='pt')
  generated_ids = bart_model.generate(batch['input_ids'])
  generated_sentence = bart_tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
  return generated_sentence

# %%
bart_paraphrases = []
for original_sentence in tqdm(test_combined_en['Text']):
  paraphrases = get_response_bart(original_sentence)
  bart_paraphrases.append(paraphrases[0])
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# 100%|██████████| 5000/5000 [3:40:38<00:00,  2.65s/it]

# %%
bart_paraphrases
# Out:
# ['The chapel and the hall were both fully funded by William Gibbs and were also designed by Butter',
#  'This is not my key.',
#  'He is a biologist.',
#  "I haven't read all the books on the shelves.",
#  'He is faster than me.',
#  'When Samuel Herrick arrived on the scene, Arnold had already been sent to Skenes',
#  'According to Jon Uren, Marketing Director of Warner Music Europe, the song had also ``',
#  'After Mary, Tom took off.',
#  'She has already lived in that town for five years.',
#  'Is wine good?',
#  'What do you smile about?',
#  'However, nationalist parties, together with other liberal groups, said they would boycott the July elections',
#  'Tom asked that he not be disturbed.',
#  'Tom changed his clothes.',
#  'The 1980 -- 81 Toronto Maple Leafs season was the Toronto Maple - Leafs 54th season of',
#  "I've dated a lunatic.",
#  'During the period between 1836 and 1846, when California was a province of independent Mexico',
#  "Tom thinks I'm an idiot.",
#  'Thank you for your warning.',
#  'How did she learn to dance?',
#  'I talk fast.',
#  'The character of Holden Ford is based on FBI agent John E. Douglas, and Bill Ten',
#  'Indeed, the two terms are now also used in other parts of the country.',
#  'They told everyone they were suspicious.',
#  'That is not a horse, but a donkey.',
#  'Tom is planning to be at your party.',
#  "I can't speak English fluently. What should I do?",
#  'Good. No absentees.',
#  'The three patrol districts serving Center City are the 6th, 9th and 17th districts',
#  'After Saturday comes Sunday.',
#  'It will soon be ten years of marriage for her.',
#  'The conclusions are that we are all manifest ideas of the one perfect spiritual mind and divine spirit',
#  'Blauburger gives good yields and is particularly susceptible to " Botrytis cine',
#  'She knows nothing about your family.',
#  'She was wearing a red blouse and a black skirt.',
#  'After Donald explained everything about Bobby and Morag, Rebecca stays in Summer Bay for the school',
#  'I speak only Italian.',
#  'The Tătaru River is a tributary of the Buză',
#  "I can't wait until tomorrow.",
#  'I saw at once that he was ill at ease.',
#  'Usually, Tom sleeps for eight hours.',
#  'Georges Merle died in 1881 in Paris, and his son Hugues Merle',
#  "I'm sure she won't come to see me.",
#  'I waited for an important call all weekend.',
#  'San Pedro Springs Park is located in the city of Bexar County San Antonio in the',
#  "I can't tell you who's on the list because I haven't seen the list yet",
#  'My whole body aches. What should I do?',
#  "I didn't call on him because I had a cold.",
#  "Tom told me that it's impossible.",
#  'Antony died on 6 November 1620 and was buried on 7 November in the church of',
#  "Why shouldn't we abuse animals?",
#  'The constituency is located in South Wales, on the right bank of the River Afan,',
#  'It is important to achieve the thermal regime of the quantum oscillator, where mechanical noise effects',
#  'Why is Tom not eating?',
#  "Victoria S. Bull ( `` Victor '' ) was introduced in 2001 as Vicki's sister",
#  'Believe what you want?',
#  'Former station North East was located north of Seymour at the junction of the Mangalore and She',
#  'Would you like me to stay?',
#  "Why don't you put some clothes on?",
#  "I think it's a great idea.",
#  'I met her last winter.',
#  'In 2016, the campus San Jose, California moved to Milpitas, California.',
#  'Tom lives outside the city.',
#  'At long last he made up his mind to propose to her.',
#  'How can I get my PIN number back if I forgot it?',
#  'A copy of the letter reached Montpellier by way of Toulouse on April 10',
#  'Additional mixing was carried out by Bill Malina, with assistance from Rice and Ghazi Hour',
#  'The residents made complaints about the noise.',
#  'I have no one to blame but myself.',
#  'She has a heart disease.',
#  'Is Tom stuck up?',
#  "You can't eat the money.",
#  '1843 : China : Sailors and Marines from St. Louis were landed at the trading',
#  "Some people take baths every day and others don't.",
#  'Are you going to come tomorrow?',
#  'In July 2011, the responsibility for the Werris Creek to North Star line was transferred from',
#  'Only six episodes survive in television archives, one from the third and fourth series, two each',
#  'Tom is not scared of spiders.',
#  'He did what he could for his children.',
#  'The Jieţ River is a tributary of the Slivei River in',
#  "Tom hasn't been expelled yet.",
#  'Wine makes the heart of man happy.',
#  'He was not disappointed.',
#  'This is the best.',
#  'The beta version of the service was released on July 30, 2008. Windows Live FrameIt',
#  'We just need time, he said.',
#  'The school is connected with the secondary department of the autistic school Ysgol Plas Br',
#  'As galanthophiles, the authors of the works on which these notes are based also',
#  'No other dog is bigger than this.',
#  "I'll be taking Tom's place.",
#  'I have enough money to buy a car.',
#  'I tried to escape.',
#  'Mudzuri defeated ZANU-PF candidate Amos Midzi in the March 2002',
#  'I did the work against my will.',
#  "Let's talk over the matter.",
#  'Buccinum parvulum is a species of sea snail, a true gastrop',
#  'What kind of songs are popular these days?',
#  'Is he swimming?',
#  'Tom may be confused.',
#  'The author translated the fairy tale into our mother tongue.',
#  'The tournament was resumed in San Francisco in 2006, where it was hosted for two years.',
#  'What is the most beautiful place in the world?',
#  'How did you meet each other?',
#  'Kathy Lloyd was born in Carrickfergus, Northern Ireland, and grew up',
#  'Tom decided to come with us.',
#  'Tom will try.',
#  'I saw a cat running after a dog.',
#  'It was first recorded by Irma Thomas in November 1961 and produced by Allen Toussaint',
#  'Tom is also sleeping.',
#  '" Darn That Dream \'\' is a popular song with music by Eddie DeLange and lyrics',
#  'How do I get home?',
#  'I agree with your proposal.',
#  'Is Tom anxious?',
#  'Maughan and his wife, the former Lorraine Hannemann of Manhattan, New',
#  'I have hard stools.',
#  'I have found out something.',
#  'She said she is concerned about her health.',
#  'Humor me.',
#  'Two weeks before the invasion, the corps was pulled out of the First Army and placed in',
#  'Olivella kifos is a species of dwarf sea snail, small gastropod',
#  "I'm thinking of switching majors. What should I do?",
#  'Tom must have had his reasons.',
#  'Who would have predicted this?',
#  'In 1739, during religious persecutions, he came as a renowned speaker ( ``',
#  'The car was sold with different names in various markets.',
#  'I went to see the movies yesterday.',
#  'Raumanga is a suburb of Raumanga in the Northland region of New Zealand',
#  'Is there any supermarket near here?',
#  'Owen Bradley recorded " Thank Schoen \'\' for her 1964 album " By Request \'\',',
#  'The loyalists had camped on the west side of the Catawba River, while',
#  'Back Street was a 1961 film directed by Universal Pictures, produced by David Miller and Ross Hunter',
#  'What is your area of expertise?',
#  'Mark, Nadine and Danielle have their pictures visible in the school display case.',
#  'The development of Bas 90 began in the 1970s and was implemented in the 1980s.',
#  'It has greatly improved compared to what it was.',
#  "The news of his son's death came as a great shock to his family.",
#  'It is found only in Yunnan and its tributaries in Dianchi Lake, China',
#  'In the first month of that year, I saw that it snowed for four days from',
#  'She gave him all the money she had.',
#  "They won't take him back.",
#  'On 1 July 2004, a police authority for the British Transport Police was created.',
#  'Scouting in Malaysia ( now YMCA ) was first introduced in 1908 as an experimental',
#  'Suzuki Beane is a humorous book written by Louise Fitzhugh in 1961 and',
#  'I need you for a second.',
#  "I'm not your teacher anymore.",
#  'In the semi-finals the teams in second place in the pools play the first teams from',
#  'Mount Sis is also a plateau that has called `` Sis Dağı Yay',
#  "What don't you get?",
#  'Does Mary look pretty?',
#  'Shimla is a suburb of the city of Sanjauli, in the Shim',
#  "Cassandra Peterson also appeared in Peaches Christ's `` All about the Evil '' with Patrick",
#  "The presbyterian doctrine is `` reformed '' and the government is `` theological ''.",
#  'I think she likes him.',
#  'The windows should have already been washed.',
#  'Please let me drive your new Toyota.',
#  'Linkuwa Pokhari is a village and village development committee in the Sagarmatha zone',
#  "I haven't finished reading this book. What should I do?",
#  "Let's play soccer.",
#  'I like your eyes!',
#  "Tom hasn't been caught yet.",
#  'It was predictable.',
#  'He broke his left wrist.',
#  '3M agreed to change the name in Acquire and Sackson suggested.',
#  'To my knowledge, he has not been involved in the fraud scheme.',
#  'He repaired the legs of the table.',
#  "I think that's inevitable.",
#  'You are the reason I came.',
#  'You are going nowhere.',
#  'According to the U.S. Census Bureau, the county is a total surface area of',
#  'I played a role at the coronation of Emperor Matthias in 1612 and the election',
#  'The mountain was named by Jules de Blosseville after French naval officer Marie Henri',
#  'He died prior to my arrival.',
#  'I have some time.',
#  'Why am I so tired?',
#  'According to Louis and Clarke Adventures, Salina is considered the Grand Island ( of Nebraska )',
#  'Esperanto is a fun language to learn.',
#  'In Europe, " Pueraria montana \'\' grows in warm regions of Switzerland and Italy',
#  'Layla paid for the taxi.',
#  'There are numerous student organizations on campus, including academic groups, religious groups, and student activity',
#  'The association has thirty members.',
#  'Michael Chang won 3 -- 6, 6 -- 3, 7 -- 5 against Renzo F',
#  'What is your favorite music?',
#  'The movie was a lot better than I expected it to be.',
#  'My friend fasts during Lent.',
#  'Lielplatone Parish is an administrative unit of the municipality of Jelgava',
#  'Disguising himself as a peasant, he crept into the castle town.',
#  "Due to Hossein Qoli Khan's castration, his brother Agha Mohammad Khan was",
#  'He works with me at the office.',
#  'He was trained in Dresden, later in Leipzig, and after a short stay in',
#  'Only the Sara of the south was governed effectively, French presence in the Islamic north and east',
#  'That might be serious.',
#  'I seem to have a temperature.',
#  'Peter Maag ( Ernst Peter Johannes Maag ) ( 10 May 1919 -- 16 April 2001',
#  'These articles are all exempt from duty.',
#  'The French were defeated at Waterloo.',
#  'During the competition she lost 50-25 to Zimbabwe, 84-16 to Tanzania, 58',
#  "I hope that doesn't happen again.",
#  'Mary and Tom are both unhappy.',
#  'After Anna was found, Martha married a man by the name of George I Eisenhauer',
#  'I dug one up.',
#  'In the week before the first race, Barwa Addax - driver Josef Krá',
#  "Tom doesn't think you should've done that.",
#  'I require absolute loyalty from my employees.',
#  'The children are in need of you.',
#  'Please tell Tom Mary.',
#  "I can't believe I'm hearing this.",
#  'She is a good deal older than he.',
#  'I heard that you did that.',
#  'The A cells produce glucagon, which mobilizes hepatic glycogen, and the ent',
#  'They had a neighborhood allies, including the Collopys ( Brian Collopy and Phillip Coll',
#  'She was in no humor for lunch.',
#  'I thought there was a possibility that Tom was going to break the contract.',
#  'People are not always rational.',
#  "My father doesn't allow me to drive. What should I do?",
#  "Tom said he's not going to sing anymore.",
#  'Giovanola also marketed the first freefall ( developed by Intamin ) and the',
#  'There are medical and pharmaceutical facilities, the provincial B.J. Vorster Hospital, a',
#  'From 1800 -- 04 Wright was British Consul - General for the Republic of the Ionian',
#  'However, a potential protocol for the use of sensitive flow control signals must be used to avoid',
#  'Are you satisfied with the result?',
#  "Aenetus blackburnii ( Blackburn's ghost moth ) is a moth of the family",
#  'What made you come here?',
#  'The snow melted away when spring came.',
#  'I had never seen such an exciting rugby match as one I saw yesterday.',
#  'Italy qualified for the Baseball - European Championship 2009 from the 2007 competition. The other qualifiers were',
#  'How did you like the party?',
#  "I've got to get it fixed.",
#  'We will carry you.',
#  'We had our roof blown off. How do we fix it?',
#  'The hurricane indirectly killed one person and immediately killed two in the state.',
#  'Are you worth gold?',
#  'Tom has already finished his lunch.',
#  'Why are you always shouting?',
#  "I don't have to wear glasses anymore.",
#  'Jarymowycz was a lecturer at the Royal Military College and was a frequent',
#  'Born in Gosforth, Northumberland, he moved to Wiseton Estate as a boy',
#  'Tom listened with interest.',
#  "She doesn't pay much attention to how she dresses.",
#  'This is not a good sign.',
#  'Albert Pyun, who had previously worked at Cannon, was brought on board and worked with',
#  'He died at his home in Trenton on 23 July 1942 and is buried at the Old',
#  'I know what you are planning.',
#  "Tom isn't going to help us today, he said.",
#  'The Bristly Peaks include the Brodie Peak and the Messent Peak.',
#  'Barbara Rogowska, also known as Barbara Kwarc ( born June 19, 1953',
#  'In the 1990s, new teaching campuses were opened in Ivrea, Mondovì',
#  'This small bridge was replaced in 1931 by the original Barron Collier Bridge, and then by',
#  'Webmention was originally published in the IndieWebCamp community and was developed as a W',
#  'Pedro eventually ended up with many other children in the care of a man called Sebastian.',
#  "I don't mind your staying here.",
#  'They make up 13 % of the population in Klaipėda, 28 %',
#  "Tom's heart was broken.",
#  'Kate is very charming.',
#  'I might be able to help.',
#  'The car is waiting at the gate.',
#  'It has also been said that the arrangement later inspired the work of Jimmy Webb.',
#  'A guide led the visitors around the museum.',
#  'Hurd Peninsula is located between South Bay and False Bay on the south coast of Livingston Island',
#  'Tom and Mary are no longer children.',
#  'How do I avoid offending Tom?',
#  "I'm not that drunk.",
#  "We're not cowards.",
#  "I don't wish to meet with him again.",
#  'I happened to be free last Sunday.',
#  'Tell me about your daily life?',
#  'He lives with his wife Lucy and their children in Noah and Mabel.',
#  'Tom got it so wrong.',
#  'She is a tease.',
#  'She wants someone to help her.',
#  'It was a very hot night.',
#  'Substitutes for asbestos now include ceramic, carbon, metal and aramid fibers,',
#  'You look rather tired. What should I do?',
#  'The job would be difficult, he said.',
#  'They said they felt nervous.',
#  'Corozal is a town and municipality in the department of Sucre in northern Colombia.',
#  "I didn't speak with him.",
#  'I started to cry too.',
#  'The wind is blowing hard.',
#  'I can accept that.',
#  'I am thirsty. Please give me something cold to drink.',
#  'Argento ( born Aria Maria Vittoria Rossa Argento ; 20 September',
#  "I'll get in touch with you soon.",
#  "His old clunker isn't worth anything.",
#  'The Concordant Greek text forms the basis of the concordant literal New Testament, which',
#  'Kendra Saunders is now 100 % Hawkgirl.',
#  'Is Tom persistent?',
#  "Tom's father walked out on his family.",
#  'What is it about?',
#  'We have to do this together.',
#  'After a succession of warm days, the weather became cold.',
#  "Let's go see them.",
#  'Tom wanted to know the cause of the accident.',
#  'The title and lyrics refer to the renaissance portrait of Mona Lisa painted by Leonardo da Vin',
#  'As correspondent she traveled to Russia, Finland, Italy, France, Scotland, Estonia, Germany',
#  'No comment.',
#  "Tom had no trouble finding Mary's house.",
#  'The two of us are finally alone.',
#  'Mary said she was mistaken.',
#  'You have to work.',
#  '" Purple Clover \'\' describes the site as for people who are `` still curious, still cool',
#  'His son, Herbie Matthews, also won a Brownlow medal and his grandson of the',
#  'I promise you that I will never do that again.',
#  'Michael J. Parlett ( also known as Mike Parlett ) is an English jazz sax',
#  'Tom was very persuasive.',
#  'I was trying to find Tom.',
#  'Carl Smestad ( May 8, 1888 -- June 29, 1962 ) was a Norwegian',
#  'Lie on the examining table.',
#  "Let's go for coffee?",
#  'Tom has lots of books.',
#  'According to a recent study, the average life span of the Japanese is still increasing.',
#  "I don't want to lie to anyone.",
#  'Both Tom and Mary want it.',
#  'You made a good decision.',
#  'The Valea Voenilor River is a tributary of the Pascu',
#  "Ask Tom if he'll do that.",
#  'Taft served as Chief Justice until his death in 1921, when he was succeeded by White',
#  'They are kin to each other.',
#  'William Middleton ( or William Middleton, died on 31 August or 1 September 1288',
#  'Tom and Mary kept their relationship from their parents.',
#  'No one was injured in the crash.',
#  'Mum is the word.',
#  'The following table compares the performance of LOD capable rendering and a brute detail method ( full',
#  'He is senior to me by two years.',
#  "The first railway workshops in the Wellington region were located near Wellington's first railway station at Pip",
#  'When she heard the news, she burst into tears.',
#  'How do I quit smoking?',
#  'The new tablet costs an arm and a leg.',
#  'In 2013, Tom died in Boston.',
#  'Mount Cobb is a mountain on Vancouver Island, British Columbia, Canada, east of Gold River',
#  'Only one percent of natural diamonds are of this type, and most are blue to grey.',
#  'He is the tallest in our class.',
#  'You may come if you like.',
#  'Tom got up and went away.',
#  'Wilson is angry with Dennis.',
#  'In 2015, SAP George X and Manny Rodriguez announced SpikeTV Spanish commentators for Premier Boxing Champions',
#  'In 2009, he joined the Professional Arena Soccer League of the San Diego Sockers.',
#  'They said they will laugh.',
#  'This is the actual problem.',
#  'Bill brought me the book.',
#  'When I saw them on a date, I asked them, "Do I hear wedding bells',
#  'As reported by Count Harrach, Franz Ferdinand\'s last words were " Sophie, Sophie',
#  "He's been dead for ten years.",
#  'Infer also has a domain abstract language for specific syntax tree linting, based on',
#  'Pérez also practiced with Telemundo, where she anchored and produced an entertainment segment',
#  'It is also home to the unregistered towns of Potter Valley, Calpella, Red',
#  "Don't disturb the others.",
#  'Ardning is a municipality in the district of Styria in the Austrian state of Lie',
#  'His dog was named Popeye by him.',
#  'The Technetium forms the simple complex. The potassium salt is isostructural with',
#  'The fortress was once again besieged by French troops under the command of General Zoller, from',
#  'The pain was agonizing.',
#  'Eduardo Rivadavia of " AllMusic \'\' called " Restless and Wild \'\'',
#  'Lucas is a clever clog.',
#  'I love my city.',
#  'Tom remained seated.',
#  'The 1988 -- 89 National Basketball Association season was the 43rd season of the NBA.',
#  'You are very good at this.',
#  'Hopewell, Charles City County, Virginia, also known as Shirley Hundred Island, is',
#  "I'd like to try on this dress.",
#  'We are working hard, he said.',
#  'How is this going to end?',
#  'This is unique.',
#  'The soundtrack was composed by musician Wajahat Attre, with texts by Noor',
#  'The Final FESPIC Games had 18 venues for the games, 9 in Selang',
#  'In geometry, the dull hexahexagonal tiling has a hyperbolic tiling',
#  'I built it.',
#  'As is quite common for teenagers aged from 13 to 19, she is conceited.',
#  "I can sure I can, although I can't really speak Shanghainese.",
#  'This is war.',
#  'Where do you park your car?',
#  'He wanted it.',
#  'After completing his university education at Cardiff University and Rouen, France, he was from 1996',
#  'His son Henry Wheeler Shaw ( 1818 -- 1885 ) became a well-known humor',
#  'He also appeared in 53 games for the Greensboro Patriots ( Piedmont League ) with',
#  'They said they were not busy.',
#  'What is the best way to go to bed?',
#  'It caught me by surprise.',
#  'Each line contains three points, so the Hesse configuration has the notation 912 in the',
#  "I'm calling from Tom's cell phone.",
#  'Tom stood quietly.',
#  'I should have told someone.',
#  'Is Tom trustworthy?',
#  "I can't raise my child by myself. What should I do?",
#  'I went there yesterday.',
#  'I want her to win.',
#  'Matter can be solid, gaseous or liquid.',
#  'It is about 4 miles east of Caernarfon, 7 miles south of Bangor',
#  'It is located at 142 South Rexford Drive in Beverly Hills, California, opposite the First',
#  'Mid Wales Hospital, originally the Brecon and Radnor Joint Counties Lunatic Asylum,',
#  'Stephen D. Reicher ( Steve Reichher ) is a Professor of Social Psychology',
#  'At that time, Tom was thirty years old.',
#  'The interpreter provides her personal interpretation.',
#  'He just left.',
#  'He lost all his possessions.',
#  'He demanded that I pay the money back at once.',
#  'He is a poet by birth.',
#  'He is specialist in contemporary music and baroque music.',
#  'The Finnish album " Deathstar Rising \'\' cracked the new Album Top 10 and reached # 8',
#  'Tom will explain.',
#  'I am not satisfied with the result at all.',
#  'It is probable that he will win the speech contest.',
#  "Wendy, I'd like you meet my brother Sam.",
#  "I'll never be able to play again.",
#  'Maine is a center and a camp for the Hog Island chapter of the National Audub',
#  'They promised that they would come.',
#  "I've seen you somewhere.",
#  'You\'re expected to be here by 2:30," he said.',
#  'English is easy to learn.',
#  'Unfortunately, this is real.',
#  'She unwraps her birthday gift.',
#  'On 6 February 2014, Spencer Machacek was traded by the Penguins to the Columbus Blue',
#  '" Myles C. Fox \'\' reached Yokosuka on 23 September and left San Diego',
#  "Yea, that's all it is.",
#  'He said he was going to be late.',
#  'Mornington House was the Dublin Georgian residence of the Earls of Mornington.',
#  'The astors settled in North America, first appearing in the 18th century in Germany with',
#  'In 2013, Beals signed on for the main role of ABC drama pilot `` Westside',
#  'I did what she asked me to do.',
#  'I like to watch baseball games.',
#  'Can I stay and help?',
#  'The poor man has no relatives.',
#  'The strong winds were blowing.',
#  'Tom nodded his head and left.',
#  'Insatiably greedy.',
#  "I got a famous singer's autograph.",
#  'Chabrian Jattan is a village in Mirpur Tehsil of Mirpur',
#  'He said he was thirsty.',
#  "Don't fuck it up!",
#  'I am quite ignorant of the plan.',
#  'Vultures circled above the dead body.',
#  "Tom looks like he's having a good time.",
#  'The official language is Bhojpuri, while the local language is Hindi.',
#  "He's a fake.",
#  'What is Esperanto?',
#  'Are you afraid of ghosts?',
#  'In 2014, Lilly will visit the World Curling Tour for her first season with new teammates',
#  'Tom knew that Mary would not win.',
#  'The library is a dream in architectural beauty and a model in interior design, according to a',
#  'She was the second daughter and the youngest of four children born to Philander Montague Wright',
#  'Ask him whether he comes.',
#  'I want his head.',
#  "The linear procedure provides the constant term in `` j '' ω regardless of how complex the",
#  'We have already tried that.',
#  'Dehgah ( also Romanized as Dehgāh ) is a village',
#  'Jones lives in London with his wife Cheryl, his son Nathan, and his three daughters,',
#  "Don't throw away a good opportunity.",
#  "That film's really interesting.",
#  'We finally got to the summit.',
#  'I did not get a wink of sleep last night. What should I do?',
#  'Is this the last train?',
#  'You can wait till the cows come home, he said.',
#  'Have you ever seen a red river?',
#  'Portuguese is quite different to Portuguese Portuguese.',
#  'The magazine was based in Paris, but was published in London by Gerald Duckworth and Company',
#  'In 1913, Lepel had lost its strategic and economic importance and was a quiet regional centre',
#  "We could've managed, he said.",
#  'Thomas was the youngest child of farmers Fred and Elizabeth Goodwill.',
#  'Tom will probably cry.',
#  'These enzymes are capable of enantioselective oxidations of prochiral substrates',
#  "Don't put me in the middle of this.",
#  "I've never said that!",
#  'Tom made us leave.',
#  'Mary is the laziest of her schoolmates.',
#  'He assured me.',
#  "I've done nothing exceptional.",
#  'How long does it take to get to the train station from a taxi?',
#  'I walked alone.',
#  'When boiled, water turns into steam.',
#  'Tom switched off the lights.',
#  "I'm so happy to visit VNU.",
#  'Tom seems wealthy.',
#  'These allegations are false, he said.',
#  'She attempted suicide.',
#  "They don't come.",
#  'I think that I was followed by someone.',
#  'I am ready to die. What should I do?',
#  'Dragan Umičević ( born October 9, 1984 in Dubica,',
#  'Tom said it was your fault.',
#  'I just brush it off.',
#  "Should I have followed Tom's advice?",
#  'Get on your horse.',
#  'I have a sharp knife.',
#  'Hopkins toured with the band for six months through Japan, the United States and England.',
#  'Simon Brook is the son of director Peter Brook and actress Natasha Parry. His sister is',
#  'I wonder if Tom is happy?',
#  "At `` Shine 8 '', Valkyrie defeated Amazing Kong, Angelina Love, Christina von E",
#  'To secure political independence, political parties are factual associations in most European countries.',
#  'Margot A. Thien ( born December 29, 1971 in San Diego, California )',
#  'The first recorded Irish presence in the area of present-day Newfoundland dates back to 1536',
#  'The tire is low.',
#  "Do you think I'm to blame?",
#  'Look out for rock slides.',
#  'On December 30, 1888, Susie J. Clarke married Brown in Ayer, Massachusetts',
#  'Tom needs help. Where can he seek professional help?',
#  'Tom Watson was originally scheduled to defend his Middleweight Championship against Frank Trigg.',
#  'Probably, Tom will be starved to death.',
#  'The teacher recommended this dictionary to us.',
#  'Everything is connected to everything.',
#  'Tom thought a lot about Mary.',
#  'Another series was played in Havana between Cincinnati Reds and Boston Red Sox.',
#  "I'm Glad no one is around.",
#  'The combined singular route now forms a new passage that leads directly from Gothenburg to Newcastle',
#  'I was at a movie theater.',
#  'This process is the photographic equivalent of a cylindrical map projection in cartography.',
#  'I remember that I met the Queen.',
#  'Did you kiss him?',
#  'I had no idea you were coming.',
#  'It was driving me crazy.',
#  'The new grammar school became the Upper School, while the old building became the Lower School.',
#  'This kind of mistake is easy to overlook.',
#  'Tom and I both know Mary.',
#  'Something unexpected happened.',
#  'Tom looked straight at me.',
#  'This debate was hosted by anchors Jessica Soho and Mike Enriquez of GMA News',
#  "I'll sing.",
#  'Dennis is arrested and sentenced to die with Hugh and Barnaby, Hugh and Dennis are',
#  'The Slănic River is a tributary of the Comina River in Romania',
#  "Nevertheless, I'm immensely proud.",
#  'Prior to his arrival in Serbia in 2002, Mišović was in Sweden, where',
#  "I'll answer you tomorrow.",
#  'Tom says he is not interested in romance.',
#  'Some authors split the species in two : the Russian and Central Asian populations as `` Fallopia',
#  'My bike has been stolen. How do I recover it?',
#  "I haven't seen him in days.",
#  'Tom took a seat across from Mary.',
#  'How did you get everything you needed?',
#  'Tom says he did nothing illegal.',
#  'Their trip was postponed because of rain.',
#  'The logo is similar to that of the Florida Panthers of the NHL. The old jersey of',
#  'I can walk to school in 10 minutes.',
#  'Emu Park was also the junction of the Central Western Line and Rockhampton line.',
#  'They went on talking all night.',
#  'You should buy him new toys.',
#  'Hugues Merle died in 1881 in Paris. His son Georges Merle also',
#  'Vermont South is bordered to the north by Mitcham, to the west by',
#  'While at American Express, Espuelas worked on the accounts Wunderman, General Foods',
#  'They danced.',
#  'You seemed interested.',
#  "I don't know what it is.",
#  'The manuscript was bought in 1819 by Edward Everett from America to Constantinople, along with six',
#  'In February 2017, Prodrive announced that they will enter the 2018 FIA World Rallycross Championship',
#  "I'm going to need some supplies.",
#  'Do you have a room of your own?',
#  'Tom gave me something.',
#  'Why do I like coffee more than tea?',
#  "Don't forget death.",
#  "Tom didn't sound very confident.",
#  "I'd never do anything like that.",
#  'Acting for `` has the same basic meaning as acting ``, except that it indicates that',
#  'Why do I keep getting spam emails?',
#  'The series was created by Mike Roberts and is written by Matt Mariska and Andy S',
#  'Can I do anything?',
#  'I fell asleep while watching TV. What should I do?',
#  'The Vienna Ice Revue toured through most European countries including Germany, Italy, the Netherlands,',
#  'Tom and I are both professors.',
#  'Percy W. Adams married Gwendoline Wright.',
#  "In 2010, Hatherley joined KT Tunstall's band, playing lead guitar and replacing",
#  'Drew Springer, Jr. ( born January 13, 2013 in Muenster in Young',
#  'He applied for admission in the Riding Club.',
#  'As a matter of course, he is quite right.',
#  'By then, three-quarters of the slaves in Maryland had been freed, and a high',
#  'There was a full moon last night.',
#  "I'm not sure Tom will be able to do that.",
#  "Sami didn't say anything.",
#  'Where are my boots?',
#  "I'm on vacation. What should I do?",
#  "Why won't you have tea with me?",
#  'All songs written by Alejandro Lerner, except " A Place Where We Belong \'\',',
#  'Milk is a good beverage.',
#  'Is Tom partly to blame?',
#  'I came early to get a good seat.',
#  'There are essentially four types of databases : curated databases, integrative databases, literature databases and',
#  'Have they found him yet?',
#  'This was the first time since 1976 that New Jersey did not vote for the same candidate as',
#  'You could have done that better.',
#  'There were no flowers or trees in his town.',
#  'How do I bring up my children?',
#  "You're conscientious.",
#  'After studying in Shanghai, he sailed to Belfast in 1933 to join his parents.',
#  'This balance was inserted into the accumulator when the card was read into the car.',
#  'Dyadic natural males do not have the anatomy needed for human embryonic and foetal',
#  'Somebody must have followed us here.',
#  'On 7 December 2017, NVIDIA officially announced the Nvidia TITAN V.',
#  'Why should I study French?',
#  'Tom died quite suddenly.',
#  'She lost both her parents.',
#  "Valerin's castle is seized, he is killed and the Queen is released.",
#  'Tom will probably be up soon.',
#  'Thomas Edward Donne ( 1860 -- 1945 ) was a New Zealand civil servant, author,',
#  'They said they are bored.',
#  'Hold me in your arms.',
#  'Joe was born on March 27, 1929 in Somerville, Massachusetts and grew up in Quincy',
#  'Wow, this is beautiful.',
#  "Tom and Mary said they're not mad.",
#  'Mahoning Creek is a tributary of the Lehigh River in Schuylkill',
#  'He is Austrian.',
#  'Aside from fright, she was not injured.',
#  "I'm sorry I dragged you into this.",
#  'The pterostigmata of white males are almost immature.',
#  'Tom is having trouble making ends meet.',
#  'Do you drink beer? Why or why not?',
#  'He is thirsty for fame.',
#  'He was the son of Shmuel Binyamin Sofer ( `` Moses Sofer',
#  'Should Tom have waited for me?',
#  'I saw him cry.',
#  'She is a more proficient leader than he is.',
#  'Tom works there.',
#  '" Robbers " is a song by the English rock band The 1975, released on May',
#  'Samata Express is a super fast express train between Visakhapatnam and Hazrat',
#  'There are flying birds in the sky.',
#  'Adult birds have white bodies with a black patch, a thin dark bill and red legs and',
#  'That was a dumb question.',
#  "What's happened to it?",
#  "I'll tell him you came by.",
#  'The Royal College of Music has appointed Natalia as a Professor of Conducting alongside Maestro',
#  'Here is the map.',
#  'Club owner Silvio Berlusconi announced his departure on 25 May 2016, along with',
#  "Don't make abrupt moves.",
#  'The theatre usually opened at this time.',
#  'It is endemic to California, in the central Sierra Nevada in eastern Madera County.',
#  "They didn't even know who they were supposed to meet.",
#  'Tom knew that I was satisfied.',
#  'The lake is three miles wide.',
#  "I'd be willing to take that chance.",
#  'Bus connections on the Luton to Dunstable Busway Route A also connect Parkway to L',
#  'Tom has written several books.',
#  "It's easy to answer that question.",
#  'Talks about the marriage of Meena have started, and Chandra has begun looking for a',
#  'That was a disappointment.',
#  'For me, nothing is more delightful than to talk with him.',
#  "Tom isn't ready yet.",
#  'A golden key opens all doors.',
#  'One billion people speak English.',
#  'I hear you have quit smoking. How?',
#  'Fritz Heider wrote that people tend to regard behavior in one of two ways : the',
#  'Stävlö or Stäflö is a castle in Sweden in the municipality of',
#  'The characteristic function provides an alternative way of describing a random variable.',
#  "My mother says I'm very handsome.",
#  'Earthquakes are common in Peru, especially in the Arequipa coastal area of',
#  'What if Tom ate my cookies?',
#  'Tom somewhat resembles his father.',
#  "I won't tell anybody you're in Australia.",
#  'He is delightful.',
#  "The dividends have increased the real `` real '' return on average equity to double, about 3",
#  'It is raining.',
#  'The construction of the new stadium was held for 4 years and was inaugurated on 21 August',
#  "I'm just a tourist.",
#  'In 1643, the English Parliamentarian Alexander Rigby bought the great existing Plough of',
#  'Winner - Effects were shown when established non-experienced chicks were placed in a study by',
#  'I went to bed last night at 12.',
#  'Tadas Langaitis is a Lithuanian politician, member of the Seimas since',
#  "You're not in her league.",
#  "Tom doesn't smoke anymore.",
#  'Tom is sure to succeed.',
#  'Terry was born in Fairfax, Iowa, and died in Cedar Rapids, Iowa.',
#  "Like its neighbour, Scotland, the constituency was one of Labour's safest seats in Dunfer",
#  'It was designed by Little Rock Architect Harold A. Berry and Dallas, Texas Architect F.',
#  "Of course, Tom didn't come.",
#  "I'm looking forward to hearing from you.",
#  'The CCV presents miniature versions of important historical buildings and structures, together with local customs.',
#  'Tom answered the question correctly.',
#  'He banged the door in anger.',
#  'Tom plans on doing that tomorrow.',
#  'I drink coffee. Why?',
#  "The stretch between Chiswick's western border to Syon Lane ( Gillette Corner )",
#  'Tom looked sharp.',
#  'He moved back with his parents.',
#  'Today I am four years old. What do I do?',
#  'Union County is included in the Spartanburg, SC Metropolitan Statistical Area, which is also included',
#  "I've known Tom all his life.",
#  "I'm not frightened of anything.",
#  "I've read all those books.",
#  "We're going to have to do that.",
#  'He beat Kakhaber Zhvania, but lost the final to Andrey Balan',
#  "According to Robert of Torigni, Humphrey's mother was Duvelina, sister",
#  "Tom doesn't need to worry anymore.",
#  'On 29 September 1849, Queen Victoria traveled by train from Gloucester to Swindon',
#  'It is located on the modern Natchez Trace, Mile 180.7 at the historic',
#  'Kittery Point is part of Portland -- South Portland -- Biddeford, Maine',
#  "I'm afraid you'll get lost.",
#  "Could you lower your voice please? I'm really hung over.",
#  "Let's start with beer.",
#  "Colonel Ray died in 1989 and Lieutenant Colonel Koski died on New Year's Eve,",
#  'Hodges, as well as Green and Tom Jones, have written all recorded songs by',
#  'Alternate.',
#  'I was so lonely.',
#  'You are either with us or against us.',
#  'Stephen Hendry won the title for the first time and defeated Peter Ebdon 9-8',
#  "Tom's parents were both teachers.",
#  'On 7 July 2009, General Major Francis Okello was replaced as Commander of AMIS',
#  'You are a great cook. Why?',
#  'The agreement with Bolivia was applied on 4 August 2016 and not denounced from 4 February 2017.',
#  'Has she come?',
#  'You have no right to pass judgement on these people, he said.',
#  'Magda Lorne learns from her supervisor, Cholayna Ares, that a Terran',
#  'What is the best way to give me a shot?',
#  'Mount Morris Township is located in Ogle County, Illinois.',
#  'Archdale is a residential neighborhood in Starmount ( South Boulevard near Arrowood and South',
#  'The incident was originally not reported by the state-controlled Iranian media, but was first reported',
#  'Somebody was murdered.',
#  'How important is sleep in health?',
#  "It's not a virus.",
#  'He believes that Elbow is too acceptable, while he himself believes that the writer should first',
#  'The participants included TJ Trinidad, Biboy Ramirez, Eric Fructuos, Rico Rob',
#  'We hope you will visit Boston.',
#  "I haven't eaten anything yet today. What should I do?",
#  'Caspar David Friedrich was born on 5 September 1774 in Greifswald, P',
#  'Lake Bordaglia is a lake in Forni Avoltri Province, Udine,',
#  'I do not know whether it is good or not.',
#  'Its approximate boundaries were Pearl Street to Grier Avenue and South Broad Street to what is now',
#  'Tom is now doing well.',
#  'The Beliu River or Agri `` River is a tributary of the Botfe',
#  'In the morning, we clear the futon.',
#  'She wept bitterly.',
#  'Although the Maryland Department of Transportation is located in Baltimore, three of its subordinate organizations have their',
#  'Living in the city is quite different from living in the country.',
#  'If the programmer does not provide a constructor for an instantiable class, most languages provide a',
#  'However, Turkish Prime Minister Ahmet Davutoglu argued that Turkey would not support the EU',
#  'Another new bridge was built at Phnom Penh on the Neak Leung to Ho',
#  'I met him early this morning.',
#  'Please take these dishes away.',
#  'He played for the Brooklyn Dodgers in 1942 and for the New York Giants from 1946 to 1948',
#  'The Urechioiu River is a tributary of the Burduja River in',
#  'Tom ate everything on his plate.',
#  'The species was first formally described in 1856 by Carl Meissner in `` Prod',
#  'The government of Qingyang County is located in the town of Rongcheng.',
#  'He also managed several international music commercials, including the European " Freestyle \'\' campaign for Nike',
#  'I got a noisemaker as a Purim gift.',
#  'Dave Denine is a provincial politician in Newfoundland and Labrador, Canada. He served as Minister',
#  "Tom said he didn't feel anything.",
#  'Tom is a teacher, right?',
#  'My friend lives in that house.',
#  'Tom will go there tomorrow.',
#  'Give me the pleasure of keeping quiet.',
#  'He was born and raised in Vancouver, British Columbia, Canada, and died in Ayles',
#  "I don't have anything to give you.",
#  'Tom said Mary likes dancing.',
#  "What color is Tom's hair?",
#  'Tell Tom how you feel.',
#  'We must help him immediately, he said.',
#  "They said they're furious.",
#  'One of them, Micheál Martin, said Fianna Fáil leader Shane',
#  'However, a sensible protocol for the use of such transmission flow control signals must be used to',
#  'I asked everybody the same question.',
#  'They are talking to each other.',
#  'Mohsin Zaidi lived in Delhi for nearly four decades before settling down in Lucknow',
#  'His invention deserves recognition.',
#  'In 1883, the first schools were built in the area for 400 black and 60 white',
#  'Euacidalia brownsvillea is a moth of the family Geometridae',
#  "It's uncertain when he will come.",
#  'I am a Trojan horse, so I have infected my Mac computer.',
#  'Tom said, "budge over," forced his way in and sat down.',
#  'We split the Loot three ways.',
#  'Do you know how to drive?',
#  'This victory repeated in an Opel Astra in 2003 this victory with Reuter, Tim',
#  'I heard a noise. What does it mean?',
#  "Tom and Mary aren't talking to each other anymore.",
#  'Penn State ( 5-1-0 ) defeated Philadelphia ( 19-7 ) at Pennsylvania',
#  'While these two railway stations are relatively close to each other, the two stations are not interchangeable',
#  "I'm all thumbs in the kitchen.",
#  'Paralepetopsis tunnicliffae is a species of sea snail, a',
#  'When he finished his career in Poland, he went to Canada to sign with the Toronto Falcons',
#  'He died in Munich and is buried at the northern cemetery in Ajaccio, Corsica',
#  "You are required to provide three months' rent in deposit.",
#  'Do you have an appointment?',
#  'I hate flying. Why?',
#  'It was founded in 2002 by Metin Üstündağ, Selçuk Erd',
#  'Both Tom and Mary are ready.',
#  'You should make notes.',
#  'Lester B. Faulkner was temporary chairman until the election of George M. Bee',
#  'Our grandfather learned five languages when he was growing up.',
#  "She doesn't like to sing sad songs.",
#  'The shape of the audiogram categorizes abrupt high-frequency loss ( sensory phenotype ) or',
#  'In July 2013, Lone Star sold comics three of their five remaining stores in Mesquite,',
#  'Defending champions were Zina Garrison and Sherwood Stewart, but lost in the second round',
#  'Djurgårdens IF U18 beat Malmö FF U18 3 --',
#  'This will be his car.',
#  'Jeetenkumar Naorem and Tony Aheibam wrote the soundtrack for the',
#  'It was taken to Australia, where today it is widespread in Queensland, the Northern Territory and',
#  'Of the women, Sarah Hendrickson ( USA ) was the favourite, Sara Takanashi',
#  "We're not crazy.",
#  'Beverly Hills railway station is located at the South Line Airport on the Sydney Trains',
#  'Davies had lived with Jomo Kenyatta at the LSE and had absorbed',
#  "She said she couldn't speak French.",
#  'Mary is a yodeler.',
#  'Why do people feel afraid?',
#  'You may invite whomever you like.',
#  'Tom put on a tie.',
#  'His acquaintance runs a grocery in the country.',
#  'Kumara Sambhavam is a 1969 Indian Malayalam and Tamil film (',
#  'Sami baptized his children.',
#  "Tom didn't understand.",
#  'He made the situation worse.',
#  'Examples of ceramics include white porcelain or white porceain decorated with cob',
#  'Another series was played in Havana between the Boston Red Sox and the Cincinnati Reds.',
#  'He thinks he is somebody, but actually he is nobody.',
#  "He said he isn't busy.",
#  "Why don't you admit your mistakes?",
#  'Main partners of the Festival are UBS, Manor, Heineken, Vaudoise',
#  'It is popular among senior citizens.',
#  'Everyone was worried.',
#  'I got these earrings from my grandmother.',
#  'No other boy in our class is more studious than Jack.',
#  'This tree bears no fruit.',
#  'Sami was baptized.',
#  'His ambition knows no bounds.',
#  "Dr. Carter remains in Africa for several months and works in Kem's AIDS clinic.",
#  'We are moving next month.',
#  'I saw Tom hit Mary.',
#  'The winner of each semi-final ( Best of 3 ) rose to the gold medal race',
#  'A medal was flown from Hawaii to Guam and presented to him in the hospital.',
#  'Tom began whistling a tune.',
#  'Do you guys know each other?',
#  'Tom was all wrong.',
#  'The Penser Joch ( ; ) ( 2211 m ) is a high mountain pass',
#  'Would you like to come to my party?',
#  'In the United States, Scion was allocated 10,000 units of the 2013 model year (',
#  'The troops had sufficient arms.',
#  'I never learned to swim. What should I do?',
#  'Baxter Aviation operated services between Vancouver Harbour Water Aerodrome and Nanaimo Harbour Water',
#  'Productions of the show require a small set and a minimal cast of 6 actors, as',
#  'How was your first trip abroad?',
#  'For example, 351 W 5th Avenue is located approximately west of Fifth Avenue on the south',
#  'Without communication, there is no progress.',
#  'My father used to say that time is precious.',
#  "I usually don't bother with people like him.",
#  'Jimmy Arias defeated Andre Agassi 6 -- 2, 6 - 2',
#  "Tom doesn't know what will happen.",
#  'Tom planned on doing that by himself.',
#  'My school grades were average.',
#  'They said they are busy.',
#  'Can you hurt a painter?',
#  'How do you pronounce the "@" sign in your language?',
#  'African stone tool technologies are divided into modes, as proposed by Grahame Clark in 1969',
#  "Tom just never should've done that.",
#  "We're eating apples. What does it mean?",
#  'In April 1944, Cozens was promoted to Lieutenant-General and was later appointed Assistant Chief',
#  'It was founded in 1998 by Olaf K. ( Robert N. and Astrid',
#  'How do I put on a happy face?',
#  'Abbott killed Mary.',
#  'We are planning to do that tomorrow, he said.',
#  'They said they are likely to win.',
#  "I don't think Tom is busy.",
#  "I'm trying to conquer her heart.",
#  "I'm not very good at Arabic.",
#  'At the State election in November 1856, 81 Republicans, 31 Democrats and 8 Americans were',
#  'Bhojpuri is the local language and the official language is Hindi.',
#  'You must buy a ticket to get on the bus.',
#  'I am calling my brother.',
#  "I think it's hogwash.",
#  'Anabel Medina Garrigues and Virginia Ruano Pascual won in the final 6',
#  "I've never seen you angry.",
#  'There are nearly 2,000 islands along the coastline, of which about three quarters are unin',
#  'Under your umbrella let me in.',
#  'If only I could speak German fluently then what would I do?',
#  'The dress becomes you.',
#  'Balıklı is a village in the district of Gümüşhac',
#  'The above test does not distinguish between more complex distributions, such as quantum and classical, or',
#  'Tom is dyeing his hair.',
#  'A few years later it failed again, but soon reopened again.',
#  "I don't see any fun in it.",
#  'Old Harbour Bay celebrated the arrival of the East Indians in Jamaica on May 13.',
#  'Jake Chapman, Tracey Emin, Angus Fairhurst, Billy Childish and Joshua Compston',
#  "It's easy to find friends, but it's harder to keep them.",
#  'Tom made a couple of good suggestions.',
#  'Good morning, Tom.',
#  'A third album, again on Dragonfly, was then released in 2003.',
#  "Young girls' desire for slim figures is strong.",
#  'Mary put on her wedding dress.',
#  'The station was founded in 1947 by the British Falkland Islands Dependencies Survey as Station F',
#  'He is known for the creation of various origami models, including erotic instrumentalists, insects',
#  'Have you traveled recently?',
#  "We consider it the citizens' legitimate right to have public libraries.",
#  'It is this window that he broke.',
#  "We didn't see him.",
#  "I'm taking him to the hospital.",
#  'It will be all right, come on.',
#  'What did Tom look like?',
#  'It was founded in 1998 by Astrid M. ( Robert N. and Olaf',
#  'The tournament was resumed in San Francisco in 2006, where it was hosted for two years.',
#  'Tom is very concerned about that.',
#  'The team has played teams such as Hawaii, Rutgers, Iowa, Mississippi State, Nebraska,',
#  'In 235 BCE, after an attack on the state of Zhao, troops from the states of',
#  'The whole body hurts me!',
#  'What counts the most in life?',
#  "Tom wouldn't help me.",
#  'The students are having recess now.',
#  'Rituparna Sengupta and Indrani Halder won the 1998 National Film',
#  'We are brothers.',
#  'The people are angry.',
#  "Let's take a break for coffee.",
#  "Let's wait for the rain to stop.",
#  'The weather is moderately warm in winter, cold in summer.',
#  'They captured him.',
#  'I have to go alone.',
#  'Mercer was the brother of George Mercer, John Francis Mercer and father of Charles Fenton',
#  'Andrea Dovizioso remained with Ducati for the 2015 season, with Andrea',
#  'The SAS curve ( Surprise Aggregate Supply ) is a vertical line called the EAS curve',
#  'On August 12, 2003 Kottonmouth Kings released their 3rd compilation album, their 9',
#  'Stenolechia zelosaris is a moth of the family Gelechi',
#  'Margaret Craske was born on 26 November 1892 in Norfolk, England, daughter',
#  'He came back before 8.',
#  'Tom is talking to Mary on the phone.',
#  'What is going to happen to us?',
#  'Sami was so sorry.',
#  'I wish I knew what was going on.',
#  'The Peabody Orlando, near Orlando, Florida, opened in 1986 as the second Pe',
#  'Are you gonna kill me?',
#  'They have mutual respect, he said.',
#  'In front of the broken veranda are holes for attaching wooden pillars.',
#  'That black one is mine.',
#  'Almost everything has been improved.',
#  'He had an operation on his left leg.',
#  'El Marsa District is a district of the province of Chlef, Algeria.',
#  'Tom has had many different jobs.',
#  'Tom is right.',
#  'Tom managed to put out the fire by himself.',
#  'The teacher is likely to get angry with the students.',
#  'Your one year stay in Germany was very useful.',
#  'It looks familiar.',
#  'Please give me a coffee.',
#  'This was the first partnership of more than 100 runs for a team seven wickets down for',
#  'Saladas Department is a department of Corrientes Province in Argentina.',
#  'I was forced to take medicine.',
#  'I want you to use it.',
#  'The countries currently on the list are Iran, North Korea, Sudan and Syria.',
#  'It was created on July 18, 1914 for the pharmacist and businessman James Horlick',
#  'The new facility was divided into four sections : an academic wing, a student services wing and',
#  'They swore that they would never cry.',
#  'You should help your friends.',
#  'It is separated by the Sarawak district of Limbang into two parts.',
#  "Tom and I aren't planning to go together.",
#  'This series was exclusive to Wal-Mart Canada, but was eventually sold online in the Spawn',
#  'My father and mother are dead. What should I do?',
#  'The tiny institutions they founded would not have appeared to them like universities -- they were small and',
#  'The successor rocket, the Falcon 9, landed its first stage successfully on land for the twentieth',
#  'I should go with you.',
#  "Why can't Tom come with us?",
#  'Since then it has been very fine.',
#  'Starmount is a residential neighborhood in South Charlotte ( South Boulevard of Arrowood and Arch',
#  'He has a hat on.',
#  "I hope I've done the right thing.",
#  'The former actor Conlan Carter, who appeared in the television series `` The Law and Mr',
#  "I know you're skeptical.",
#  'Tom is a garbage collector.',
#  'It will be over soon.',
#  'Tom is not a busy man.',
#  "I don't envy him.",
#  'Is there any Zakuska?',
#  'This species can be found in the Atlantic Ocean and the Gulf of Mexico ; in the Caribbean',
#  'Husbands and wives should stand by each other throughout their lives.',
#  "I'm taking care of it, you can relax. You can rely on me.",
#  'This soup smacks of fish.',
#  'In the 2015 regional elections, after Tosi was excluded by the Federal Party, Gid',
#  'Have you ever seen an elephant fly?',
#  'These are the same or similar protocol specifications that cover the open space as AMQP :',
#  'The township occupies the southwestern corner of Fulton County, bordered to the west by Franklin County',
#  'It was the last edition in which cyclists participated in commercial teams of 1969, used on national',
#  'It is snowing in Paris.',
#  "She doesn't want to judge him.",
#  'On 17 July 2006, López Obrador said in a radio interview with Miguel',
#  'I know that Tom is happy.',
#  'She told me that she would go to Paris in August.',
#  'Some witnesses reported seeing a white powder : TATP is a white crystalline powder.',
#  'Another memorable ruler was Max Franz ( founded 1784 -- 1794 ) who ruled the university',
#  'Does the room have a bath?',
#  'There is nothing inside.',
#  "I'd rather be home.",
#  'Tom told me that he thought Mary was irritated.',
#  "Don't mention the matter to him.",
#  "I should've invited Tom.",
#  'Radhika Rajamani of " Rediff \'\' gave 3 out of 5 stars and',
#  'At the time, the preferred treatment method was active medication.',
#  'He was seized with sudden chest pains.',
#  'Galinoporni is a southern village in Cyprus, located on the Turkish Cypri',
#  'Dean wrote a story and a song for the cat, and the two began a partnership,',
#  'Tom is talking to Mary.',
#  "These aren't fish.",
#  'Rabbi Levi taught that on the night described in God, Jacob showed all the signs',
#  'What is the best way to eat fruit?',
#  'After the partition of India in 1947, Bade Ghulam returned to his hometown Kas',
#  'I never concealed anything from you.',
#  "Let's break for tea.",
#  "I've never met anybody like you.",
#  'All people are good at the heart of their souls.',
#  "Joe Joe feels betrayed and decides to join Gallagher's escape plan.",
#  'The definition can be extended to standard or nonstandard points ( arbitrary ) as follows :',
#  'How is Tom related to you?',
#  'The NBA season from 1982 to 83 was the 37th season of the National Basketball Association.',
#  'I hated him.',
#  "I don't know what it's about.",
#  'Tom likes fishing.',
#  'According to the U.S. Census Bureau, the county is a total surface area of',
#  "We've been helping Tom.",
#  "We're all agreed on that, he said.",
#  'Writing with chalk is trivial.',
#  'He captained South Africa in Kimberley on 29 August 1891 against the British Isles.',
#  'Tom kept running.',
#  'Andrea Dovizioso remained with Ducati for the 2015 season, with Andrea',
#  '" Purple Clover \'\' describes the site as for people who are `` still curious, still cool',
#  ...]

# %%
test_combined_en['bart_paraphrases'] = bart_paraphrases

# %% [markdown]
# ## Computing metrics over BART paraphrases

# %%
Jaccard_1 = []
bleu_1 = []
bleu_2 = []
bleu_3 = []
rouge_l = []


for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['bart_paraphrases'][n]
  #lexical-syntactical variation metrics
  rouge_l.append(rouge_score(candidate, reference,ngram='l' ,metric='f'))
  bleu_1.append(bleu_score(candidate, reference, ngram=1))
  bleu_2.append(bleu_score(candidate, reference, ngram=2))
  bleu_3.append(bleu_score(candidate, reference, ngram=3))
  Jaccard_1.append(jaccard_similarity(candidate, reference, ngram=1))
# Out:
#   0%|          | 1/5000 [00:00<21:40,  3.84it/s]/usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 100%|██████████| 5000/5000 [00:10<00:00, 457.49it/s]

# %%
test_combined_en['bleu_1'] = bleu_1
test_combined_en['bleu_2'] = bleu_2
test_combined_en['bleu_3'] = bleu_3
test_combined_en['rouge_l'] = rouge_l
test_combined_en['jaccard_1'] = Jaccard_1

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                        bart_paraphrases    bleu_1    bleu_2  \
# 0     The chapel and the hall were both fully funded...  0.888889  0.823529
# 1                                   This is not my key.  0.833333  0.600000
# 2                                    He is a biologist.  1.000000  1.000000
# 3          I haven't read all the books on the shelves.  1.000000  1.000000
# 4                                 He is faster than me.  0.427848  0.205367
# ...                                                 ...       ...       ...
# 4995              Tom and Mary said they're not hungry.  1.000000  1.000000
# 4996                        I went swimming in the sea.  1.000000  1.000000
# 4997                             I'm not too surprised.  1.000000  1.000000
# 4998   I think you could've been more patient, he said.  0.750000  0.636364
# 4999                          Tom denies that he cried.  1.000000  1.000000
#
#              bleu_3   rouge_l  jaccard_1
# 0      7.500000e-01  0.928571   0.812500
# 1      2.500000e-01  0.666667   0.714286
# 2      1.000000e+00  1.000000   1.000000
# 3      1.000000e+00  1.000000   1.000000
# 4     1.142391e-308  0.571429   0.454545
# ...             ...       ...        ...
# 4995   1.000000e+00  1.000000   1.000000
# 4996   1.000000e+00  1.000000   1.000000
# 4997   1.000000e+00  1.000000   1.000000
# 4998   6.000000e-01  0.750000   0.750000
# 4999   1.000000e+00  1.000000   1.000000
#
# [5000 rows x 7 columns]

# %%
cosine_similarities = []
for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['bart_paraphrases'][n]
  cosine_similarities.append(cosine_similarity(candidate, reference))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 100%|██████████| 5000/5000 [15:55<00:00,  5.23it/s]

# %%
cosine_similarities
# Out:
# [0.8911691308021545,
#  0.9903277158737183,
#  1.0000001192092896,
#  1.0,
#  0.8351850509643555,
#  0.7071976065635681,
#  0.8033717274665833,
#  0.9523603916168213,
#  1.0000001192092896,
#  0.7871351838111877,
#  0.9563596844673157,
#  0.8107166290283203,
#  0.9999999403953552,
#  1.0,
#  0.942598819732666,
#  0.9999999403953552,
#  0.7531691789627075,
#  1.0,
#  1.0000001192092896,
#  0.9580051302909851,
#  1.0000001192092896,
#  0.792489230632782,
#  0.898823618888855,
#  0.9910138845443726,
#  0.9999998807907104,
#  1.0,
#  0.6816774606704712,
#  1.0000001192092896,
#  0.9054992198944092,
#  0.9293562173843384,
#  0.881113588809967,
#  0.8320733308792114,
#  0.7854591012001038,
#  0.9999999403953552,
#  0.9790887832641602,
#  0.8979122042655945,
#  1.0,
#  0.8756097555160522,
#  0.9999999403953552,
#  0.9999999403953552,
#  0.964002788066864,
#  0.8716351389884949,
#  0.9435681104660034,
#  1.0,
#  0.8752878904342651,
#  0.9939123392105103,
#  0.8455442190170288,
#  1.0,
#  0.9999999403953552,
#  0.8914995193481445,
#  0.7290793061256409,
#  0.8146786689758301,
#  0.8272390365600586,
#  1.0,
#  0.9023057222366333,
#  0.9472194910049438,
#  0.8789151310920715,
#  0.9999998807907104,
#  1.0,
#  1.0,
#  0.9999998807907104,
#  0.8667032718658447,
#  0.9999999403953552,
#  0.9999998807907104,
#  0.7644156217575073,
#  0.8616458773612976,
#  0.9057366847991943,
#  0.9999998807907104,
#  1.0,
#  1.0,
#  0.8255950808525085,
#  0.9999998807907104,
#  0.8461644649505615,
#  0.9819613695144653,
#  1.0,
#  0.8279491662979126,
#  0.8630738258361816,
#  0.994898796081543,
#  1.0,
#  0.8165678977966309,
#  0.9999998807907104,
#  0.958791196346283,
#  0.9999999403953552,
#  0.8567655086517334,
#  0.7579782009124756,
#  0.7402014136314392,
#  0.8011524081230164,
#  0.6831308007240295,
#  0.9999999403953552,
#  1.0,
#  1.0,
#  1.

#  0.9999999403953552,
#  1.0,
#  0.9999999403953552,
#  0.9999999403953552,
#  1.0,
#  0.9650061726570129,
#  0.8959924578666687,
#  1.0000001192092896,
#  0.9960198998451233,
#  0.9999998807907104,
#  0.6766205430030823,
#  1.0,
#  0.9930983781814575,
#  0.8897683620452881,
#  0.9132295846939087,
#  0.9927881956100464,
#  1.0000001192092896,
#  0.8384538888931274,
#  1.0,
#  1.0000001192092896,
#  0.9409729242324829,
#  0.7850845456123352,
#  0.9999998807907104,
#  0.9901692867279053,
#  0.9755907654762268,
#  0.9847237467765808,
#  1.0,
#  0.9999999403953552,
#  0.7250044345855713,
#  0.8798913955688477,
#  0.9999998807907104,
#  0.9093777537345886,
#  0.6631168127059937,
#  1.0,
#  0.9999999403953552,
#  0.9516467452049255,
#  0.6852877140045166,
#  0.7677953243255615,
#  1.0,
#  0.9864770770072937,
#  1.0000001192092896,
#  0.9123228788375854,
#  0.8991676568984985,
#  0.9967753887176514,
#  0.9999999403953552,
#  0.9243321418762207,
#  0.9999999403953552,
#  1.0,
#  1.0,
#  0.6907296180725098,
#  0.9999999403953552,
#  0.8572542071342468,
#  0.9999998211860657,
#  0.9638552665710449,
#  0.9999999403953552,
#  0.8855077028274536,
#  0.8937258124351501,
#  ...]

# %%
len(cosine_similarities)
# Out:
# 5000

# %%
test_combined_en['cosine_similarities'] = cosine_similarities

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                        bart_paraphrases    bleu_1    bleu_2  \
# 0     The chapel and the hall were both fully funded...  0.888889  0.823529
# 1                                   This is not my key.  0.833333  0.600000
# 2                                    He is a biologist.  1.000000  1.000000
# 3          I haven't read all the books on the shelves.  1.000000  1.000000
# 4                                 He is faster than me.  0.427848  0.205367
# ...                                                 ...       ...       ...
# 4995              Tom and Mary said they're not hungry.  1.000000  1.000000
# 4996                        I went swimming in the sea.  1.000000  1.000000
# 4997                             I'm not too surprised.  1.000000  1.000000
# 4998   I think you could've been more patient, he said.  0.750000  0.636364
# 4999                          Tom denies that he cried.  1.000000  1.000000
#
#              bleu_3   rouge_l  jaccard_1  cosine_similarities
# 0      7.500000e-01  0.928571   0.812500             0.891169
# 1      2.500000e-01  0.666667   0.714286             0.990328
# 2      1.000000e+00  1.000000   1.000000             1.000000
# 3      1.000000e+00  1.000000   1.000000             1.000000
# 4     1.142391e-308  0.571429   0.454545             0.835185
# ...             ...       ...        ...                  ...
# 4995   1.000000e+00  1.000000   1.000000             1.000000
# 4996   1.000000e+00  1.000000   1.000000             1.000000
# 4997   1.000000e+00  1.000000   1.000000             1.000000
# 4998   6.000000e-01  0.750000   0.750000             0.870027
# 4999   1.000000e+00  1.000000   1.000000             1.000000
#
# [5000 rows x 8 columns]

# %%
test_combined_en.to_csv('/content/drive/MyDrive/working_directory/tfm/models evaluation/bart_evaluation.csv', index=False)

# %%
test_combined_en['bleu_1'].describe()
# Out:
# count    5000.000000
# mean        0.811152
# std         0.224819
# min         0.016960
# 25%         0.651439
# 50%         0.894839
# 75%         1.000000
# max         1.000000
# Name: bleu_1, dtype: float64

# %%
test_combined_en['bleu_2'].describe()
# Out:
# count     5.000000e+03
# mean      7.402258e-01
# std       2.738232e-01
# min      6.374943e-309
# 25%       5.078890e-01
# 50%       7.829844e-01
# 75%       1.000000e+00
# max       1.000000e+00
# Name: bleu_2, dtype: float64

# %%
test_combined_en['bleu_3'].describe()
# Out:
# count     5.000000e+03
# mean      6.852139e-01
# std       3.225868e-01
# min      4.492347e-309
# 25%       4.178112e-01
# 50%       7.142857e-01
# 75%       1.000000e+00
# max       1.000000e+00
# Name: bleu_3, dtype: float64

# %%
test_combined_en['rouge_l'].describe()
# Out:
# count    5000.000000
# mean        0.835335
# std         0.187984
# min         0.000000
# 25%         0.705882
# 50%         0.888889
# 75%         1.000000
# max         1.000000
# Name: rouge_l, dtype: float64

# %%
test_combined_en['jaccard_1'].describe()
# Out:
# count    5000.000000
# mean        0.825280
# std         0.198060
# min         0.066667
# 25%         0.666667
# 50%         0.888889
# 75%         1.000000
# max         1.000000
# Name: jaccard_1, dtype: float64

# %%
test_combined_en['cosine_similarities'].describe()
# Out:
# count    5000.000000
# mean        0.900740
# std         0.094167
# min         0.100092
# 25%         0.850200
# 50%         0.914487
# 75%         0.983810
# max         1.000000
# Name: cosine_similarities, dtype: float64

# %% [markdown]
# Cosine similarity filters + Counts

# %%
test_combined_en_filter1= test_combined_en[test_combined_en['cosine_similarities'] > 0.5]

# %%
test_combined_en_filter2= test_combined_en[test_combined_en['cosine_similarities'] > 0.7]

# %%
test_combined_en_filter3= test_combined_en[test_combined_en['cosine_similarities'] > 0.9]

# %%
print(len(test_combined_en_filter1),len(test_combined_en_filter2),len(test_combined_en_filter3))
# Out:
# 4985 4820 2820

# %% [markdown]
# #mT5

# %% [markdown]
# ## mT5 paraphrase inference

# %%
# !pip install simpletransformers
# Out:
# Downloading config.json:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.51G [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/332 [00:00<?, ?B/s]

# %%
import logging
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args
import sklearn

# %%
mt5_model = T5Model(
    "t5",
    '/content/drive/MyDrive/working_directory/tfm/Distilled_mt5_finetuning/mt5_outputs/best_model'
)

# %%
def get_response_mt5(input_text):
  generated_sentence = t5_model.predict([input_text])
  return generated_sentence[0]

# %%
mt5_paraphrases = []
for original_sentence in tqdm(test_combined_en['Text']):
  paraphrases = get_response_mt5(original_sentence)
  bart_paraphrases.append(paraphrases[0])
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# 100%|██████████| 5000/5000 [3:40:38<00:00,  2.65s/it]

# %%
mt5_paraphrases
# Out:
# ['William Gibbs fully funded the Chapel and Hall, and Butterfield designed them.',
#  "This isn't my forte.",
#  'He is a biologist.',
#  "I haven't read all of the books on the shelves.",
#  'He can run faster than I can.',
#  'Arnold had already been sent to Skenesboro and Asa Douglas to Panton with sections to hold boats when Samuel Herrick arrived.',
#  'The album also received "early" great support throughout Europe, according to Jon Uren, marketing director of Warner Music Europe.',
#  'After Mary, Tom took off.',
#  'She has already lived in the town for five years.',
#  'I think wine is good.',
#  'What are you smiling about?',
#  'However, nationalist groups, along with other liberal groups, said they would boycott the July elections.',
#  'Tom asked him not to be disturbed.',
#  'Tom changed his clothes.',
#  "The 1980 - 1981 Toronto Maple Leafs season was the franchise's 54th season and the Maple Leafs' 64th season.",
#  "I've met a nerd.",
#  'The following 13 ranchos were granted in Napa County during the period between 1836 and 1846, when California became a province of independent Mexico.',
#  "Tom thinks I'm an idiot.",
#  'Thank you for your note.',
#  'Where did she learn to dance?',
#  'I talk fast.',
#  "Holden Ford's character is based on FBI - Agent John E. Douglas, and Bill Tench is based on a pioneer - FBI - Agent Robert K. Ressler.",
#  'The two terms are now used in other parts of the country.',
#  'They told everyone they were suspicious.',
#  'That is not a horse, but a donkey.',
#  'Tom is planning to attend your wedding.',
#  "I can't express myself in English very well.",
#  'Good. No absentees.',
#  'The 17th, 9th, and 6th districts serve Center City.',
#  'After Saturday, Sunday is the day after.',
#  "She'll be married to him for ten years in a row.",
#  'We are all manifest ideas of the one true spiritual Mind, and divine Spirit, not a physical body, according to the findings.',
#  'Blauburger produces good yields and is particularly susceptible to "Botrytis cinerea", but is resistant to mildew.',
#  'She knows nothing about your family.',
#  'She was clad in a red blouse and a black skirt.',
#  'Rebecca stays in Summer Bay for the school holidays after Donald explained everything about Bobby and Morag.',
#  'I am only Italian.',
#  'In Romania, the river Tătaru is a tributary of the Buzăiel River.',
#  "I can't wait until tomorrow.",
#  'I noticed immediately that he was feeling ill at ease.',
#  'Tom usually sleeps for eight hours.',
#  'In 1881, Georges Merle died in Paris, and his son Hugues Merle became a painter.',
#  "I'm sure she won't come to see you.",
#  'All weekend, I waited for a call.',
#  'San Pedro Springs Park is located in the town of Bexar County, Texas, in the United States state of Texas.',
#  "Because I haven't seen the list yet, I can't tell you who's on it.",
#  'My entire body hurts.',
#  "Because I had a cold, I didn't call him.",
#  "Tom said it's impossible.",
#  'Antony died on November 6th, 1620, and was buried in the Carew church on November 7th.',
#  "People shouldn't abuse animals.",
#  'The constituency is in South Wales, on the right bank of the River Afan, near its mouth in Swansea Bay.',
#  'It is important to achieve the thermal stability of the Quantum Oscillator, so that mechanical noise reductions are minimized on the device.',
#  'Why is Tom not eating?',
#  'Vicki S. Bull ( "Victoria" ) was born in 2001 as Vicki\'s sister, but she has been missing for many years.',
#  'Believe what you want.',
#  'North East was a former station north of Seymour, near the junction of the Mangalore and Shepparton lines.',
#  'Would you like me to stay?',
#  'Why not try some clothes on?',
#  "I think it's a great idea.",
#  'I met her last winter.',
#  'The San Jose, California, campus was relocated to Milpitas, California, in 2016.',
#  'Tom lives outside the city.',
#  'He finally decided to propose to her.',
#  'I forgot my PIN number!',
#  'On April 10, 1562, Toulouse delivered a copy of the letter to Montpellier.',
#  'Bill Malina performed additional mixing with Rice and Ghazi Hourani, who also participated in the preparation.',
#  'The residents blasted the noise.',
#  'I have no one to blame but myself.',
#  'She has a heart disease.',
#  'Is Tom really stuck?',
#  "You can't afford to lose money.",
#  'China, 1843: After a confrontation between Americans and Chinese, sailors and Marines from St. Louis were landed at the Canton trading station.',
#  "Some people take a bath every day, while others don't.",
#  'Is it possible to arrive tomorrow?',
#  'The Werris Creek to North Star line was transferred to the ARTC in July 2011.',
#  'In television archives, only six episodes survive, one from the third and fourth series, two from the first and one from the final series.',
#  "Tom isn't afraid of spiders.",
#  'He did what he could for his children.',
#  'In Romania, the JieT is a tributary of the River Slivei.',
#  "Tom hasn't been expelled yet.",
#  'Wine brings joy to the human heart.',
#  'He was not disappointed.',
#  'This will be the best.',
#  'On July 30, 2008, a beta version of the app was launched. Windows Live Frame was discontinued on December 15, 2010.',
#  'We just need a little bit of time.',
#  'The school is affiliated with the autistic school Ysgol Plas Brondyfryn, which was established in 2003.',
#  'The botanist Aaron Davis and the gardeners John Grimshaw and Matt Bishop are also applicable as galanthophiles.',
#  'There is no other dog that is as big as this.',
#  "I'll take Tom's place.",
#  'I have enough money to buy a car.',
#  'I tried to flee.',
#  'Mudzuri defeated ZANU-PF candidate Amos Midzi in the March 2002 mayoral election by a large margin, receiving 262,275 votes against 56,796 votes for Midzi.',
#  'I did the work against my will.',
#  "Let's talk about it.",
#  'Buccinum parvulum is a species of sea snail, a true gastropod mollusk in the Buccinidae family, the whelks marine family.',
#  'What are the most popular genres of songs these days?',
#  'Is he swimming?',
#  'Tom may be confused.',
#  'The author translated the fairy tale into our mother tongue.',
#  'The tournament was revived in 2006 in San Francisco, where it was held for two years.',
#  'What a beautiful spot!',
#  'How did the two meet each other?',
#  'Kathy Lloyd was born in Carrickfergus, Northern Ireland, and grew up in Netherton, Bootle, where she attended Warwick Bolam High School.',
#  'Tom came with us.',
#  'Tom will try.',
#  'I saw a cat running after the dog.',
#  'It was first published in November 1961 by Irma Thomas and was later released by Allen Toussaint.',
#  'Tom is also sleeping.',
#  '" Darn That Dream" is a popular song written by Eddie DeLange and lyrics by Jimmy Van Heusen, which was released in 1939.',
#  'How do we get home?',
#  'I agree with your plan.',
#  "Tom isn't enthused, isn't he?",
#  'Maughan and his partner, the former Lorraine Hannemann of Manhattan, New York, live in Honolulu, Hawaii.',
#  'I have hard stools.',
#  'I discovered something.',
#  'She is worried about her health.',
#  'Humor me, I say.',
#  'Two weeks before the invasion, Omar Bradley pulled the corps out of the First Army and into the Third Army.',
#  'Olivella kifos is a dwarf sea snail, a small gastropod mollusk in the Olivellidae family, the navy olives.',
#  "I'm considering switching majors.",
#  "Tom must've had his reasons.",
#  "Who'd have predicted this?",
#  'He came to the Serbian ajkai in Komárom in 1739 as a well-known speaker ( " slavni propovednik") during religious persecutions.',
#  'In various countries, the car was sold under different names.',
#  'Yesterday, I went to the cinemas.',
#  "Raumanga is a suburb of Raumanga in New Zealand's Northland Region. The main campus of Northland Polytechnic is located in Whangarei.",
#  'Is there a grocery near here?',
#  'Owen Bradley recorded "Thank Schoen" for her 1964 album " By Request", which was produced by Brenda Lee.',
#  "The loyalists based on the west side of the Catawba River were stationed, while General Charles Cornwalli's army stationed on the east side.",
#  'Back Street was a 1961 film produced by David Miller and Ross Hunter, directed by Universal Pictures, and directed by David Miller.',
#  'What is your area of expertise?',
#  'In the school case, Danielle, Nadine, and Mark have seen their pictures.',
#  'Bas 90 was introduced in the 1970s and 1980s.',
#  'It has greatly improved over time as compared to what it was.',
#  "The news of his son's death was a shock.",
#  'It is only found in Yunnan and its tributaries in Lake Dianchi, China.',
#  'I saw that it snowed for four days from the 14th to the 17th month of the year.',
#  'She gave him all of her money.',
#  "They won't take him back.",
#  'On July 1, 2004, the British Transport Police Police Authority was established.',
#  'Scouting in Malaysia (now YMCA) was first introduced in Malaya in 1908 as an experimental troop in Penang before spreading throughout the peninsula.',
#  'Louise Fitzhugh wrote and illustrated Suzuki Beane in 1961, and it was published in 1961.',
#  'For a second, I need you.',
#  "I'm not your tutor anymore.",
#  'In the semi-finals, the teams meet in second place in the pools, the first place from the other pool.',
#  'In Turkey, Mount Sis is also known as "Siss Da Yaylas."',
#  'What do you get?',
#  "Doesn't Mary look lovely?",
#  'Shimla is a major suburb of Sanjauli, in the Shimla district of Himalayan Pradesh, India.',
#  'Cassandra Peterson appeared in "All about the Good" of Peaches Christ with Patrick Bristow, Mink Stole, and Brown.',
#  'The Presbyterian doctrine is "reformed," and the government is "theological."',
#  'I think she likes him.',
#  "The windows should've been washed.",
#  'Please let me drive your brand-new Toyota.',
#  "Linkuwa Pokhari is a village and village development committee in Khotang District in eastern Nepal's Sagarmatha Region.",
#  "I haven't finished reading this book.",
#  "Let's play soccer.",
#  'I like your eyes!',
#  "Tom hasn't been caught yet.",
#  'It was predictable.',
#  'He broke his left wrist.',
#  'In Acquire, 3M agreed to change the name, and Sackson suggested it.',
#  'He has not been involved in the deception, as far as I know.',
#  "He replaced the table's legs.",
#  "I think it's inevitable.",
#  'I came to you for the reason.',
#  "You're going nowhere.",
#  'The county has a total area of, of which land and ( 17.6 percent) is water, according to the US Census Bureau.',
#  "I was a part of Emperor Matthias' coronation in 1612 and Emperor Ferdinand's election in 1619.",
#  'Jules de Blosseville named the peak after French naval officer Marie Henri Daniel Gauthier, comte de Rigny (1782-1835).',
#  'He died before I was born.',
#  'I have some free time.',
#  "I'm really not sure why I'm so drained.",
#  'Salina is also known as the Grand Island ( of Nebraska ) of the south, according to Louis and Clarke Adventures.',
#  'Esperanto is a fun language to learn.',
#  '"Pueraria montana" grows in a variety of regions in Switzerland and Italy near Lake Maggiore and Lake Lugano in Europe.',
#  'Layla paid for the taxi.',
#  'On campus, there are many student organizations, including academic organizations, religious organizations, and student service groups.',
#  'The association has thirty members.',
#  'Michael Chang defeated Renzo Furlan in the final 3 -- 6, 6, 7 — 5.',
#  'What is your favorite song?',
#  'The film was a lot better than I expected it to be.',
#  'During Lent, my friend fasts.',
#  'Lielplatone parish is an administrative division of the Jelgava Municipality (now the Jelgava District) in Latvia.',
#  'He crept into the castle town, disguised as a peasant, and crept into the castle town.',
#  "Agha Mohammad Khan, Hossein Qoli Khan's brother, was appointed Qoyunlu's new chieftain due to his brother's castration.",
#  'He works with me at the office.',
#  'He was educated in Dresden and Leipzig, and later in 1865 in Leipzig, and in 1869, after a short stay in Weimar, went to New York with Franz Liszt.',
#  'Only the Sara of the south was governed effectively; the French presence in the Islamic north and east was marginal.',
#  'That could be serious.',
#  'I seem to have a temperature.',
#  'Ernst Ernst Maag (Peter Maag) (born 10 May 1919 – 16 April 2001) was a Swiss conductor.',
#  'All of these items are exempt from duty.',
#  'At Waterloo, the French were defeated.',
#  'She lost 50-25 to Zimbabwe, 84-16 to Tanzania, and 58-24 to South Africa during the competition.',
#  "I hope it doesn't happen again.",
#  'Tom and Mary are both dissatisfied with each other.',
#  'Martha married George I. Eisenhauer, a man who was discovered by her.',
#  'I dug one up.',
#  'Josef Král of Barwa Addax was replaced by Dani Clos of Ocean Racing Technology in the week leading up to the first race.',
#  "Tom doesn't think you should've done it.",
#  'I want to maintain absolute loyalty among my staff.',
#  'The children are in need of you.',
#  'Please call Tom Mary.',
#  "I can't believe I'm hearing this.",
#  'She is a good deal older than he is.',
#  'I heard you did it, and I believe you did it.',
#  'The A cells produce glucagon, which mobilizes the hepatic glycogen, and the enterochromaffin cells produce serotonin, which stimulates the smooth muscle contraction.',
#  'They had a neighborhood allies, including the collopys ( Brian Collopy and Phillip Collopy ).',
#  'For lunch, she was out of humor.',
#  'I thought Tom was going to break the contract.',
#  "People aren't always rational.",
#  "My father doesn't allow me to drive.",
#  "Tom said he's not going to sing.",
#  'Giovanola also launched the first freefall (designed by Intamin) and the first drop tower.',
#  'In or near Kareedouw, there are medical and pharmaceutical facilities, including the provincial B.J. Vorster Hospital, a public library, and a Lutheran mission monument.',
#  'Wright was British consul-general for the republic of the Seven Islands (Ionian Islands) from 1800 to 04.',
#  'To avoid such deadlock conditions, a proposed protocol for the use of sensitive flow control signals should be used.',
#  'Are you happy with the result?',
#  "Aenetus blackburnii (Blackburn's ghost moth) is a Hepialidae family moth that is native to Australia, where it is well-known.",
#  'What made you want to come here now?',
#  'When spring arrived, the snow fell away.',
#  "I'd never seen such an exciting rugby match as yesterday.",
#  'Since the 2007 tournament, Italy qualified for the 2009 European Baseball Championship, while the other qualifiers included the Netherlands, Sweden, Spain, Germany, France, and Great Britain.',
#  'How was the party?',
#  "I've got to get it fixed.",
#  'We will carry you.',
#  'Our roof was blown off.',
#  'In the state, one person was killed indirectly and two others were killed immediately as a result of the storm.',
#  "You're worth more than gold.",
#  'Tom has already finished his lunch.',
#  'Why are you always yelling?',
#  'I no longer have to wear glasses.',
#  'Jarymowycz was a lecturer at the Royal Military College and a regular contributor to letters to the editor.',
#  'As a child, he moved south to the Wiseton Estate in Gosforth, Northumberland, near Retford, Nottinghamshire, where his father found employment.',
#  'Tom listened with curiosity.',
#  "She doesn't pay much attention to how she dresses.",
#  "This isn't a positive sign.",
#  'Director Albert Pyun, who had previously worked at Cannon, was recruited and worked with the Tolkin script that first appeared at Cannon.',
#  'He died on July 23 in Trenton on his home and is buried at the Old Broad Street Presbyterian Church and Cemetery in Bridgeton.',
#  "I know what you're thinking about it.",
#  "Tom isn't going to be there for us today.",
#  'The Messent Peak and the Brodie Peak are among the Bristly Peaks on the planet.',
#  'Barbara Rogowska, a Polish actress, comedian, and celebrity, was born on June 19, 1953.',
#  'In the 1990s, new teaching facilities were established in Ivrea, Mondov, Biella, Alessandria and Vercelli.',
#  'The original Barron Collier Bridge was added in 1931, followed by the new Barron Collier Bridge and the Gilchrist Bridge that crossed the Peace River.',
#  'The IndieWebCamp community first published the Webmention and it was published on January 12th, 2016 as a W3C work draft.',
#  'Pedro ended up with many other children in the care of a man named Sebastian.',
#  "I'm sorry you're staying here.",
#  'They account for 13 percent of the population in Klaipda and 28 percent in Vilnius.',
#  "Tom's heart was broken.",
#  'Kate is a natural performer.',
#  'I may be able to help.',
#  'The car is waiting at the gate.',
#  "The arrangement was later attributed to Jimmy Webb's career, as has been said.",
#  'The visitors were led round the museum by a guide.',
#  'On the south coast of Livingston Island in the South Shetland Islands, Antarctica, the Hurd Peninsula is located between South Bay and False Bay.',
#  'Tom and Mary are no longer children.',
#  'Be careful not to insult Tom.',
#  "I'm not that drunk.",
#  'We are not cowards.',
#  "I don't want to meet with him again.",
#  'Last Sunday, I was free.',
#  'Tell me about your day to day life.',
#  'He lives in Noah and Mabel with his partner Lucy and their children.',
#  'Tom got it wrong.',
#  "She's a tease.",
#  'She needs someone to help her.',
#  'It was a very, very hot night.',
#  'Ceramic, carbon, metal, and aramid fibers, such as Twaron or Kevlar, are now used as asbestos substitutes.',
#  'You seem to be a little drained.',
#  'The job would be difficult.',
#  'They said they were afraid.',
#  'Corozal is a town and municipality in the Sucre district of northern Colombia.',
#  "I didn't speak with him.",
#  'I began to cry as well.',
#  'The wind is blowing fast.',
#  'I can accept that.',
#  'I am thirsty, so please give me something cold to drink.',
#  'Maria Maria Rossa Argento (born September 20th, 1975 in Aria Asia Argento) is an Italian actress, singer, model, activist, and film producer.',
#  "I'll be in touch with you shortly.",
#  "His old clunker isn't much more valuable.",
#  'The concordant Greek text is the basis for the concordant literal New Testament, which is more idiomatic in its English than the hyperliteral Sublinear.',
#  'Kendra Saunders is now 100 percent Hawkgirl.',
#  "Is Tom persistent? Isn't he?",
#  "Tom's father left his family.",
#  'What is it really about it?',
#  'We have to do this together.',
#  'The weather became cold after a string of warm days.',
#  "Let's go see them.",
#  'Tom wanted to know the source of the accident.',
#  'The name and lyrics refer to Leonardo da Vinci\'s renaissance portrait " Mona Lisa" in the title.',
#  'She traveled to Russia, Finland, Italy, France, Scotland, Estonia, Germany, and Iceland in 1923 as a reporter.',
#  'There is no comment.',
#  "Tom had no trouble finding Mary's house.",
#  'We are now all alone.',
#  'Mary admitted that she was wrong.',
#  'You have to work.',
#  'The website "Purple Clover" describes it as a place for people who are "... still cool, still curious, and still crazy after all these years."',
#  'Herbie Matthews, his son, also received a Brownlow Medal, and his grandson of the same name played with South Melbourne later that year.',
#  "I promise you, I'll never do it again.",
#  'Mike Parlett (also known as Michael J. Parlett) is an English jazz saxophonist, producer, and radio moderator.',
#  'Tom was adamant about his message.',
#  'I was trying to find Tom.',
#  'Carl Smestad (born May 8th, 1888, to Jacob Olssad) was a Norwegian industrialist, son of Reidar Smestad and grandson of Jacob Olssad.',
#  'Lie on the exam table.',
#  'Why not have a cup of coffee?',
#  'Tom has a slew of books.',
#  'According to a recent survey, the average life span of the Japanese is also increasing.',
#  "I don't want to lie to them.",
#  'Both Tom and Mary want it.',
#  'You made a wise decision.',
#  'The Valea Voenilor River is a tributary of the Pascu River.',
#  "Ask Tom if he'll do it.",
#  'Taft served as Chief Justice until his death in 1921, when he was succeeded by White.',
#  'They are related.',
#  'William de Middleton (or William Middleton; born 31 August or 1 September 1288) was a medieval Bishop of Norwich.',
#  "Tom and Mary's marriage was kept secret from their parents.",
#  'No passengers were injured in the crash.',
#  'Mum is the correct word.',
#  'The following table shows the results of the LOD - capable rendering and the brute - detail technique ( full force).',
#  'He is two years older than I am.',
#  "Near Wellington's first railway station, Pipitea Point, were the first railway workshops in the Wellington area.",
#  'When she heard the news, she burst into tears.',
#  "It's impossible to quit smoking.",
#  'The latest tablet costs an arm and a leg.',
#  'Tom died in Boston in 2013.',
#  'Mount Cobb is a mountain on Vancouver Island, British Columbia, Canada, east of the Gold River and southwest of Mount Filberg.',
#  'Only about one percent of natural diamonds are of this species, and the majority are blue to gray.',
#  "He's the tallest in our class.",
#  'You may come if you so desired.',
#  'Tom screamed and left.',
#  'Dennis is angry with Mr Wilson, as shown by his wife.',
#  'SAP announced George X and Manny Rodriguez as the Spanish commentators for Premier Boxing Champions on Spike TV in 2015.',
#  "He joined the San Diego Sockers' Professional Arena Soccer League in 2009.",
#  "They said they'd laugh.",
#  'This is the root of the problem.',
#  'Bill brought me the book.',
#  'When I saw them on a date, I asked them, "Do I hear wedding bells?"',
#  'Franz Ferdinand\'s last words were " Sophie, Sophie!" as Count Harrach reported.',
#  "He's been dead for ten years.",
#  'Infer also has a domain abstract language for specific syntax tree linting, based on concepts from Model Checking for Computation Tree Logic.',
#  'Pérez also worked with Telemundo Internacional, where she hosted and produced an entertainment segment.',
#  'It also hosts the unincorporated towns of Redwood Valley, Calpella, Potter Valley, and Talmage.',
#  "Don't disturb the others.",
#  'Ardning is a municipality in the Austrian province of Liezen in the district of Styria.',
#  'He named his dog Popeye.',
#  'The potassium salt is isostructural with.',
#  "From December 22nd to April 1814, French forces assaulted the fortress, under General Zoller's command, before the Bavarian garrison capitulated.",
#  'The pain was agonizing.',
#  '"AllMusic"\'s Eduardo Rivadavia gave "Restless and Wild" 4.5 out of 5 stars and praised it as a "creative breakthrough."',
#  'Lucas is a clever clog.',
#  'I love your town.',
#  'Tom remained seated.',
#  'The 1988 season -- the 89 National Basketball Association -- was the 43rd NBA season.',
#  "You're a master at it.",
#  'Hopewell Island, Charles City County, Virginia, is a small island with a historic home and archaeological site near Eppes Island.',
#  "I'd like to try on this skirt.",
#  "We're putting in a lot of effort.",
#  'How does it all end?',
#  'This is something that is not often seen.',
#  'The soundtrack was composed by musician Wajahat Attre, with lyrics by Noor Jehan, and Mehnaz, and sung by Hazin Qadri.',
#  'The Final FESPIC Games had 18 venues, 9 in Selangor, 7 in Kuala Lumpur, and 1 in Putrajaya and Negeri Sembilan, respectively.',
#  'The dull hexahexagonal tiling has a hyperbolic tiling of the single plane in geometry, it is Schläfli - the symbol of sr ( 6,6 ).',
#  'I designed it.',
#  'She is conceited, as is common among teenagers aged 13 to 19.',
#  "I can, although I can't speak Shanghainese.",
#  'This is war.',
#  'Where did you park the car?',
#  'He wanted it.',
#  'He lived in Harrogate, North Yorkshire, from 1996 to 1999, after completing his undergraduate studies at Cardiff University and Rouen, France.',
#  'Henry Wheeler Shaw (1818-1885) became a well-known humorist under the name Josh Billings (also known as Josh Billings).',
#  'He also played in 53 games for the Piedmont League ( Greensboro Patriots), with a 26- 19 record over the seasons 1928 and 1929.',
#  "They said they weren't too busy.",
#  'Go upstairs and go to bed.',
#  'It took me by surprise.',
#  'Each line has three points, so the Hesse configuration has the notation 912 in the language of configurations.',
#  "I'm calling from Tom's cell phone.",
#  'Tom stood still.',
#  'I should have told someone.',
#  "Is Tom trustworthy? Isn't he?",
#  "I can't raise our child by myself.",
#  'Yesterday, I went to the beach.',
#  'I want her to win.',
#  'Matter can be solid, gaseous, or liquid.',
#  'It is about 4 miles east of Caernarfon, 7 miles south of Bangor, and 3 miles northwest of Llanberis.',
#  'It is located at 142 South Rexford Drive in Beverly Hills, California, opposite the First Church of Christ, Scientists.',
#  'Mid Wales Hospital, which was originally known as the Brecon and Radnor Joint Counties Lunatic Asylum, was a psychiatric hospital in Talgarth, Wales.',
#  'Steve Reicher ( Stephen D Reicher ) is a Professor of Social Psychology and former Head of the School of Psychology at the University of St Andrews.',
#  'Tom was thirty years old at the time.',
#  'The interpreter provides her own personal interpretation.',
#  'He just left.',
#  'He lost all of his possessions.',
#  'He asked me to pay the money back immediately.',
#  'He is a poet by birth.',
#  'He is a Baroque and contemporary music composer.',
#  'In the first week of March 2011, the Finnish album "Deathstar Rising" made it to the Top ten and reached #8.',
#  'Tom will explain.',
#  'I am not content with the end result at all.',
#  'He is expected to win the speech competition, according to reports.',
#  "Wendy, I'd like you to meet my brother Sam.",
#  "I'll never be able to play again.",
#  "The National Audubon Society's Hog Island chapter is a center and camp in Maine.",
#  "They promised that they'd be here.",
#  "I've seen you someplace.",
#  "By 2:30 p.m., you're supposed to be here.",
#  'English is a simple language to learn.',
#  'This is untrue.',
#  'She opens her birthday present.',
#  'Spencer Machacek was traded to the Columbus Blue Jackets on February 6, 2014, in exchange for Thompson.',
#  '"Myles C. Fox" reached Yokosuka on September 23 and left San Diego on October 8th.',
#  "That's all it is.",
#  'He said he would be late.',
#  "Mornington House was the Earls of Mornington's social season Georgian residence in Dublin.",
#  "The Astors settled in North America, first appearing in Germany in the 18th century with John Jacob Astor, one of history's richest people.",
#  'In 2013, the ABC - Drama - Pilot "Westside" was announced and produced by Ilene Chaiken, and he received beals for the main role in 2013.',
#  'I did what she told me to do.',
#  'I like to watch a baseball game.',
#  'Can I just stay and help?',
#  'The poor man has no relatives.',
#  'The strong winds were blowing.',
#  'Tom nodded his head and left.',
#  'Insatiably greedy.',
#  "I was given a famous singer's autograph.",
#  'Chabrian Jattan is a village in the Mirpur district of Azad Kashmir, Pakistan.',
#  'He said he was thirsty.',
#  "Don't fuck it up!",
#  'I am completely ignorant of the scheme.',
#  'Vultures circled over the dead body.',
#  'Tom seems to be having a good time.',
#  'The official language is Bhojpuri, while the local language is Hindi.',
#  'He is a fake.',
#  'You may not know what Esperanto is like?',
#  "You aren't afraid of ghosts, isn't it?",
#  'Lilly will return to the World Curling Tour in 2014 for her first season with Sarah Potts, Oye-Sem Won Briand, and Tirzah Keffer.',
#  'Tom knew that Mary would not win.',
#  'According to a newspaper story about the case, "The library is a dream in architectural splendor and a model in interior."',
#  'Philander Montague Wright and his partner, Mary Weeks ( Bracket ) Wright, had the second child and the youngest of four children born.',
#  'Ask him if he comes.',
#  'I want his head.',
#  'Regardless of how complicated the RC network becomes, the open circuit time linear scheme provides the constant term in " j ".',
#  "We've already tried it.",
#  'Dehgh (also known as Dehg h) is a village in Bojnord County, North - Khorasan - Province, Iran, in the Badranlu Rural District of Central District.',
#  'In London, Jones lives with his wife Cheryl, son Nathan, and his three daughters, Ella, Coral, and Holly.',
#  "Don't waste a good opportunity.",
#  'That film is really interesting.',
#  'We finally reached the summit.',
#  "Last night, I didn't get a single snooze.",
#  "This isn't the last train, is it?",
#  'You can wait until the cows come home.',
#  'Have you ever seen a red river?',
#  'Brazilian Portuguese is very different from Portugal Portuguese.',
#  'The magazine was published in Paris, but Gerald Duckworth and Company in London published it.',
#  'Lepel had lost its strategic and economic importance in 1913 and had become a small regional center.',
#  "We should've done it.",
#  'Fred and Elizabeth Goodwill, the youngest children of the farmers, raised Thomas Thomas.',
#  'Tom will most likely cry.',
#  'These enzymes are able to perform enantioselective oxidation of prochiral substrates.',
#  "Don't put me in the middle of it.",
#  "I've never said that!",
#  'We left after Tom made us leave.',
#  'Mary is the laziest of her classmates.',
#  'He assured me.',
#  "I've done nothing extraordinary.",
#  'How long does it take to get to the train station by taxi?',
#  'I walked alone.',
#  'When water is boiled, it turns into steam.',
#  'Tom turned off the lights.',
#  "I'm so glad to visit VNU.",
#  'Tom seems to be rich.',
#  'These allegations are false.',
#  'She committed suicide.',
#  "They don't arrive.",
#  'I suspect I was followed by someone.',
#  'I am ready to die.',
#  'Dragan Umievi (born October 9, 1984 in Dubica, SFR Yugoslavia) is a Serbian ice hockey player of Swedish descent.',
#  'It was your fault, Tom said.',
#  'I just brush it off.',
#  "You should've followed Tom's advice.",
#  'Get on your horse.',
#  'I have a sharp knife.',
#  'Hopkins spent six months with the band in Japan, the United States, and England.',
#  'Simon Brook is the son of director Peter Brook and actress Natasha Parry, while his sister, Irina Brook, is the author and actress.',
#  'I wonder if Tom is content.',
#  'In an eight-man team - match, Valkyrie defeated Amazing Kong, Mia Yim, Christina von Eerie, and Angelina Love in "Shine 8."',
#  'Political parties are factual associations in the majority of European countries to ensure political autonomy.',
#  'Margot A. Thien (born December 29, 1971 in San Diego, California) is an American American swimmer who competes in the synchronized swimming and Olympic championships.',
#  'The first recorded Irish presence in the area of present-day Newfoundland dates back to 1536, when Irish fishermen from Cork travelled to Canada.',
#  'The tire is worn out.',
#  "Do you think I'm to blame?",
#  'Keep an eye on the rocks.',
#  'Susie J. Clarke married Brown in Ayer, Massachusetts, on December 30th, 1888.',
#  'Tom needs some assistance.',
#  'Tom Watson was originally scheduled to defend his Middleweight title against Frank Trigg.',
#  'Tom will most likely be starving.',
#  'The teacher gave us this dictionary.',
#  'Everything is connected to everything.',
#  'Tom thought about Mary a lot.',
#  'In Havana, the Boston Red Sox and Cincinnati Reds met for a second game.',
#  "I'm glad no one is around.",
#  'The two-way route now forms a single route that leads directly from Gothenburg to Newcastle, via Kristiansand, Norway.',
#  'I was in a movie theater.',
#  'In cartography, this procedure is the photographic equivalent of a cylindrical map projection.',
#  'I remember meeting the queen when I was a kid.',
#  'Did you kiss him?',
#  'I had no idea you were coming.',
#  'It made me go crazy.',
#  'The new grammar school was named the Upper School, while the old building was named the Lower School.',
#  'This is a common occurrence that is easy to overlook.',
#  'I know Mary, as Tom and I both know her.',
#  'Something unexpected happened. Suddenly, something unexpected happened.',
#  'Tom looked straight at me.',
#  'Jessica Soho and Mike Enriquez of GMA News, and John Nery, editor of " Inquirer.net," moderated this discussion.',
#  "I'll sing.",
#  'Dennis is arrested and sentenced to death with Hugh and Barnaby, while Hugh and Dennis are hanged. Barnaby is pardoned by Gabriel Varden.',
#  'In Romania, the Slănic River is a tributary of the River Comina.',
#  'Nevertheless, I am incredibly proud.',
#  'Miovi left Serbia in 2002 to escape capture after being involved in organized crime in Sweden.',
#  "Tomorrow, I'll call you.",
#  "Tom says he isn't interested in romance.",
#  'Some authors grouped the species in two groups, naming the Russian and central Asian populations as " Fallopia aubertii" and the Chinese species as " F. baldschuanica."',
#  'My bike has been stolen.',
#  "I haven't seen him in days.",
#  'Tom took a seat across from Mary.',
#  'Were you able to get everything you needed?',
#  'Tom says he did nothing illegal.',
#  'Due to the rain, their trip was postponed.',
#  "The Bearcats' old jersey is that of the Buffalo Sabres from 1996/97-2005/06, with the Bearcats' logo similar to that of the Florida Panthers of the NHL.",
#  'I can walk to school in ten minutes.',
#  'Emu Park was also the intersection of the Central Western Line and the Rockhampton line.',
#  'They went on talking all night.',
#  'You should buy him new toys.',
#  'Hugues Merle died in Paris in 1881, and his son Georges Merle became a painter as well.',
#  'Vermont South is bordered to the north by Mitcham, to the west by Nunawading and Forest Hill, to the south by Wantirna and Ringwood, and to the east by Nunawading and Forest Hill.',
#  'Espuelas worked on the Wunderman, General Foods Gevalia, and Weight Watchers accounts while at American Express.',
#  'They danced.',
#  'You seemed interested.',
#  "I'm not sure what it is.",
#  'Edward Everett bought the manuscript in 1819 from America to Constantinople, along with six other manuscripts ( Lectionary 296, Lectionary 297, and Lectionary 298).',
#  'Prodrive announced in February 2017 that they would compete in the FIA - Rallycross - World Championship in 2018 with a Renault Mégane for Guerlain Chicherit.',
#  "I'm going to need some equipment.",
#  'Do you have a room for yourself?',
#  'Tom gave me something.',
#  'I like coffee much more than tea.',
#  "Don't forget death.",
#  "Tom didn't seem to be too optimistic.",
#  "I'd never do something like that again.",
#  '"Acting for" has the same basic meaning as "acting," except that it indicates that the original occupant of the position is still officially holding control.',
#  'I keep getting spam emails.',
#  'Matt Mariska and Andy Sipes wrote the series, which was created by Mike Roberts and was released in May.',
#  'Can I do anything?',
#  'While watching television, I fell asleep.',
#  'The Viennase ice revue toured through most European countries, including Germany, Italy, the Netherlands, Switzerland, Hungary, Czechoslovakia, Belgium, France, and Spain.',
#  'We are both professors, Tom and I.',
#  'Percy W. Adams married Gwendoline Wright in 1890.',
#  'Hatherley joined KT Tunstall in 2010 as lead guitarist and replacement Sam Lewis.',
#  'Since January 2013, Republican Drew Springer, Jr., a businessman from Muenster, Texas, has represented Cooke County in the Texas House of Representatives.',
#  'He applied for membership to the riding club.',
#  'He has a lot of sense as to why he has such a point.',
#  'By then, three-quarters of Maryland slaves had been released, and a significant number of Delaware slaves had been released.',
#  'Last night, there was a full moon.',
#  "I'm not sure Tom will be able to do so.",
#  "Sami didn't say anything.",
#  'Where are my boots?',
#  "I'm on vacation.",
#  "Wouldn't you like to have tea with me?",
#  'Alejandro Lerner wrote all songs except " A Place Where We Belong" co-written by Graham Russell.',
#  'Milk is a healthy beverage.',
#  'Is Tom partly to blame?',
#  'In order to get a good seat, I arrived early.',
#  'There are four main types of databases: curated databases, predictive databases, literature databases, and integrative databases.',
#  'Has he been found yet?',
#  'This was the first time New Jersey has not voted for the same candidate as the neighboring Pennsylvania, which was also a year earlier.',
#  "You should've done it better.",
#  'On the streets of his town, there were no flowers or trees.',
#  'How does she raise her children?',
#  "You're conscientious.",
#  'He sailed to Belfast in 1933 to join his parents after studying in Shanghai.',
#  'When the card was read into the vehicle, this balance was inserted into the accumulator.',
#  'Natural males with dysmorphic anatomy lack the structure necessary for human embryonic and foetal growth.',
#  "Someone must've followed us here.",
#  'NVIDIA revealed the Nvidia TITAN V.... on December 7th, 2017.',
#  'Why should I study French?',
#  'Tom died suddenly.',
#  'She also lost both of her parents.',
#  "Valerin's castle is confiscated, he is shot, and the queen is released.",
#  'Tom will most likely be up.',
#  'Thomas Edward Donne (1860–45) was a New Zealand civil servant, author, fine hunter, and collector of Maori antiquities and New Zealand recreational art.',
#  "They said they're bored.",
#  'Hold me in your hands.',
#  'Joe was born in Somerville, Massachusetts, on March 27th, 1929, and grew up in Quincy, Massachusetts.',
#  'Wow, this is stunning.',
#  "Tom and Mary said they aren't mad.",
#  'Mahoning Creek is a tributary of the Lehigh River in Schuylkill and Carbon - County, Pennsylvania, United States.',
#  'He is an Austrian.',
#  'She was not injured other than in fear.',
#  "I'm sorry I pulled you into this situation.",
#  "The white males' pterostigmata are almost immature.",
#  'Tom is having trouble making ends meet.',
#  'Do you drink alcohol?',
#  'He is a man of greatness.',
#  'He was the son of Shmuel Binyamin Sofer (the " Moses Sofer" ) and grandson of Ksav Sofer (the " Chasam Sofer" ).',
#  "Tom should've waited for me.",
#  'I saw him cry.',
#  'She is a more effective a tiger than he is.',
#  'Tom works there.',
#  'The 1975, an English rock band, released their sixth single from their self-titled debut on May 26, 2014.',
#  'The East Coast Railway operates Samata Express, a super fast express train between Visakhapatnam and Hazrat Nizamuddin in New Delhi.',
#  'There are flying birds in the air.',
#  'Adult birds have white bodies with a black wing patch, a thin dark bill, and red legs and feet.',
#  'That was a dumb question.',
#  'Something has happened to it.',
#  "I'll tell him you came by.",
#  'Natalia has been appointed a conductor professor at the Royal College of Music by Maestro Peter Stark.',
#  'Here is a map of the area.',
#  "Silvio Berlusconi, the club's owner, announced his resignation on May 25th, 2016, along with Phillippe Mexes, Kevin - Prince Boateng, and Mario Balotelli.",
#  'Avoid sudden moves.',
#  'At this time, the theater is usually opened.',
#  'It is endemic to California, in the central Sierra Nevada in eastern Madera County.',
#  "They didn't even know who they were supposed to meet.",
#  'Tom knew that I was happy.',
#  'The lake is three miles long.',
#  "I'd be able to take the opportunity.",
#  'The Luton to Dunstable Busway Route A also connects Parkway to Luton Airport.',
#  'Tom has written several books.',
#  "To answer this question, it's simple.",
#  "Meena's marriage has been discussed, and Chandra has begun searching for a Jodi for her.",
#  'That was a disappointment.',
#  'Talking with him is nothing more enjoyable for me.',
#  "Tom isn't quite ready.",
#  'Any doors are opened by a golden key.',
#  'One billion people speak English.',
#  "I hear you've given up smoking.",
#  'People tend to think of behavior in one of two ways, according to Fritz Fritz Heider: the result of situational or dispositional factors.',
#  'Stävlö or Stäflö is a castle in the municipality of Kalmar in Sweden.',
#  'The characteristic function is a different way to describe a random variable.',
#  "I'm very handsome, according to my mother.",
#  'Earthquakes are common in Peru, particularly in the Arequipa – coastal area.',
#  'Tom ate my cookies.',
#  'Tom looks a lot like his father.',
#  "I won't tell anyone you're in Australia.",
#  'He is a delight to watch.',
#  'The dividends have increased the total "real" return on average equity to nearly double, about 3.2 percent.',
#  "It's pouring down rain.",
#  'The new stadium was completed on August 21, 1974, and was completed on August 21, 1974.',
#  "I'm just a visitor.",
#  'Alexander Rigby, an English parliamentarian, obtained the great old Plough of Lygonia patent in 1643, which covered the entire region, including Cape Elizabeth.',
#  'In a study conducted by Drummond, established non-experienced chicks were compared to dominant chicks to see winner effects.',
#  "Last night, I went to bed at twelve o'clock.",
#  'Tadas Langaitis is a Lithuanian politician, member of the Seimas since November 2016, and a civil rights defender who is active in political and civil initiatives in Lithuania.',
#  "You aren't in her group.",
#  "Tom doesn't smoke anymore.",
#  'Tom is certain to succeed.',
#  'Terry was born in Fairfax, Iowa, and died in Cedar Rapids, Iowa.',
#  "The constituency, like its neighbor, Scotland, was one of Labour's safest seats in Dunfermline East.",
#  'It was created in international style by Little Rock architect Harold A. Berry and Dallas, Texas architect F. Eugene Withrow.',
#  "Of course, Tom didn't arrive.",
#  "I'm looking forward to hearing from you.",
#  'The CCV consists of miniature versions of historic buildings and structures, as well as local customs.',
#  'Tom answered the question correctly.',
#  'In rage, he blasted the door.',
#  'Tomorrow, Tom is planning on doing it.',
#  'I drink coffee.',
#  "The stretch from Chiswick's western border to Syon Lane (Gillette Corner) is known as the Golden Mile, with some notable Art Deco factories.",
#  'Tom looked sharp.',
#  'He returned to his parents in the early 1980s.',
#  'I am four years old today.',
#  'Union County is included in the Spartanburg, SC Metropolitan Statistical Area, which is also included in the Greenville -- Spartanburg -- Anderson, SC combined statistical area.',
#  "I've known Tom all his life.",
#  "I'm not afraid of anything.",
#  "I've read all of them.",
#  "We're going to have to do it.",
#  'He defeated Kakhaber Zhvania in the final, but lost to Andrey Balanov in the final.',
#  "Humphrey's mother was Duvelina, the sister of Gunnora, the Duke of Normandy's concubine, according to Robert of Torigni.",
#  "Tom doesn't have to worry anymore.",
#  'Queen Victoria travelled from Gloucester to Swindon by train on September 29, 1849.',
#  'It is located on the historic Natchez Trace Parkway in Mississippi, Mile 180.7, on the modern Natchez Trace, Mile 180.7.',
#  'Kittery Point is located in the Portland -- South Portland -- Biddeford Metropolitan Statistical Area in Maine.',
#  "I'm afraid you'll get lost.",
#  "I'm really hungover. Could you lower your voice?",
#  "Let's start with beer.",
#  "Colonel Ray died in 1989, and Lieutenant Colonel Koski died on New Year's Eve, 1989.",
#  'Hodges, Green, and Tom Jones, among other Hi Records artists, have all recorded songs written by Syl Johnson, O.V. Wright, O.V. Wright, O.V. Wright, O.V. Wright, and Tom Jones.',
#  'Alternate.',
#  'I was so lonely.',
#  'You are either with us or against us.',
#  'Stephen Hendry claimed the title for the first time in the final and defeated Peter Ebdon 9-8.',
#  "Both Tom's parents were teachers.",
#  'Major General Nathan Mugisha replaced Major General Francis Okello as commander of AMISOM on July 2009.',
#  "You're a great cook.",
#  'The deal with Bolivia was signed on August 4, 2016 and not denied until February 2017.',
#  'Has she arrived?',
#  'You have no right to judge these people.',
#  'Magda Lorne learns from her supervisor, Cholayna Ares, that a Terran operative, Alexis Anders, has survived a plane crash in the Hellers a week before.',
#  'Give me a shot.',
#  'Mount Morris Township is located in Ogle County, Illinois.',
#  'Archdale is a residential area in the Starmount (South Boulevard between Arrowood and South Charlotte) area.',
#  'The incident was not reported by Iranian state-controlled media until it was first reported by international media.',
#  'Someone was murdered.',
#  'Sleep is vital to health.',
#  "It isn't a virus.",
#  'He believes that the Elbow is too acceptable, while insisting that the writer first have to prove himself.',
#  'TJ Trinidad, Biboy Ramirez, Eric Fructuos, Rico Robles, Joem Bascon, Jordan Hererra, and Michael Roy Jornales were among the participants.',
#  'We hope that you will come to Boston for a visit.',
#  "I haven't eaten anything yet.",
#  'Caspar David Friedrich was born on September 5th in Greifswald, Pomerania, Sweden, on the Baltic coast of Germany.',
#  'Lake Bordaglia is a lake in the province of Udine in Friuli-Venezia Giulia, Italy.',
#  "I'm not sure if it's healthy or not.",
#  'Its approximate boundaries were Pearl Street to Grier Avenue and South Broad Street to what is now US 1 \'9" (or.',
#  'Tom is doing fine now.',
#  'In Romania, the Beliu River or Agriș River is a tributary of the Botfei River.',
#  'We clear the futon in the morning.',
#  'She wept bitterly.',
#  'Although the Maryland Department of Transportation is headquartered in Baltimore, three of its subordinate departments have their headquarters in Anne Arundel County.',
#  'Living in the town is very different from living in the country.',
#  'Most languages will have a "default constructor" if the programmer does not have a constructor for an instantiable class.',
#  'However, Turkish Prime Minister Ahmet Davutoglu said that if the EU does not weaken visa requirements by June 2016, Turkey would not accept the EU-Turkey agreement.',
#  'With Japanese government support, another new bridge was constructed at Phnom Penh on the Neak Leung to Ho Chi Minh Highway 1 and opened in 2015.',
#  'I met him early this morning.',
#  'Please take these dishes with you.',
#  'He played for the Brooklyn Dodgers in 1942 and the New York Giants from 1946 to 1948.',
#  'In Romania, the Urechioiu River is a tributary of the Burduja River.',
#  'Tom ate everything on his plate.',
#  'Carl Meissner first described the species in 1856 in " Prodromus Systematis Naturalis Regni Vegetabilis" from material collected by James Drummond.',
#  'The county of Qingyang is located in the town of Rongcheng.',
#  'He also produced several international music commercials, including the Nike "Freestyle" campaign, which has won many awards, and commercial videos.',
#  'As a Purim gift, I received a noisemaker.',
#  'Dave Denine is a provincial politician from Newfoundland and Labrador, Canada, who served as Minister of Intergovernmental Affairs in the former Canadian cabinet from 2007-2011.',
#  "Tom said he didn't feel anything.",
#  'Tom is a tutor, right?',
#  'In that house, my friend lives.',
#  'Tomorrow, Tom will fly to the beach.',
#  'Give me the pleasure of being quiet.',
#  'He was born and raised in Vancouver, British Columbia, Canada, and died in Aylesbury, Saskatchewan, Canada.',
#  "I don't have anything to offer you.",
#  'Mary loves to dance, according to Tom.',
#  "What is Tom's hair color?",
#  'Tell Tom what you think about him.',
#  'We must immediately assist him.',
#  'They said they were furious.',
#  'Micheál Martin, one of them, said that Shane Ross, the Fianna Fáil leader, had called her the day before and that she would meet the following week.',
#  'To avoid potential deadlock conditions, however, a sensible protocol for the use of such transmission flow control signals must be followed.',
#  'I asked everyone the same question.',
#  'They are talking to each other.',
#  'Mohsin Zaidi lived in Delhi for almost four decades before settling in Lucknow after retiring.',
#  'His invention merits to be praised.',
#  'The first schools in the area were constructed for 400 black students and 60 white students in 1883.',
#  'Euacidalia brownsvillea is a species of the Geometridae family, which occurs in North America, including Texas and Hawaii.',
#  "It's uncertain if he'll be here.",
#  'I am a Trojan horse, so I have infected your Mac system.',
#  'Tom said, "budge over," forced his way in and sat down.',
#  'We divided up the loot in three ways.',
#  'Do you know how to drive?',
#  'In 2003, Reuter, Marcel Tiemann, Volker Strycek, and Timo Scheider claimed this victory in an Opel Astra, this victory being repeated in 2003.',
#  'I heard a scream.',
#  'Tom and Mary are no longer talking to each other.',
#  'Penn State ( 5-1-0) defeated Philadelphia 19-7, with Pennsylvania ( 5-1-0) winning.',
#  'Although these two stations are located very close to each other, they are not mutually exclusive; they are located along different portions of Pudian Road.',
#  "In the kitchen, I'm all thumbs.",
#  'Paralepetopsis tunnicliffae is a species of sea snail, a true limpet, and a true gastropod mollusk in the family Neolepetopsidae, one of the marine limpet families.',
#  'After finishing his career in Poland, he returned to Canada to sign the Toronto Falcons of the National Soccer League.',
#  "He died in Munich and is buried in Ajaccio, Corsica's northern cemetery.",
#  "In order to pay the rent, you must have three months' notice.",
#  'Do you have a meeting?',
#  'I hate flying.',
#  'Metin Üstünda, Bahadr Baruter, Erdil Yaşarolu, and Selçuk Erdem founded it in 2002.',
#  'Both Tom and Mary are ready.',
#  'You should take notes.',
#  'Lester B. Faulkner was the interim chairman of the United States until George M. Beebe was elected president.',
#  'When he was a child, our grandfather learned five languages.',
#  "She doesn't like to sing a sad song.",
#  'The shape of the audiogram determines whether the signal is abrupt (sensory phenotype) or flat (strial phenotype) loss.',
#  'Lone Star Comics sold off three of their remaining stores in Plano, Hurst, and Mesquite in July 2013.',
#  'Zina Garrison and Sherwood Stewart were the defending champions, but they lost in the second round to Jana Novotná and Jim Pugh.',
#  'Djurgrdens IF U18 defeated Malmö FF U18 with 3 -- 0 -- in the final.',
#  'This will be his motorcycle.',
#  "The film's soundtrack was composed by Jeetenkumar Naorem and Tony Aheibam, while Raju Mikoncha composed the lyrics.",
#  'It was introduced to Australia in the form of Queensland, the Northern Territory, and New South Wales.',
#  'Sarah Hendrickson (USA), Sara Takanashi (Japan), Coline Mattel (France) and Evelyn Insam (Italie) were the favorites among the women.',
#  "We're not crazy.",
#  'On the Sydney Trains Network, Beverly Hills station is located at the South Line Airport, with Riverwood in the west and Narwee in the east.',
#  "Davies had lived with Jomo Kenyatta at the LSE and had absorbed Harold Laski's socialist ideals.",
#  "She said she couldn't speak French.",
#  'Mary is a yodeler.',
#  'Why do people have apprehension?',
#  'You may invite anyone you like.',
#  'Tom put on a tie.',
#  'His acquaintance runs a grocery store in the area.',
#  'Kumara Sambhavam is a 1969 Indian Malayalam and Tamil film ( bilingual) directed and produced by P. Subramaniam.',
#  'Sami baptized his children.',
#  "Tom didn't understand.",
#  'He worsened the situation.',
#  'White porcelain or white porcelain are used in combination with cobalt, copper-blue underglaze, red underglaze, and iron underglaze.',
#  'In Havana, a new series between the Cincinnati Reds and the Boston Red Sox was played.',
#  'He thinks he is someone, but in reality he is nothing.',
#  "He said he isn't busy.",
#  "Why don't you admit to your blunder?",
#  'Parmigiani Fleurier, Manor, Heineken, Vaudoise, and UBS are the main sponsors of this festival.',
#  "It's also popular with seniors.",
#  'Everyone was worried.',
#  'These earrings were given to me by my grandmother.',
#  'Jack is the most active in our class.',
#  'This tree does not bear fruit.',
#  'Sami was baptized.',
#  'His ambition has no boundaries.',
#  "Dr. Carter is in Africa for several months and works in Kem's AIDS clinic.",
#  "Next month, we'll be moving house.",
#  'I saw Tom hit Mary.',
#  'The winner of each semi-final (Best of 3) qualified for the gold medal race, while the other two drivers qualified for the bronze medal race.',
#  'A medal was flown from Hawaii to Guam and presented to him in the hospital.',
#  'Tom began to play a song.',
#  'Do you guys know each other?',
#  'Tom was wrong.',
#  'The Penser Joch (2211 m) is a high mountain pass in Jaufenpass, northern Italy, close to the South Tyrol.',
#  'Would you like to attend my party?',
#  'Scion was given 10,000 units of the 2013 model year ( MY13 ) production in the United States, while Subaru was limited to only 6,000 units.',
#  'The troops had a lot of ammunition.',
#  'I never learned to swim.',
#  'Between Vancouver Harbour Water Aerodrome and Nanaimo Harbour Water Aerodrome to Vancouver International Water Airport, Baxter Aviation operated services.',
#  'The show requires a small stage and a small cast of 6 actors, as well as a solo violinist who is present on stage throughout the performance.',
#  'Is this your first trip abroad?',
#  'On the south side of High Street, 351 W 5th Avenue is about west of Fifth Avenue, on the south side of the street.',
#  'Without communication, there will not be progress.',
#  'Time is precious, according to my father.',
#  "I don't bother with people like him.",
#  'Jimmy Arias defeated Andre Agassi by 6 -- 2, 6 -- 2.',
#  "Tom doesn't know what's going to happen.",
#  'Tom wanted to do it by himself.',
#  'My school grades were below average.',
#  "They said they're busy.",
#  'A painter can be hurt by anyone.',
#  'In what language do you pronounce the "@" symbol?',
#  'African stone tool techniques are broken down into three main groups, as proposed by Grahame Clark in 1969, and illustrated by Lawrence Barham and Peter Mitchell as follows:',
#  "Tom would've done it any other way.",
#  "We're eating apples.",
#  'Cozens was promoted Lieutenant-General in April 1944 and later appointed Assistant Chief to General Ronald Scobie.',
#  'In 1998, Olaf K., Robert N., and Astrid M. formed it.',
#  'Put on a happy face.',
#  'Mary was killed by Abbott, who was killed by her.',
#  "Tomorrow, we're planning to do it.",
#  "They said they'd most likely win.",
#  "I don't think Tom is busy.",
#  "I'm trying to conquer her heart.",
#  "I'm not very good at speaking Arabic.",
#  'For the 1857 session, 81 Republicans, 31 Democrats, and 8 Americans were elected to the Assembly by November 1856.',
#  'Bhojpuri is the local language, while Hindi is the official language.',
#  'To board the bus, you must purchase a ticket.',
#  "I'm calling my brother.",
#  "It's hogwash, I think.",
#  'Anabel Medina Garrigues and Virginia Ruano Pascual defeated Eleni Daniilidou and Jasmin Wöhr in the final 6 -- 2, 6 -- 4 games.',
#  "I've never seen you so enraged as I have.",
#  'The coast of the United States has about 2,000 islands, of which about three-quarters are uninhabited.',
#  'Let me in under your umbrella.',
#  'I wish I could also speak German fluently!',
#  'The skirt becomes you.',
#  "Balkl is a village in the district Gümüşhacköy, Turkey's province of Amasya.",
#  'The test above does not distinguish between more complex distributions, such as quantum and classical, or between fermionic and bosonic statistics.',
#  'Tom is dyeing his hair.',
#  'It closed down again a few years later, but it soon opened again.',
#  "I don't see any joy in it.",
#  'On May 13, the East Indians arrived in Jamaica.',
#  'The project includes Tracey Emin, Angus Fairhurst, Billy Childish, Jake Chapman, Billy Childish, and Joshua Compston.',
#  "It's easy to find friends, but it's difficult to keep them.",
#  'Tom made a few good suggestions.',
#  'Tom, good morning.',
#  'In 2003, a third album was released, this time on Dragonfly.',
#  "Young girls' need for slim figures is high.",
#  'Mary donned her wedding dress.',
#  "The British Falkland Islands Dependencies Survey named the station Station F or Argentine Islands ''on Winter Island in 1947.",
#  'He is well-known for his creation of various origami models, including erotic instrumentalists, spiders, and complex origami techniques, such as " Pornigami."',
#  'Have you been to a destination in recent times?',
#  "We consider it to be the citizens' right to have public libraries.",
#  'He broke this window.',
#  "We didn't see him.",
#  "I'm taking him to the hospital.",
#  "It'll be all fine, come on.",
#  'What did Tom look like?',
#  'In 1998, Astrid M., Robert N., and Olaf K. formed it.',
#  'The tournament was revived in 2006 in San Francisco, where it was held for two years.',
#  'Tom is extremely worried about it.',
#  'In 2011, the team has played against teams such as Iowa, Rutgers, Hawaii, the State of Mississippi, Nebraska, Connecticut, and Pittsburgh.',
#  'After an assault on the State of Zhao in 235 BCE, troops from the Qin and Chu groups teamed up to attack Wei, but they were defeated.',
#  'I feel like my entire body is hurting!',
#  "That's what matters.",
#  "Tom wouldn't help me.",
#  'The students are now off to recess.',
#  'For the film, Rituparna Sengupta and Indrani Halder received the National Film Award for Best Actress in 1998. Ghosh shared the National Film Award for Best Screenplay.',
#  "We're brothers.",
#  'The people are angry.',
#  'Take a break for coffee.',
#  "Let's wait for the rain to stop pouring.",
#  'In winter, the weather is moderately warm, but it is cold in summer.',
#  'They kidnapped him.',
#  'I have to travel alone.',
#  'Mercer was the brother of George Mercer, John Francis Mercer, and the father of Charles Fenton Mercer.',
#  'Andrea Dovizioso stayed with Ducati for the 2015 season, with Andrea Iannone joining the factory team from a Pramac Ducati.',
#  'The SAS curve ( Surprise Aggregate Supply ) is a long-term vertical line called the EAS curve ( Equilibrium Aggregate Supply).',
#  'On August 12th, 2003, the Kottonmouth Kings released their 3rd Compilation - Album, their 1st Live album, and their 9th total album, Classic Hits Live.',
#  'Stenolechia zelosaris is a species of Gelechiidae family, which occurs in Assam (India).',
#  'Margaret Craske was born on November 26, 1892 in Norfolk, England, the daughter of Edmund and Hannah Craske.',
#  'He came back before eighteen.',
#  'Tom is on the phone with Mary, who is talking to her.',
#  'Something bad is about to happen.',
#  'Sami was so sorry.',
#  'I wish I knew what was going on.',
#  'The Peabody Orlando, near Orlando, Florida, opened in 1986 as the second Peabody Hotel.',
#  'Is it possible to kill me?',
#  'They have mutual respect.',
#  'There are holes for fastening wooden pillars on the broken veranda.',
#  'The black one is mine.',
#  'Almost everything has been improved.',
#  'He underwent an operation on his left leg.',
#  "El Marsa District is a district in Algeria's Chlef Province.",
#  'Tom has worked in many different capacities.',
#  'Tom is absolutely correct.',
#  'Tom managed to put out the fire by himself.',
#  'The teacher is likely to be outraged with the students.',
#  'Your one-year stay in Germany was extremely beneficial.',
#  'It seems familiar.',
#  'Please bring me a cup of coffee.',
#  'In List A Cricket in Bangladesh, it was the first partnership of more than 100 runs for a team seven wickets down for less than 100 runs.',
#  "Saladas - Department is a part of Argentina's Corrientes province.",
#  'I was compelled to take drugs.',
#  'I want you to use it, please.',
#  'Iran, Syria, Sudan, and North Korea are the countries on the list currently on the list.',
#  'It was established on July 18, 1914, by James Horlick, a pharmacist and businessman who was the brother of William Horlick.',
#  'The new facility was divided into four parts: an academic wing, a student services wing, and two athletic wings with classrooms.',
#  'They vowed that they would never cry.',
#  'You should help your coworkers.',
#  'The Sarawak district of Limbang divides it into two parts.',
#  "I don't want to go out together with Tom.",
#  '"This collection was only available at Wal-Mart Canada, but was eventually available online in the Spawn Store.',
#  'My father and mother are dead.',
#  'The tiny institutions they established would not have been considered universities because they were small and did not have the high school diplomas in medicine and theology.',
#  'On December 22, 2015, the successor rocket, the Falcon 9, successfully launched its first stage on land for the twentieth time on its first flight.',
#  'I should go with you.',
#  "Tom can't come with us.",
#  'Since then, it has been going well.',
#  'Starmount is a residential area in South Charlotte (South Boulevard of Arrowood and Archdale).',
#  'He has a hat on.',
#  "I hope I've done the right thing.",
#  'Conlan Carter, a former actor who appeared in the television series " The Law and Mr. Jones" with James Whitmore and " Combat! ", was a part of the original cast.',
#  "I know you're skeptical.",
#  'Tom is a garbage collector.',
#  'It will be over soon.',
#  "Tom isn't a man who likes to travel.",
#  "I don't envy him.",
#  'Is there a zakuska?',
#  'This species is found in the Atlantic Ocean and the Gulf of Mexico; in the Caribbean Sea from South Carolina to Brazil; and in the Gulf of Mexico.',
#  'Husbands and wives should stand by one another throughout their lives.',
#  "I'm here to help you relax and enjoy life. You can rely on me.",
#  'This soup tastes like fish.',
#  'Gidoni was elected to the Veneto Regional Council in the province of Belluno in 2015 after Tosi was excluded by the Federal Party.',
#  'Have you ever seen an elephant fly?',
#  'These are the well-known or similar protocol requirements that apply to the open space as AMQP: These are the same or similar protocol requirements as the above mentioned ones.',
#  'Fulton County is located in the southwestern corner of Maryland, and is bordered to the west by Franklin County and to the south by Washington County.',
#  'It was the last time cyclists competed in commercial teams in 1969, and it was used on national teams.',
#  "In Paris, it's snowing.",
#  "She doesn't want to judge him.",
#  'López Obrador said in a radio interview with Miguel ngel Granados Chapa on " Radio UNAM" on July 17th, 2006.',
#  'I know Tom is content.',
#  'She told me that she would fly to Paris in August.',
#  'TATP is a white crystalline powder that is dissolved in water. Some witnesses described it as a black powder.',
#  'Max Franz (founded 1784 – 1794) was another notable ruler who ruled the university and the spa district of Bad Godesberg.',
#  'Is there a bath in the room?',
#  'Inside, there is nothing.',
#  "I'd like to be at home.",
#  'Tom said he thought Mary was enraged.',
#  "Don't tell him about it.",
#  "I should've invited Tom.",
#  '"Vishwaroopam" was undoubtedly owed to Kamal Haasan, who is brilliant," according to Radhika Rajamani of " Rediff."',
#  'Active medication was the most commonly used therapy method at the time.',
#  'He was seized with sudden chest pains.',
#  'Galinoporni is a southern village in Cyprus on the Turkish Cypriot side of the Karpas Peninsula.',
#  "Dean wrote a book and a song about the cat, and the two formed a friendship, although Litwin and Litwin's relationship ended in 2012.",
#  'Tom is talking to Mary.',
#  "These aren't fish.",
#  'Rabbi Levi said that God showed Jacob all the signs on the night of the story.',
#  'I like fruit.',
#  'Bade Ghulam returned to his hometown of Kasur, Pakistan, in 1947, but returned to India in 1957 to live there permanently.',
#  'I never concealed anything from you.',
#  "Let's take a break for tea.",
#  "I've never met anyone like you.",
#  'From the bottom of their hearts, all people are noble.',
#  "Joe feels betrayed and joins Gallagher's escape plan.",
#  'The term can be extended to standard or nonstandard points (arbitrary): : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : : :',
#  'How is Tom related to you?',
#  'The 1982-1983 NBA season was the 37th season of the National Basketball Association.',
#  'I hated him.',
#  "I'm not sure what it's about.",
#  'Tom loves fishing.',
#  'The county has a total area of, of which consists of land and (0.2 percent) water, according to the US Census Bureau.',
#  'Tom has been assisting him.',
#  "We're all united on this.",
#  'Writing with chalk is trivial.',
#  'In Kimberley, he captained South Africa on August 29, 1891, against the British Isles.',
#  'Tom kept on running.',
#  'Andrea Dovizioso stayed with Ducati for the 2015 season, with Andrea Iannone joining the factory team from a Pramac Ducati.',
#  'The website is named "Purple Clover" to describe people who are "... still cool, still curious, and after all those years of being crazy."',
#  ...]

# %%
test_combined_en['mt5_paraphrases'] = mt5_paraphrases

# %% [markdown]
# ## Computing metrics over mt5 paraphrases

# %%
Jaccard_1 = []
bleu_1 = []
bleu_2 = []
bleu_3 = []
rouge_l = []


for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['mt5_paraphrases'][n]
  #lexical-syntactical variation metrics
  rouge_l.append(rouge_score(candidate, reference,ngram='l' ,metric='f'))
  bleu_1.append(bleu_score(candidate, reference, ngram=1))
  bleu_2.append(bleu_score(candidate, reference, ngram=2))
  bleu_3.append(bleu_score(candidate, reference, ngram=3))
  Jaccard_1.append(jaccard_similarity(candidate, reference, ngram=1))
# Out:
#   0%|          | 1/5000 [00:00<21:40,  3.84it/s]/usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 100%|██████████| 5000/5000 [00:10<00:00, 457.49it/s]

# %%
test_combined_en['bleu_1'] = bleu_1
test_combined_en['bleu_2'] = bleu_2
test_combined_en['bleu_3'] = bleu_3
test_combined_en['rouge_l'] = rouge_l
test_combined_en['jaccard_1'] = Jaccard_1

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                         mt5_paraphrases    bleu_1    bleu_2  \
# 0     William Gibbs fully funded the Chapel and Hall...  0.644123  0.289030
# 1                                  This isn't my forte.  0.833333  0.600000
# 2                                    He is a biologist.  1.000000  1.000000
# 3       I haven't read all of the books on the shelves.  0.916667  0.818182
# 4                         He can run faster than I can.  0.584101  0.333772
# ...                                                 ...       ...       ...
# 4995              Tom and Mary said they aren't hungry.  0.777778  0.625000
# 4996                        I went swimming in the sea.  1.000000  1.000000
# 4997                             I'm not too surprised.  1.000000  1.000000
# 4998           I think you should've been more patient.  0.888889  0.750000
# 4999                                  Tom denies cried.  0.606531  0.404354
#
#              bleu_3   rouge_l  jaccard_1
# 0      1.252462e-01  0.320000   0.647059
# 1      5.000000e-01  0.750000   0.714286
# 2      1.000000e+00  1.000000   1.000000
# 3      7.000000e-01  0.941176   0.909091
# 4      2.596003e-01  0.666667   0.545455
# ...             ...       ...        ...
# 4995   4.285714e-01  0.714286   0.636364
# 4996   1.000000e+00  1.000000   1.000000
# 4997   1.000000e+00  1.000000   1.000000
# 4998   5.714286e-01  0.857143   0.800000
# 4999  1.349576e-308  0.750000   0.666667
#
# [5000 rows x 7 columns]

# %%
cosine_similarities = []
for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['mt5_paraphrases'][n]
  cosine_similarities.append(cosine_similarity(candidate, reference))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# 100%|██████████| 5000/5000 [15:55<00:00,  5.23it/s]

# %%
cosine_similarities
# Out:
# [0.8294095396995544,
#  0.5710312724113464,
#  1.0000001192092896,
#  0.9972928762435912,
#  0.9581010937690736,
#  0.8246363401412964,
#  0.7899690270423889,
#  0.9523603916168212,
#  0.9857299327850342,
#  0.9876384735107422,
#  1.0,
#  0.7820661067962646,
#  0.958531618118286,
#  1.0,
#  0.9154039621353148,
#  0.435489296913147,
#  0.918546199798584,
#  1.0,
#  0.6569724678993225,
#  0.9999999403953552,
#  1.0000001192092896,
#  0.8993380665779114,
#  0.8699037432670593,
#  0.9910138845443726,
#  0.9999998807907104,
#  0.8412721157073975,
#  1.0000001192092896,
#  1.0000001192092896,
#  0.760033905506134,
#  0.9014626741409302,
#  0.7945283055305481,
#  0.8066702485084534,
#  0.8572185039520264,
#  0.9999999403953552,
#  0.9977285861968994,
#  0.889935314655304,
#  0.8936795592308044,
#  0.9335485696792604,
#  0.9999999403953552,
#  0.8875333666801453,
#  1.0000001192092896,
#  0.930136740207672,
#  0.980851113796234,
#  0.936462104320526,
#  0.8868374228477478,
#  0.9602332711219788,
#  0.8063328266143799,
#  0.9503862857818604,
#  0.9383984804153442,
#  0.8998771905899048,
#  0.9999999403953552,
#  0.8913910388946533,
#  0.7893461585044861,
#  1.0,
#  0.7685424089431763,
#  1.0000001192092896,
#  0.9146206974983216,
#  0.9999998807907104,
#  0.7646693587303162,
#  1.0,
#  0.9999998807907104,
#  0.8474864959716797,
#  0.9999999403953552,
#  0.807456374168396,
#  1.0,
#  0.890363335609436,
#  0.8243812918663025,
#  0.8381783366203308,
#  1.0,
#  1.0,
#  0.7827950716018677,
#  0.7402973175048828,
#  0.8983839154243469,
#  0.9944593906402588,
#  0.6613226532936096,
#  0.8403854370117188,
#  0.8607103824615479,
#  0.9916651844978333,
#  1.0,
#  0.9117342233657836,
#  0.9999998807907104,
#  0.8884230852127075,
#  0.9999999403953552,
#  1.0,
#  0.7995657324790955,
#  0.9786375761032104,
#  0.8299850821495056,
#  0.8042091131210327,
#  0.9403117299079896,
#  0.9759398698806764,
#  1.0,
#  0.9030117988586426,
#  0.9510029554367064,
#  0.9999999403953552,
#  0.8577625155448914,
#  0.8842682838439941,
#  0.9225499629974364,
#  1.0000001192092896,
#  1.0,
#  1.0000001192092896,
#  0.8700774908065796,
#  0.911520779132843,
#  0.9583918452262878,
#  0.9063373804092408,
#  0.9149947166442872,
#  0.9999998807907104,
#  1.0,
#  0.8422271609306335,
#  0.9477624893188475,
#  0.9253360033035278,
#  0.9295241832733154,
#  0.8025974631309509,
#  0.8247403502464294,
#  0.8729222416877747,
#  0.8910489082336426,
#  0.8472307920455933,
#  0.9627721309661864,
#  0.6322813034057617,
#  0.8747990131378174,
#  0.7835637331008911,
#  0.7753981351852417,
#  1.0,
#  0.8519037365913391,
#  0.849515974521637,
#  0.9999999403953552,
#  1.0,
#  0.8281784057617188,
#  0.9103841781616212,
#  0.9999998807907104,
#  0.9942927360534668,
#  0.8233577013015747,
#  0.9999999403953552,
#  1.0,
#  0.9999999403953552,
#  0.7627248167991638,
#  1.0,
#  0.9541893601417542,
#  0.8292891979217529,
#  0.9951297044754028,
#  0.6940039396286011,
#  0.9236566424369812,
#  0.8957235217094421,
#  1.0,
#  0.8374732732772827,
#  0.8500267267227173,
#  0.8728994727134705,
#  0.9572579860687256,
#  1.0000001192092896,
#  0.8885869979858398,
#  0.8744031190872192,
#  0.9570979475975036,
#  0.7606896162033081,
#  0.8999041318893433,
#  0.9567015767097472,
#  0.9067581295967102,
#  0.9209149479866028,
#  0.8888663649559021,
#  0.7682729363441467,
#  0.9999999403953552,
#  0.7348208427429199,
#  0.8617410659790039,
#  0.9999998807907104,
#  0.9464291930198668,
#  0.8439520001411438,
#  1.0,
#  0.9999999403953552,
#  0.9082299470901488,
#  0.8656193614006042,
#  0.8598271608352661,
#  1.0,
#  0.9416331052780152,
#  0.9911593198776244,
#  0.8109100461006165,
#  0.8951939940452576,
#  0.7196291089057922,
#  0.9999999403953552,
#  0.8625569343566895,
#  0.9999999403953552,
#  0.9490076303482056,
#  0.9810135960578918,
#  0.8386646509170532,
#  0.8159587979316711,
#  0.7327244281768799,
#  0.9999998211860656,
#  0.9250596761703492,
#  0.9868141412734984,
#  0.9499807357788086,
#  0.7751592993736267,
#  ...]

# %%
len(cosine_similarities)
# Out:
# 5000

# %%
test_combined_en['cosine_similarities'] = cosine_similarities

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                         mt5_paraphrases    bleu_1    bleu_2  \
# 0     William Gibbs fully funded the Chapel and Hall...  0.644123  0.289030
# 1                                  This isn't my forte.  0.833333  0.600000
# 2                                    He is a biologist.  1.000000  1.000000
# 3       I haven't read all of the books on the shelves.  0.916667  0.818182
# 4                         He can run faster than I can.  0.584101  0.333772
# ...                                                 ...       ...       ...
# 4995              Tom and Mary said they aren't hungry.  0.777778  0.625000
# 4996                        I went swimming in the sea.  1.000000  1.000000
# 4997                             I'm not too surprised.  1.000000  1.000000
# 4998           I think you should've been more patient.  0.888889  0.750000
# 4999                                  Tom denies cried.  0.606531  0.404354
#
#              bleu_3   rouge_l  jaccard_1  cosine_similarities
# 0      1.252462e-01  0.320000   0.647059             0.829410
# 1      5.000000e-01  0.750000   0.714286             0.571031
# 2      1.000000e+00  1.000000   1.000000             1.000000
# 3      7.000000e-01  0.941176   0.909091             0.997293
# 4      2.596003e-01  0.666667   0.545455             0.958101
# ...             ...       ...        ...                  ...
# 4995   4.285714e-01  0.714286   0.636364             0.996521
# 4996   1.000000e+00  1.000000   1.000000             1.000000
# 4997   1.000000e+00  1.000000   1.000000             1.000000
# 4998   5.714286e-01  0.857143   0.800000             0.949482
# 4999  1.349576e-308  0.750000   0.666667             0.941180
#
# [5000 rows x 8 columns]

# %%
test_combined_en.to_csv('/content/drive/MyDrive/working_directory/tfm/models evaluation/mt5_evaluation.csv', index=False)

# %%
test_combined_en['bleu_1'].describe()
# Out:
# count    5000.000000
# mean        0.819999
# std         0.164522
# min         0.142857
# 25%         0.725020
# 50%         0.846482
# 75%         1.000000
# max         1.000000
# Name: bleu_1, dtype: float64

# %%
test_combined_en['bleu_2'].describe()
# Out:
# count     5.000000e+03
# mean      6.528370e-01
# std       2.728735e-01
# min      9.997901e-309
# 25%       4.696305e-01
# 50%       6.666667e-01
# 75%       9.265873e-01
# max       1.000000e+00
# Name: bleu_2, dtype: float64

# %%
test_combined_en['bleu_3'].describe()
# Out:
# count     5.000000e+03
# mean      5.411025e-01
# std       3.363775e-01
# min      8.185589e-309
# 25%       2.729103e-01
# 50%       5.020410e-01
# 75%       8.888889e-01
# max       1.000000e+00
# Name: bleu_3, dtype: float64

# %%
test_combined_en['rouge_l'].describe()
# Out:
# count    5000.000000
# mean        0.733353
# std         0.216334
# min         0.000000
# 25%         0.588235
# 50%         0.750000
# 75%         0.933333
# max         1.000000
# Name: rouge_l, dtype: float64

# %%
test_combined_en['jaccard_1'].describe()
# Out:
# count    5000.000000
# mean        0.773466
# std         0.200005
# min         0.083333
# 25%         0.640000
# 50%         0.785714
# 75%         1.000000
# max         1.000000
# Name: jaccard_1, dtype: float64

# %%
test_combined_en['cosine_similarities'].describe()
# Out:
# count    5000.000000
# mean        0.908482
# std         0.089049
# min         0.378741
# 25%         0.861008
# 50%         0.922321
# 75%         0.992039
# max         1.000000
# Name: cosine_similarities, dtype: float64

# %% [markdown]
# Cosine similarity filters + Counts

# %%
test_combined_en_filter1= test_combined_en[test_combined_en['cosine_similarities'] > 0.5]

# %%
test_combined_en_filter2= test_combined_en[test_combined_en['cosine_similarities'] > 0.7]

# %%
test_combined_en_filter3= test_combined_en[test_combined_en['cosine_similarities'] > 0.9]

# %%
print(len(test_combined_en_filter1),len(test_combined_en_filter2),len(test_combined_en_filter3))
# Out:
# 4989 4862 2957

# %% [markdown]
# #DistilGPT2

# %% [markdown]
# ## DistilGPT2 paraphrase inference

# %%
DistilGPT2_model = AutoModelWithLMHead.from_pretrained('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/DistilGPT2_output_model/output_model')
DistilGPT2_tokenizer = AutoTokenizer.from_pretrained("distilgpt2")
# Out:
# Downloading config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
generator = pipeline('text-generation', model=DistilGPT2_model, tokenizer=DistilGPT2_tokenizer )

# %%
def clean_paraphrase(input_sentence):
  p = generator('<s> '+input_sentence+' </s> === <p> ')
  return p[0]['generated_text'].split(' </s> === <p> ')[1].split(' </p>')[0]

# %%
DistilGPT2_paraphrases = []
for original_sentence in tqdm(test_combined_en['Text']):
  paraphrases = clean_paraphrase(original_sentence)
  DistilGPT2_paraphrases.append(paraphrases)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 20 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# 100%|██████████| 5000/5000 [3:40:38<00:00,  2.65s/it]

# %%
DistilGPT2_paraphrases
# Out:
# ['William Gibbs funded the Chapel and Hall, which was also designed by Butterfield.',
#  'icky.',
#  'Â He is a biologist.',
#  "ersatzit is not a book that I've read.",
#  'ive met the power of his instinctive mind.',
#  'Â When Samuel Herrick arrived in',
#  'The song also received " early " dazzling support across Europe," according to Jon Uren, Warner Music Europe\'s marketing manager.',
#  'After Mary, Tom was dismissed.',
#  'ersatzin is the neighborhood where she settled in that city for five years.',
#  'iced wine makes me want to drink that.',
#  'ersatz! What are you smiling about?',
#  'Â Nationalist parties did not, however, join the other liberal groups that said they',
#  'Tom said he would not be concerned with being disturbed.',
#  'Tom changed his clothes.',
#  'iced Maple Leafs season of the Toronto Maple Leafs was the',
#  '""<s> "" The New York Times "" reported that Thomas D. Rockefeller was the "" main banker in New York "" and his nephew, "" John',
#  'iced in the 1836 period between 18',
#  "I'm an idiot, according to Tom.",
#  'ersity is very nice, thanks.',
#  'Â Where did he learn dance?',
#  'I talk fast.',
#  'ive served as captain',
#  'ersatzit - terminology is now also used in other parts of the country.',
#  'ersatzitaiksi is an island in South Ossetia, Russia, in the south of the Caucasus.',
#  'Â Гартся is a horse and donkey.',
#  'Tom is planning to attend your party.',
#  'ценерский is the kind of person I can speak English well.',
#  'ive gone off for good. No two absentees.',
#  'ersatz -- police districts serving Center City are the 17th, 9th and 6th districts',
#  'ersatz Sunday is the Sunday of the month.',
#  "She'll soon be married to him for ten years.",
#  'ersatz is a logical and intelligent philosophy. But at the same',
#  'iced to a high degree, Blauburger gives',
#  "ersus can't explain exactly her family.",
#  'iced by the red blouse and a black skirt.',
#  'Â After Donald explained everything about Bobby and Morag, Rebecca stays for the school holidays in Summer',
#  'словарандуаннной is an Italian word spoken only by me.',
#  'ștaru is a tributary of the River Tăt',
#  'ersatzatzititz is today a public holiday.',
#  'iced him a bit so he could relax.',
#  'Â Tom usually spends eight hours each night.',
#  'Georges Merle died in Paris in 1881, and his son Hugues Merle later became a painter.',
#  'erythniclopalidus zelosaris is a moth of the family Geometridae. It is found in Yun',
#  'iced me a drink at the table.',
#  'San Pedro Springs Park is located in Bexar County, Texas, in the United States state of Texas.',
#  'Â Do I need to know who is on this list?',
#  'My whole body aches.',
#  "iced Tom without saying that I'd been late.",
#  'icky is a lot.',
#  'Antony died on November 6th, 1620, and was buried in the church of Carew on November 7th.',
#  'ersatz is a public place for people to live.',
#  "ersatzcheek's constituency is situated on the right bank of",
#  'erythrostrata is a non-linear oscillator developed in 1963',
#  'ikkoi is a Russian-language newspaper with bilingual, newsstand and newsstand.',
#  'Â Victoria S. Bull ( "" Victor "" ) was',
#  'Believe what you want.',
#  'ersatz was previously located at the south-eastern corner of Seymour at Mangalore',
#  'Would you like me to stay?',
#  'iced coffee?',
#  'ersatzit!',
#  'Â Met an angel last winter.',
#  'izin was created in 2016 to relocate Milpitas, California campus to Milpitas, California. </',
#  'ersatzko is a municipality in the central region of Gipuzhwa in southern Iran.',
#  'șdţića is the father of the Bulgarian pianist Stefan Milner.',
#  'icky and confused the password.',
#  'ersatz-commemorated 14 May 1562 with the letter written by Taupinet on',
#  'ersatz of additional mixing was carried out by Bill Malina, with assistance from Rice and Gh',
#  'ersatzentacluorbid was a village in the Kultur municipality in the district of Gützcheit in Switzerland.',
#  'I have no one to blame but myself.',
#  'icky knows something.',
#  'icky?',
#  'ersatzit is impossible to eat the money.',
#  'China 1843 - After a confrontation between Americans and Chinese, sailors and Marines from St. Louis were landed at the Canton trading station.',
#  "iced tea doesn't make much of a difference.",
#  'iced coffee, too?',
#  'Â From July 2011 to July 2011, the Werris Creek',
#  'ersatz ( codice _ 692-697',
#  'ersatz-spirosis is a skin-eating spider.',
#  'He did what he could for his children.',
#  'Â JieT is a tributary of the Slivei Slivei River in Romania.',
#  "icky, but he didn't tell anybody of that.",
#  'erythritos ale is the most enjoyable drink in the world.',
#  'iced up.',
#  '""<s> Tom said he\'d help.',
#  'iced version of the service was released on 7 July 2008 on Windows',
#  'ersantosaurid is a true gastropod mollusk in the family Buccinidae, which is found from Bolivia to Mexico.',
#  'ives the school to the secondary department of the autistic',
#  'irlanth',
#  'No other breed is bigger than this one.',
#  '""He gave me a call on 2nd October.',
#  'iced water for me, has enough money to buy a car.',
#  'I tried to escape.',
#  'ū',
#  'Â Do I take any action?',
#  "Let's discuss the subject.",
#  'Â Buccinum par',
#  'ersatz "" Ionian "" and "" O" are also popular nowadays.',
#  'Is he swimming?',
#  'Â I may be confused.',
#  'iced by the author of our mother tongue, the translator was able to translate everything in the book.',
#  'iced the tournament again in San Francisco ( 2006 ) where it was hosted for two years. </p',
#  'What a stunning spot!',
#  'ive had a couple of other friends who met her from time to time.',
#  'erskleen had three',
#  'Â Tom decided to leave with us.',
#  'Â Tom is going to try.',
#  'Â I saw another cat run after the dog.',
#  'It was first recorded by Irma Thomas in November 1961 and was produced by Allen Toussaint.',
#  'Tom is asleep, as well as Tom.',
#  'трактрутск',
#  'ich is how to get home?',
#  'I accept your plan.',
#  'ersatz -- the verb is always present, so he wants to try it.',
#  'Â Maughan and his wife, former Lorraine Hannem',
#  'Â I have cold stools.',
#  'ersatzhares, also known as Mottaka, is a village in the Bijapur District in Pakistan, United Arab Emirates.',
#  'She is worried about her health.',
#  'ersatz! Humor me!',
#  'ersatz was sent out to the First Army in late October, and',
#  'The olivella kifos is a species of dwarf mollusk in the Olivellidae family, similar to the navy olives.',
#  "ersatzah's work can't be completed without a paper trail.",
#  'ersatziki was his attempt at understanding a person by name.',
#  'ersatzitungska-sangria is a national language spoken in Armenia.',
#  'He came from Serbian ajkai in Komárom in 1739 as a renowned speaker ( "slavni propovednik") during religious persecutions.',
#  'In various countries, the car was sold with different names.',
#  'iced tea over and over and went to the cinema yesterday.',
#  'ute Raum',
#  'ersatz is located in the northwestern corner of the city along the highway between Market Square and Market Square.',
#  'Owen Bradley has released " Thank Schoen" from her 1964 album " By Request," which was produced by Brenda Lee.',
#  "The loyalists had camped on the west side of the Catawba River, while General Charles Cornwalli's army camped on the east side.",
#  'ersatznik was a 1961 film directed by Universal Pictures produced and was premiered by David Miller',
#  'ia can play the guitar, violin, piano, or whatever.',
#  "ersatz's Danielle, Nadine and Mark have visible their pictures in the school case.",
#  "Bas 90's development began in the 1970s and was fully operational in the 1980s.",
#  'ersatz was a very good place to do that.',
#  "ersatz news of his son's death was a great shock.",
#  'ichai is found only in Yunnan and its tributaries in Lake Dianchi, China.',
#  'iced from the first month of this year, when I saw that',
#  "ersatzpiel was fond of his mother's clothes.",
#  'ersatzkei - race car accident rates are much lower than elsewhere.',
#  'ive Beengan was commissioned on 1 July 2004 to the British Transport Police Police Force.',
#  'ersatz training in Malaysia ( now Y',
#  'Â Suzuki Beane is a humorous book written in 1961 by Louise Fitzh',
#  'Â Thanks for saying that.',
#  'ersatzpahm is the second branch of the Hebrew University, founded in 1979.',
#  'ersatz - games are played in second places in the pools, the first place',
#  'Â Mount Sis is also a plateau that has called "" Sis Da',
#  "What don't you get?",
#  'ersatzinis obv.',
#  'iced milk is a main part of Shimla District,',
#  'Cassandra Peterson appeared in "All About the Evil" of Peaches Christ with Patrick Bristow, Mink Stole, and Brown.',
#  'The Presbyterian doctrine has been "reformed," according to the government, and the government is "theological."',
#  'izamo jima refers to people who use modern clothing and often wear conservative clothing.',
#  'ersatzvostis would have known that the ceiling was already rinsed and tiles had already been rinsed.',
#  'ickyphooey, please let me stay at the station with you.',
#  'Â Linkuwa Pokhari is a village and village development',
#  'уткрая is a list of Chinese books that I have not already finished reading.',
#  'ersatzpiel is a word used interchangeably with words in German, where "" på obkom "" should not be used.',
#  'ikowasa are my friends.',
#  'ersatz.”',
#  'It was predictable.',
#  'He fractured his left wrist.',
#  'erymekening3.0.0 was agreed to change the name of Acquire and Sackson suggested. </',
#  'He has not been interested in the ruse scheme, to my knowledge.',
#  'ersatzikis replaced his leg with a knife.',
#  'Â What to expect from a young, old man.',
#  'iced tea?',
#  'ersatz!',
#  'According to the US Census Bureau, the county has a total area, of which land and ( 17.6 percent) are water.',
#  'Â He plays the role of a diplomat in the coronation of Emperor',
#  'Â',
#  'ichalco is an Albanian politician born in 1996 in Darjeeling, Gires, north of Phnom Penh ( Cambodia ).',
#  'ivenates go out a little bit.',
#  'сструшет is a very, very tired man now.',
#  'Â Russ Salina is considered the Grand Island ( of Nebraska ) of south.',
#  'с Esperanto is one of those languages that you use very rarely.',
#  'ilipe anne spigano ""',
#  'iced the taxi.',
#  'ersatzikis provides a wide range of academic activities, including academic forums and student activity',
#  'ersatzit participates in the association of twenty members.',
#  'iced by Michael Chang, Michael Chang won the final 3 -- 6, 6',
#  'стреня октренся is the song by Vivaldi called',
#  'The film was a lot better than I expected it to be.',
#  'iced when I was a child.',
#  'Â Lelpl',
#  'iced in the castle as a peasant, he crept into the castle town.',
#  "Agha Mohammad Khan, his brother, was appointed Qoyunlu's new chieftain due to his castration.",
#  'Â He works in the office.',
#  'ich was trained in',
#  'Only the Sara of the south was ruled effectively; the French presence in the Islamic north and east was negligible.',
#  'ersatzitik is a village in East Antwerp. It is located in South Antwerp.',
#  'icky!',
#  'ersatz Maag ( born 13 May 1919 ; died 14 April',
#  'ive novella novella novella with a single theme has been added.',
#  'Â Parachute - Cavalrymen were defeated in Waterloo.',
#  'She lost 50-25 to Zimbabwe, 84-16 to Tanzania, and 58-24 to South Africa during the tournament.',
#  "I hope this doesn't happen again.",
#  'ive ever seen one of these people?',
#  'Â She married George I. Eisenhauer after Anna was discovered.',
#  'iced it up.',
#  'iced',
#  'ersatz-eisleptus has no place in society.',
#  'ersatzit is a requirement of your employees to be absolutely loyalty to their employees.',
#  'ersatz ( "" schnopro" ) is a German slang term for people in need of you.',
#  'ersatzförungsar ( born November 28, 1965 ) is a Turkish cyclist and former professional under-19 World Champion, born in Gümü',
#  'ersatzfakte is a village in the Berisha district of Gümüşhacıköy, Turkey. </p',
#  'ersatzmiki is a very small but extremely beautiful woman.',
#  'ersatzzah is a village in the Dahanu district of Karnataka, India. It is located in the state of Karnataka.',
#  'The A cells produce glucagon, which mobilizes the hepatic glycogen, and serotonin is produced by the enterochromaffin cells, which promotes the contraction of the smooth muscles.',
#  'ersatzymbika is a neighbourhood that has an ally including the collopys ( Brian',
#  'ersatzka is a village in the province of Békésszentandrás, in eastern Slovakia.',
#  'ive never thought Tom would break the contract.',
#  "ersatz's perception of beauty comes when people compare beautiful faces with flawless expressions.",
#  'Â Mother does not let me drive.',
#  'Tom said he would not be able to sing.',
#  'iced Giovanola also released the first freefall ( developed by Intamin ) and the',
#  'ersatz is a private hospital',
#  'ersatz was British consul-general from 1800 -- 04 from the',
#  'Â A potential protocol for the use of sensitive flow control signals must be used',
#  "utesy-minded people don't like this result.",
#  'ickybacke',
#  'iced tea?',
#  'ersatz - winter was on a cold day.',
#  'ersatziki is one of the most beautiful rugby games I have ever seen.',
#  'Italy qualified for the 2009 European Baseball Championship from the 2007 series.',
#  'ersatz.com/en/s> === <p> How did you enjoy your party?',
#  "I've got to get it fixed.",
#  'erythiel is a village in the Dibsøy District in the region of Amersfoort in Sweden.',
#  'iced the roof for us.',
#  'In the state, one individual was killed by the hurricane indirectly and two others were killed in a flash.',
#  'ersatzu is a village in the province of Gipuzli of Şaşheer in Turkey.',
#  'iced some soup.',
#  'Why is everyone screaming?',
#  'ive been waiting for three months.',
#  'erymowycz was a Professor of Civil Engineering at the Royal',
#  'ich aureus m',
#  'icky listened attentively.',
#  "She doesn't pay much attention to how she dresses.",
#  '""<s> In the absence of evidence, the question was answered.',
#  'Â Founded at Cannon, Director Albert Pyun',
#  'ersatz died on 23 July 1942 at his',
#  "utes and I know what you're planning.",
#  'ersatzfelski is a part of the family of Swiss violinist Fritz Lebedt.',
#  'Â The Bristly Peaks include the Messent Peak, and the Brodie Peak.',
#  'слашен ( born June 19, 1953',
#  'Â New teaching sites were opened in Ivrea in',
#  'iced the bridge this',
#  'idedWebment was originally published as a W3C',
#  'Pedro, along with many other children in the custody of a man named Sebastian, died soon.',
#  'уститл was not my intention to stay here.',
#  'ershusaður is a town in Klaipėda County',
#  'ive a heart is broken.',
#  'ersatzko is very good at the talking points.',
#  'стоприя артулский пропалан Отер',
#  'ixx.com offers the option of waiting for the driver to show the status of the car before passing the gate.',
#  'ersatz has also been said to have inspired the creative work of Jimmy Webb.',
#  'ersatz was the guide to the visitors round museum.',
#  'iced snow is also present in the South Bay peninsula and',
#  'Tom and Mary are no longer children.',
#  'ersatz!',
#  "I'm not that inebriated.",
#  'ersatzka is a village in the Berasia district, in the Austrian district of Tübingen.',
#  'ive met her a lot recently.',
#  'ive never had to go to Boston last Sunday.',
#  'стря "" nach "" is the tenth episode of the fourth season, and the fifth episode of the fourth season.',
#  'Â He lives with his wife Lucy and his children with his wife Lucy and grandchildren.',
#  'icky said he lied.',
#  'ive eaten a flower.',
#  'She needs someone to help her.',
#  'iced coffee was very sweet.',
#  'Asbestos substitutes now include ceramic, carbon, metal, and aramid fibers, such as Twaron or Kevlar.',
#  'iced me a bit.',
#  'ersatz is an elementary school in Córdoba, in the Córdoba Province, northern Venezuela.',
#  'ersatzu is a village in western Hungary, where there are a number of Jewish and mixed ethnic communities.',
#  'izarroal is a town and municipality in the Sucre district - Province of northern Colombia.',
#  '""<s> "" Déjàvu Déjàvu Déjàvu "" is a book with illustrations by Jacques Rambour',
#  'ive already cried.',
#  'ersatzit is hard to drive a computer.',
#  'ive become a student.',
#  'iced tea is delicious, please give me something cold to drink.',
#  'ÃÃÃ',
#  'Â Will you go to Chicago today?',
#  'ikonka is a Georgian national who served in the service of the Georgian President, Ida Bashir before retiring in 2014.',
#  'ersatz - Greek text',
#  'Â Kendra Saunders is now 100 % Hawkgirl.',
#  "ersatz is persistent, isn't she?",
#  'ive followed Tom off on his family.',
#  'iced wine?',
#  'тромарствая деля 2008 :',
#  'The weather became colder after a string of warm days.',
#  'ive been going around the countryside.',
#  'Tom wanted to know the cause of the accident.',
#  'ersatz "" mona Lisa "" was painted by Leonardo da Vinci in the 12th',
#  'iced with him as a correspondent in Norway at a time when European relations',
#  'ive spent several nights of his life in prison.',
#  "ersatzchev was puzzled over Mary's house.",
#  "We're finally alone.",
#  'étente is on the line.',
#  'ersatz is very important.',
#  'ive black Clover is described as being for people',
#  'строватр was an Olympic athlete,',
#  "ive never said an honest word after you've finished living forever.",
#  'Â Mike Parlett ( also known as Michael J. Parlett',
#  'vername-guitarists used to be very persuasive.',
#  'iced this tea.',
#  'igrated',
#  'iavetta was examined at the table.',
#  'ersatzka is a village situated in the Berasia district, in the Berasia District of Armenia.',
#  'Â Tom has many books.',
#  'ersatzolumba means that the average of life expectancy in Japan is still increasing.',
#  'icky.',
#  'ive seen Tom and Mary both want it.',
#  'ersatz is an area of the Thirteenth - year in India, India and Sri Lanka.',
#  'The Valea Voenilor River is a tributary of the Pascu River.',
#  '""<s> He told me that he thought of going alone, but it came later.""<s> On 31 December 2015, Chris Pratt and',
#  'Taft served as Chief Justice until his death in 1921, when he was replaced by White.',
#  'ersatz is the closest people from each other.',
#  'ÃÃÃÃÃÂ (?? * * * *',
#  'iced Tom and Mary kept their relationship secret from their parents.',
#  'No passengers were hurt.',
#  'ivepated by Tom.',
#  'The following table compares the results of the LOD - capable rendering and a brute - detail technique (full force).',
#  'ersatzkoi is my junior to me by two years.',
#  'utes began to be the first railway workshops in the Wellington Region, situated near the first',
#  'She burst into tears as she heard the news.',
#  'iced coffee is really hot.',
#  'ive received an upgrade package for the computer.',
#  'ersatzbrück is a municipality in the province of Biella in Austria.',
#  'Mount Cobb is a mountain on Vancouver Island, British Columbia, Canada, east of Gold River and southwest of Mount Filberg.',
#  'Only one percent of natural diamonds are of this sort, and the majority of them are of the blue to gray variety.',
#  'ersatzpene im Beaulieu is the tallest person in the class.',
#  'ive already talked you can come if you like.',
#  'Tom woke up and went away.',
#  'Â Wilson is angry with Dennis.',
#  'ersatz added in 2015 "" SpikeTV Spanish "" commentators for Premier Boxing Champions',
#  'iced up his career with the Professional Arena Soccer League of San Diego Sockers in 2009.',
#  'ersatzvoortis is the tenth Croatian team to win the silver medal in the European championships in 2004.',
#  'icky-headed girls are girls who speak English fluently.',
#  'стралуский : Bill brought the book to me.',
#  '"Do I hear wedding bells?" I asked them on a date.',
#  'ersatz "" was the last line Franz Ferdinand wrote to Count Harrach, while Sophie had',
#  'ive a son, one hundred and fifty years were his last years.',
#  'ersatz provides a domain abstract language for specific syntax tree',
#  'été parceloro is also known as Pérez',
#  'ersatzfangue is also home to the unincorporated towns',
#  'ersatzit is dangerous to disturb the others.',
#  'ersatzion is a municipality in the district of Styria in the Austrian state of Liezen.',
#  'Â His dog is named Popeye Popeye.',
#  'erythrocytium forms the basic complexes. The potassium salt is syntactic with.',
#  'Â The fortress',
#  'ive felt pain.',
#  'Â Restless and Wild ""',
#  'ersatz.com is a smart spider.',
#  'ersatz.',
#  '""<s> In "" The New York Times Magazine "", Tom told Mary not to drive.',
#  'Â The 1988-89 National Basketball Association season was the 37th season of the NBA.',
#  'ive been so good at this.',
#  'Â Hopewell,',
#  'iced this dress.',
#  'ersatzchez is my favorite meal.',
#  '""<s> The only way to achieve this result - would be to take a second look at the "" Final "" and compare each of its components by',
#  'erythroid - type 0, or 0x, is unique for its highly reactive chemical formula _ 0 and for its highly reactive chemical formula 1.',
#  "ersatz's",
#  'The Final FESPIC Games featured 18 venues in Selangor, 7 in Kuala Lumpur, and 1 in Putrajaya and Negeri Sembilan respectively.',
#  'ips',
#  'ive already built.',
#  'ivities are very common between 13 years and 19 years old.',
#  "Yes, I can, but I can't really speak Shanghainese.",
#  'icky.',
#  'iced in the car where did you park the car?',
#  'ive received it.',
#  'He was based in Harrogate, North Yorkshire, from 1996 to 1999 after completing his university studies at Cardiff University and Rouen, France.',
#  'Â Morton Hunt ( 1818 -- 1885 ) became a',
#  'ersatz also appeared in 53',
#  'ersatz, however, claimed they were not busy.',
#  'Go upstairs and go to bed.',
#  'ersatzitam was a real shock.',
#  'ersatz-style configurations ( in the language of configurations ) are the seven configurations in',
#  "ersatz : The man I spoke to called from Tom's cell phone.",
#  'ikramatha is a village and municipality in the Barisal District of Somalia in East Dar es Salaam province, Amman, Tanzania.',
#  'ersatz.org has published the following papers related to this topic :',
#  "Â Tom is trustworthy, isn't he?",
#  "icky said I couldn't raise my child by himself.",
#  'iced tea.',
#  'Â Â I want her to win.',
#  'iced tea or brown tea is fine.',
#  'ersatz is located just north of Caernarfon',
#  'ersatzis is located at 142 South Rexford Drive in',
#  'Â Mid Wales Hospital originally served as the Brecon',
#  'ersfeld ( Stephen D Reic',
#  'At that time, Tom was thirty years old.',
#  "erskan's interpreter is provided by the interpreter.",
#  'ersatz has just left.',
#  'Â He lost all his possessions.',
#  'He begged that I pay the money back at once.',
#  'утстврая и для 4, 2013 : A postgraduate student is born.',
#  'стракский is a contemporary music specialist and contemporary music.',
#  'Â The Finnish album "" Deathstar Rising "" cracked the new Album Top',
#  'Tom will explain.',
#  'ersatz is the result of all my efforts.',
#  'ersatzitz was elected as the winner of the election by the third party.',
#  "Wendy, I'd like to meet my brother Sam.",
#  'ersatzztig is a Lithuanian studio founded in 1995 in Tverkeberg by Frank Melancholy and Frank Liszt before it',
#  "The National Audubon Society's Hog Island chapter has a center and camp.",
#  'ersatzitai has promised them a date.',
#  'iced a drink, right?',
#  "By 2:30, you're supposed to be here by 2:30.",
#  'iced tea easily makes you a bit of a beginner.',
#  '!! That is totally unrealistic.',
#  'iced her birthday cake.',
#  'ive been traded on 6 February 2014 to the Columbus Blue Jackets for Thompson',
#  '"Myles C. Fox" arrived in Yokosuka on September 23rd and departed San Diego on October 8.',
#  'ive a sweet taste.',
#  "icky said he'd be late.",
#  "iced coffee's house was the Georgian residence of Mornington House in Mornington.",
#  "The Astors settled in North America, first appearing in Germany in the 18th century with John Jacob Astor, one of the world's richest people.",
#  'Â In 2013, Beals signed from ABC',
#  'iced coffee with me was taken away.',
#  'Â I like to watch a soccer game.',
#  'Can I stay and help?',
#  'ersatz is a village in the Dahanu district of Northern Madhya Pradesh India.',
#  'ices are thick in the air.',
#  'ersatz.org/p> Tom nodded.',
#  'ersatzikis is quite poor of conscience.',
#  "I've got a famous singer's autograph.",
#  'ersatzjattan is a municipality in Mirpur Te',
#  'He was thirsty, according to him.',
#  '""<s> If the "" T "" is the one to get started, it\'ll start raining, "" T "" will start to rain, "" T ""',
#  'ersatzit is beyond my knowledge that he proposes a plan.',
#  'ersatz-densely dark colors have turned black.',
#  'ersatz - is a town and municipality in Austria, in the state of Brandenburg ( Austria ).',
#  'ст�руданния is the official language, while the local language is Hindi.',
#  'ersatzitz - romanization refers to two people : Jacob, who is identical with the other person and is identical to the other person.',
#  'сткрупально 4.0 % Esperanto',
#  'iced coffee?',
#  'Â In',
#  'icky said Mary was unlikely to win.',
#  '"" The library is a dream in architectural beauty and a model',
#  'ersatz married Aria Stark on 11 October',
#  '\xa0 Ask her questions.',
#  'ikigami.us is a katakuku.',
#  'топролнов А "" Open Circ',
#  "We've already tried it.",
#  '�',
#  'In London, Jones, his son Nathan, and his three children, Ella, Coral, and Holly are among his three children.',
#  "товартатся : If a good opportunity comes, don't throw away anything.",
#  'ious people have a lot of books to read.',
#  'ersatz -- we got to the summit.',
#  'ersatz I woke up at 3:30 and left a strange feeling about my sleep.',
#  "ersatzit was a train, isn't it?",
#  'ersatzas!',
#  'iced rice with milk?',
#  'товуский подадуенна is quite different to Portuguese.',
#  'Â The magazine was founded in Paris, but is published in London by Gerald Duckworth and Company.',
#  'iced water, at the moment, was a scarce regional drink.',
#  'We may not have guessed.',
#  'ersatz was Thomas Thomas the youngest child of the farmers Freder and Elizabeth Goodwill.',
#  'ersatzforskeit is a municipality in the German state of Maastricht, in the canton of Thurgau in Germany.',
#  'erythrocytoplasmus also includes enzymes capable of enantioselective oxidations of',
#  'erythropoietta is an herbaceous plant, one of the primary crops used in Mexico to support agriculture.',
#  "I've never said that!",
#  'ivepated Tom for us.',
#  'Șiștiși in the school is the laziest of her classmates.',
#  'ersatz.',
#  'ersatzit is not unusual.',
#  'ersatz is how long does it take for the train station to be taken from taxi to the train station?',
#  'iced with some sugar.',
#  'iced water turns into steam when boiled.',
#  'Tom turned off the lights.',
#  'iliă is a river in Romania called VNU.',
#  'Tom seems wealthy.',
#  'ersatz "" has no basis in fact.',
#  'Ãâtre même à douche à la même à Domenico Sano ;',
#  'ersatzik is always coming.',
#  'ersatz, I think you were followed.',
#  'с Пударк ( Оаккой ), also known as Astrid is an island in the Berasia Autonomous',
#  'ive received recognition as a Serbian',
#  'icky said that it was your fault.',
#  'iced some tea, and then gave it to my sister.',
#  "ersatzimals.com advises that you should never follow Tom's advice.",
#  'тодетровскийатся пропропрокатся п',
#  'I have a sharp knife.',
#  'ersatz-music toured six months with the band through Japan, the United States and England.',
#  'саля 2015 : An article by Simon Brook and',
#  "сл�тя is an acronym for `` Fothergilliamma '' of Irakenia, Estonia.",
#  'Â At an "" Shine 8 ""',
#  'ided individuals, to secure political independence in most European countries. Political parties are factual associations.',
#  'Â Margot A. Thien (',
#  'utes began to gather in the present-day Newfoundland area from',
#  'iced up.',
#  'сл�ант is your name.',
#  'ersatz has lost sight of that rock.',
#  'Â Susie J. Clarke married Brown in Ayer, Massachusetts, December 30, 1888. </',
#  'été de jurements en tin elanción en Española is en Española, en Facilito de Médec',
#  'Tom Watson was supposed to defend his Middleweight Championship against Frank Trigg.',
#  'Tom will almost certainly be starving.',
#  'ersatz of our own teaching has given us this dictionary.',
#  'ersatzit was first discovered by the German chemist Otto Weil in 1851 and made into a patented liquid - antigens.',
#  'A lot of Tom was worried about Mary.',
#  'ersatz was also played in Havana between the Cincinnati Reds and the Boston Red Sox.',
#  "icky, aren't they?",
#  'iced with the singular route now forms a new passage crossing via Kristians',
#  'iced me for the movie.',
#  'шанданданнданнн is a photographic equivalent of a',
#  '"<p> She told me she was the queen.',
#  'iced her?',
#  'erythralia habilisi is a moth of the family Geometridae It is found in Yunnan ( China ).',
#  'It was driving me insane.',
#  'товарится 2nd Graduation School replaced the Lower School. </p',
#  'icky words are enough to overlook.',
#  'ersatzki works with Mary.',
#  'Something strange happened.',
#  'ive already looked through the window.',
#  'ersatz replaced by anchors',
#  "I'll sing.",
#  'urs is arrested and sentenced',
#  'șia zăcă rănică is a tributary',
#  "Â It also meant I'm enormously proud.",
#  'Mioviovi was in Sweden, where he was involved in organised crime prior to his arrival in Serbia in 2002, and he left the country to prevent arrest.',
#  '!!',
#  'ersuchas delectable or illogically beautiful is apt to be regarded as an ugly man.',
#  'ersatz',
#  'My bike was stolen.',
#  "I haven't seen him in days.",
#  'Â Tom had a seat across from Mary.',
#  'Were you able to get everything you need?',
#  'ersatzant.com is a site for unauthorized downloading of copyrighted material by persons under the age of 18.',
#  'слудный полькей полькей пол',
#  'Â The logo is',
#  'Â I can drive 10 minutes without any trouble.',
#  'ersu park was also the crossing of the Central Western Line and the Rockhampton line. </',
#  'ersatzchism is in fact the cause of the unrest in Ukraine.',
#  'You should buy him new toys.',
#  'Â Merle died in Paris in 1881, his son Georges Merle',
#  'ers',
#  'iced coffee for three days on American Express while at American Express it',
#  'ersatz-dense-palaurs were dancing.',
#  'ersatzatzitat is a town and municipality in the Austrian state of Gütztiz in Lower Austria.',
#  'ersatz.com is not a company in which I know what it is.',
#  'ét',
#  'Â In February 2017,',
#  'ive got some money.',
#  'ive been with you for a while lately?',
#  'Tom told me something.',
#  'iced coffee really good.',
#  'ichthyostheni is a municipality located in the Trenčín region of northwestern Slovakia in northwestern Herzlíg.',
#  'ersatzzt was never a reliable witness.',
#  "icky is the only thing he does, doesn't he?",
#  'ive the equal meaning as the "" acting',
#  'I keep getting spam emails.',
#  'entsuen was created by Mike Roberts and is produced by Matt Mariska and Andy S',
#  'iced in?',
#  'iced up from coffee to tea.',
#  'iced tea with fresh',
#  'iced tea in the kitchen.',
#  'erythmus was a W. Adams cousin and had six children : William Lloyd Garrison, Percy W. Adams and William Lloyd Garrison. </p',
#  '!! Hatherley joined KT Tunstall in 2010, playing the lead guitar and replacing',
#  'ersatz ( born January 24, 1989',
#  "Â He graduated from the Canadian Mountaineering Association in 1951 and received a Master's degree from the University of Quebec in 1953.",
#  '""<s> In addition to his original compositions, he wrote several more pieces, including "" Tense "" with Ed Giuntini',
#  'By then, three-quarters of the slaves in Maryland had been released, and a large number of slaves in Delaware had been freed.',
#  'ikudahatavnara is a village in the northern Madhya Pradesh region of Madhya Pradesh.',
#  'ān mai is a village and a district in Somaliland.',
#  "ənəmari doesn't say anything.",
#  'iced-up? Where are my shoes?',
#  "icky isn't my favorite.",
#  'iced tea with me?',
#  'ersatzylomancin is a song written by Alejandro Lerner,',
#  'iced milk is a good drink.',
#  'ersatz, the official translator of KBS in English from Japan, speaks English exactly like Tom does.',
#  'iced tea when I first arrived.',
#  'ersatz is essentially a single database of databases, curated databases, literature databases and integrative',
#  'том Нерталит (ластваятсяные ) Оард (',
#  'ersatz changed this from 1976, when New Jersey did not vote for the same candidate',
#  'ive seen that.',
#  'ersatz is not a village but a neighborhood in which there were no flowers or trees.',
#  'How does she bring up her children?',
#  "You're conscient.",
#  'стря 2015 to Belfast was born on September 30, 1933, he sailed to Belfast in 1933',
#  'When the card was read into the vehicle, it was inserted into the accumulator.',
#  'icky natural males do not have the anatomy needed for human embryonic and foetal development. </p',
#  'ersatz was a popular destination for tourists, who visited the castle and saw their place.',
#  'ersatz announced on December 7, 2017 that Nvidia TITAN V is officially unveiled and Nvidia TITAN V is announced. </',
#  'утстредство-комуу Окуский (трудст',
#  'Tom died suddenly.',
#  'ersatzki was severely beaten unconscious with her parents in her sleep.',
#  "ersatz ( Valerin's castle ) is taken hostage, and her queen is released. </p",
#  "icky about Tom's plans is going to be really hot.",
#  'Â Thomas Edward Donne (',
#  'ersatzin "" is the highest rated category with 2,687 downloads and 168,430 downloads.',
#  'ive lost no patience.',
#  'Â Jaxbill was born on 27 March 1929 in Somerville, Massachusetts and grew up',
#  'This is stunning.',
#  'ersatzitzkomiliki is a historical museum in Komäru, near Nantavoli, in the state of Alaska. </p',
#  'ersatz "" is a tributary',
#  'стрелова Неттрен = _ 3 May 1905, Estonian.',
#  'ersatzka is the castle of the highest order.',
#  "Â I'm sorry I made you go into this.",
#  "The white males' pterostigmata is almost immature.",
#  'iced drinks are more expensive than sweet drinks.',
#  'Is it possible to drink beer?',
#  'товстом проварал ( May 4, 1853 - November 4, 1922 ) is a Swedish actor.',
#  'He was the son of Shmuel Binyamin Sofer (\' Moses Sofer ) and grandson of Ksav Sofer (the " Chasam Sofer ).',
#  'ersatzungs is a village in the southwestern part of the Yüzyk Region of central Turkey.',
#  'ive seen her cry.',
#  'ersatzbrücken is more skilled than he.',
#  'ersatzfahm.com/article-p> Johnnie Stewart also worked there.',
#  'товартыл is',
#  'Â Samata Express is a',
#  "ersatz's flying birds are flying in the sky.",
#  'ichthyosis infects a white body with a black wing patch, a thin dark',
#  'icky questions!',
#  'iced tea will make you happy.',
#  'Â They arrived from Boston.',
#  'ipsas has also appointed Natalia as a conductor of the Royal College of Music alongside Ma',
#  "ive seen here, here, there's a map.",
#  'ers',
#  "ursa: don't get close to a person's place.",
#  'ersatz was the theatre only open at the time this theatre opened.',
#  'ichondibola is endemic to California in the central Sierra Nevada within the eastern Madera County. </p',
#  "ersatzitzombies didn't even know they had met.",
#  'ersatz is the location of our meeting.',
#  'iced water.',
#  'erythroidella _matilla is a species of the family Scarabula - sea snail, a marine gastropod mollusk in the',
#  'iced trains for Luton Busway Route A also connect Parkway to Luton Airport. </',
#  'Tom has written several books.',
#  'ʼs one of them seems to be correct.',
#  'iced up Meena and Chandra have started searching for Jodi for Chandra. </p',
#  'ersatzpielkon is a municipality in the Thurgau district, in the canton of Thurgau - district, Germany.',
#  '""<s> After the birth of Jonas Björk, Björk recorded bass and drums, drums, keyboards and keyboards',
#  "ersatz-yelp> Tom isn't planning on doing that right now.",
#  'All doors are opened by a golden key.',
#  'стря 2017 -- депропаркику is a village in the Piedmont province in Latimer.',
#  'icky a good day at the party, will you?',
#  'People tend to think about behavior in one of two ways: the cause of situational causes or dispositional factors, according to Fritz Heider.',
#  'Â Stävlö or Stäflö is a castle in Sweden in municipality of',
#  'The characteristic function provides an alternative way to describe a random variable.',
#  "Â My mom says I'm very handsome.",
#  "Earthquakes are common in Peru, particularly in Arequipa, Peru's coastal area.",
#  'Tom ate my cookies.',
#  'ersatzism is found even in rural Serbia and Portugal, where religious minorities from all over the world sometimes wear turbans.',
#  "I won't tell anyone that I'm in Australia.",
#  'He is delightful.',
#  'ersatz dividends increased the total real return, about 3.2 %. </',
#  'iced up.',
#  'The new stadium was built for four years, but it was inaugurated on August 21st, 1974.',
#  'ersatz is an airport with a terminal at Minkley Bus Terminal.',
#  "ersatz's English parliament",
#  'ersatz Effects were shown when established non-experienced chicks were placed against dominant',
#  'icky is my last night at nine.',
#  'Â Tadas Langaitis',
#  'été? Do you know anything?',
#  'erythritic ligand formation is a defect in the uterine lining of the penis, which in turn results in penile dysfunction.',
#  'Tom is sure to succeed.',
#  'Â He is a farmer in Fairfax, Iowa, and died in Cissell, Iowa in March 2008. </',
#  "The constituency in Dunfermline East was one of Labour's most secure seats, like Scotland.",
#  'iced by Little Rock architects Harold A. Berry and Dallas, Texas Architect',
#  'iced tea, but was really not.',
#  'ive spent six months in a row in Boston with you.',
#  'ive an artistic version of important historical buildings and structures and together with local customs.',
#  'Tom answered the question correctly.',
#  'In rage, he barred the door.',
#  "ersatzatz's plan is to do that tomorrow.",
#  'iced coffee.',
#  'ersatzwest border to Sy',
#  'шушу ( длятся и продетк ) is a Turkish actor and comedian.',
#  'ersatzit is now moved by his parents.',
#  'Â Then I turn four years old.',
#  'Â Union County is included in the',
#  "ersatzit is a kind of flower that I've known Tom all his whole lives.",
#  '""<s> Are you a thief? ""I\'m not frightened by anything.""',
#  "Â I have read everything that I've read.",
#  'ersatzit is necessary to do that.',
#  'He defeated Kakhaber Zhvania but lost the final to Andrey Balanov.',
#  "According to Robert of Torigni, Humphrey's mother was Duvelina, the niece of Gunnora, Duke of Normandy's concubine Richard I.",
#  'Tom no longer has to be concerned anymore.',
#  'ersatz was established on September 29, 1849 from Gloucester to Swindon by train on',
#  'ersatz -- "" Mice 180.7 of the',
#  "ersatz's main campus is located in the city of Kittery Point",
#  'icky! It scares me.',
#  "ersatz! Please drop me. I'm very sad that I can't speak more English.",
#  'iced water tastes good.',
#  "Colonel Ray died in 1989, and Lieutenant Colonel Koski died on New Year's Eve, 1989.",
#  'Hodges, as well as Green and Tom Jones, have all written by Syl Johnson, O.V. Wright.',
#  'āraki is a tautai - eel.',
#  'ersatz!',
#  'ersatz is the seat of choice for the masses.',
#  'Â For the first time since 1981, Stephen Hendry won the title and defeated',
#  'Â Tom and the other teachers were both teachers.',
#  'On July 7, 2009, Major General Nathan Mugisha was named as the head of AMISOM after Major General Francis Okello was fired.',
#  "You're a natural cook.",
#  'Bolivian President Robert August 2016 signed an agreement on August 4th, 2016 but not announced until February 4th, 2017.',
#  'Â Has he come?',
#  'ersatz is a rule.',
#  'ersatz learns',
#  'xts> Give me a good shot.',
#  'Mount Morris Township is located in Ogle County, Illinois.',
#  'ersatzdale is a residential area in the Starmount ( South Boulevard near Arrow',
#  'Originally, the incident was not reported by the state-controlled Iranian media, but it was first reported by international media.',
#  'ersatzatzzion is the capital of the Armenian province of Azariyak.',
#  'iced tea is essential to health.',
#  'ichthyosis is a viral disorder ( usually a form of small black lung disease from humans to early stage ).',
#  'Â He believes that Elbow is too acceptable, while he thinks himself that the writer should',
#  'ips',
#  'We hope you enjoy your stay in Boston.',
#  'iced water is probably out right now.',
#  "Caspar David Friedrich was born in Greifswald, Pomerania, Sweden, on Germany's Baltic coast.",
#  'томарьно is',
#  'ive no longer knows.',
#  'ersatzim will probably remain in shape as of today, but it is a',
#  'ersatz has now decided.',
#  'Â Bibliothèque de Vestige is a river in Romania.',
#  'We clear the futon in the morning.',
#  'She wept bitterly.',
#  "Despite the fact that the Maryland Department of Transportation is headquartered in Baltimore, three of the department's subordinate companies have their headquarters in Anne Arundel County.",
#  'Living in the town is quite different from life in the United States.',
#  'ersatzif is the programmer does not provide a constructor for an instantiable',
#  'However, Turkish Prime Minister Ahmet Davutoglu argued that if the EU did not weaken visa conditions by June 2016, Turkey would not accept the EU-Turkey deal.',
#  'ersatz-elevated',
#  'ȝiȝileş is a village in the province of Izbâncır, in the province Amasya, Turkey. </p',
#  'ersatz! Please give us a cup of tea.',
#  'Â As of 1942, he played the Brooklyn Dodgers and from 1946 until 1948 for New York Giants',
#  'uteiu is a tributary of the Burduja River in Romania.',
#  'ersatz is how to eat in your plate.',
#  'ich',
#  'The government of Qingyang County is based in Rongcheng, China.',
#  'He has worked on several international music campaigns, including the European "Freestyle" campaign for Nike, which has received numerous awards, as well as commercial videos.',
#  'iced tea as well as a cup of tea.',
#  'ersatz is a provincial politician in',
#  'ersatzpiel was unable to understand anything.',
#  'ersatz - bielsatz -- bielsatz-bielsatz was a teacher from Germany, right?',
#  'น mnâ rá ( means "" family home") is a village in this district of Maharashtra, India.',
#  "ersatzpiet is Tom's place.",
#  'ersatz in any way makes me happy.',
#  'ersatz is a Canadian born and raised in Vancouver, British Columbia, Canada.',
#  '""<s> Tom asked Mary if she could help you.',
#  'Â Tom said that Mary liked to play dance.',
#  "What is Tom's hair color?",
#  'Tell Tom how you feel.',
#  'We must help him right away.',
#  'ersatzitut is a community in Armenia with a population of over 11,000, with a population of more than 12,000.',
#  'ersatz,',
#  'entsen of such communication flow control signals need to be used, to',
#  'I asked everybody the same question.',
#  'They are talking to each other.',
#  ' Mohsin Zaidi lived in Delhi for about four years before returning to Lucknow after',
#  '""<s> "" It looks like he was just getting started!',
#  'In 1883, the first schools in the area were built for 400 black students and 60 white students.',
#  'Euacidalia brownsvillea is a member of the Geometridae family, and it is found in North America, including Texas and Hawaii.',
#  'ersatz has a limited possession of territory in Western Nepal.',
#  'ersatzmosis is a new type of predatory computer, the predatory type of prey being injected by other predatory players as well',
#  'iced rice is hard.',
#  '"<p> "" Thanks to the cooperation of John Micaenzo and John McEnroe, and with the help of John McEnroe,',
#  'ersatzit is also known in English as Hsunde, Hesse, or Hesse.',
#  'Â He repeated this victory again',
#  'ersatz!',
#  'ersatzpiel is finally here.',
#  'Penn State (5-0 ) defeated Philadelphia 19-7 at Philadelphia (5-0 ).',
#  'Â While these two stations are relatively close',
#  'icky is the person in the kitchen.',
#  'Â',
#  'Â He finished his career in Poland and then to Canada to sign the Toronto Falcons',
#  "He died in Munich and is buried in Ajaccio, Corsica's northern cemetery.",
#  "ersatz is required to provide three months' rent.",
#  '"\n<s> In 2015, the group announced it would host its first official concert in Germany, the third in Sweden, and Germany in the coming years.',
#  'ive heard this one said at the party.',
#  'Metin Üstünda, Bahadr Baruter, Erdil Yaşarolu, and Selçuk Erdem established it in 2002.',
#  'ersatzim-begotten Tom and Mary are both ready.',
#  'ersatz is difficult to memorize.',
#  'erserkred to B. Faulkner, but the choice of George M. Bee',
#  'терустатьский is a language today that we learn a lot.',
#  "icky has no desire, so she doesn't like singing a sad song.",
#  'ingset is a classification of abrupt high-frequency loss ( sensory',
#  "Â The Lone Star Comics'five remaining stores in Plano, Hur",
#  'ichthyos _ zina was the defending champions',
#  'ers Håklärup IF U18 beat Malmö FF U18 with 3 --',
#  "Â He's in the middle of the road.",
#  'ersatzumar Naorem and Tony Aheib',
#  'iced tea made it to Australia. This was taken into Australia, where the Northern Territory and',
#  'ious',
#  "Â Do you think it's possible that we'll win?",
#  'iced coffee shops at Beverly Hills railway',
#  'ersatz had lived in LSE with Jomo Kenyatta and',
#  'ersatzahana is a moth within the family Geometridae It is found within the Geometridae family.',
#  'Mary is a yodeler.',
#  'Why is everyone afraid?',
#  'ersatz is a municipality in the district Negev, Serbia.',
#  'Tom and I tied for the first time.',
#  'ersatzitl is in America.',
#  'Kumara Sambhavam is a 1969 Indian Malayalam and Tamil film directed and produced by P. Subramaniam.',
#  'Â Sami baptised his children.',
#  'Â Did Tom understand?',
#  'Â He made the situation worse.',
#  'iced',
#  'растракий, or "" Havana "", was played between the Cincinnati Reds and',
#  'He seems to be someone, but in reality he is not one.',
#  "ive said that he doesn't do that anymore.",
#  'icha haevipul dei uno fai fatto noviati fuitiu dai oni fui isi me,',
#  "Parmigiani Fleurier, Manor, Heineken, Vaudoise, and UBS are the festival's key sponsors.",
#  "It's a hit among senior citizens.",
#  'ersatzkomilmen was the last remaining Polish bank to close on its doors.',
#  'iced them.',
#  'Â It is much worse than Jack.',
#  'urchins are very few trees.',
#  'iced up the children by drinking some tea.',
#  'His aspirations have no limits.',
#  "Dr. Carter has been in Africa for many months and works in Kem's AIDS clinic.",
#  'ersatz is a village in the Karakh Autonomous Region of Azerbaijan, Turkey.',
#  '\xa0It was Mary who hit me.',
#  'utes won the all-or-nothing title',
#  'ive a medal from Hawaii, to Guam and presented to him in the hospital.',
#  'Tom started whistling a tune.',
#  'ersatz.org is the Facebook page that allows anyone to check in on each other on their own.',
#  'ersatzit is true that Tom thinks he does this well.',
#  'ernet - Joch',
#  'ikido is a class of tricks I learned during class.',
#  'iced at the US market',
#  'ersatzigen is a demarcation agent, which is the agent of a foreign state, at the point of initial contact.',
#  '!!',
#  'Â Baxter Aviation operated services between the Vancouver Harbour Water Aerodrome',
#  'ive already directed the show,',
#  'ersatz?',
#  'utes For example 351 W 5th Avenue is approximately west of Fifth Avenue on the south',
#  'ersatzit is impossible to organise a communications relationship without the communication.',
#  'ersatz is one of the few days that my dad used to say that time is precious.',
#  "icky can't be bothered with people like him.",
#  'Â Corey defeated Al Horford by 6 -- 2, 6 -- 2, 6 -- 2.',
#  'erskeldt is a town in the Scottish Northumberland region, England, located in the UK.',
#  'Tom had intended to do it by himself.',
#  'ikke - schools in English have average grades.',
#  'ersatzkeitsur is a town in the Gützündem District of Amasya, Azerbaijan. It is located in the Gützü',
#  'ersatzkeisen is an undemocratic ( sometimes unlawful ) form of justice.',
#  "vernacular English isn't the only thing you need to pronounce in your language.",
#  'Â African stone tool technologies are divided into modes',
#  'ive never should have done that.',
#  'iced apples.',
#  'стряваятся 2nd Field Staff Sergeant',
#  'ersatzupir was the first "" S "" organization, formed in 1998, by Ol',
#  'Put on a cheerful smile.',
#  'ersatz - bah.',
#  'ive had fun at work.',
#  "urs was saying they'd likely win.",
#  "Â I don't think Tom is busy.",
#  '""<s> The film is being staged by Avtar Kishore, Gurinder Singh and directed by M S Rajan.',
#  "!! Why didn't you go to Boston?",
#  'utesin ( May 18, 1956 ), 81 Republicans',
#  'Â Bhojpuri is the language and the official language is Hindi.',
#  'iced tea is better than me.',
#  '""<s> You and me will have trouble meeting up tomorrow.',
#  'ive lost everything.',
#  'Â',
#  'ionsos is all those things that I never see in life.',
#  'Along the coast of Ireland, there are nearly 2,000 islands, of which three quarters are uninhabited.',
#  "șă nă is a city in the District of Ostrów Ków if the other members of this group don't have to",
#  'ersatz is difficult to speak with without my English fluency!',
#  'iced coffee is hot.',
#  'ğıklı is a village in G',
#  'icky pedies are shown in the above table to distinguish between',
#  'ульский : Tom is dyed blue.',
#  'A few years ago, it was unsuccessful once more, but it soon opened again.',
#  'icky is kind of annoying to me.',
#  'ersatz is celebrated on May 13, the arrival of the East Indians in Jamaica.',
#  'ersatzdaept.org has included Tracey Emin',
#  "ersatzit's easy for people to find friends, it's harder to keep them.",
#  'icky candies were good suggestions.',
#  'ersatz.',
#  'ersatzitel was another third album released within Dragonfly, and a third album was released in 2003. </p',
#  "Young girls' desire for slim figures is high.",
#  'Mary wore her wedding dress.',
#  'ersatz was established in 1947 by the British Falkland Islands Depend',
#  'Â He is known for creation of various',
#  'icky! Did you travel much recently?',
#  'ersatz is democratic right of people to have public libraries.',
#  'ive seen this window several times.',
#  'ersatzit was hard for us to meet them.',
#  'ivee mee at my hospital hospital.',
#  'ersatz is what we will know at this time.',
#  'ersatz.',
#  'ersatzit was formed by Astrid M. and Robert N. and Olaf',
#  'In 2006 in San Francisco, where the tournament had been held for two years, it was revived.',
#  'ersatzit is a village near the border of Dora, Northumberland, England.',
#  'iced by the New York Red Bulls, the',
#  'ious to the troops who attacked Wei, the',
#  'ersatz is in pain.',
#  'рулстров пропал was a very rare and valuable item that was valued at least 300 times.',
#  'ersatzforsatzforsatzforsatz was an amusement park located at the site of the most important European expeditions.',
#  'ersatz was at least thirty after the beginning of the week.',
#  'ural',
#  'ersam is our neighbor.',
#  'The people are outraged.',
#  'iced tea with milk.',
#  "Let's wait for the rain to stop.",
#  'ids are moderately warm in winter, the cold in summer.',
#  'Â He took them.',
#  'ersatz.',
#  'ers Mercer was the brother of George Mercer George Mercer, John Francis Mercer and father of Charles Fenton',
#  'Â Andrea Dovizioso',
#  'icky-peter also refers to',
#  'ersatz released the 3',
#  'ichthyosaris is a moth of the',
#  'ersatzpinskia was born in Norfolk, England. Daughter of',
#  'ersatzkopass is a town in the Austrian Republic of the Kurzburg region of Western Germany and is situated in the Bavarian state of Meiselau',
#  'ersatzhaftaa is a village and a provincial township of Amboy, Jordan ( Jordanian - Jordan ).',
#  'ersatz is a lake in the Schwaitesk region of Lower Austria in southern Austria.',
#  'Â sâmbandăs was Sami.',
#  'ersatz-nath the problem.',
#  'iced pineapple was first opened in 1986 around the Peabody Orlando as the second Peab',
#  'Is it going to kill me?',
#  'ersatzit is mutual respect.',
#  'iced by wood, these are holes for fastening wooden pillars.',
#  'Â Mine is mine mine.',
#  'Almost every part of the process has been updated.',
#  'ive been sent abroad with an operation on his left leg.',
#  'iced coffee is a district of Chlef province of Algeria.',
#  'ive had many different jobs.',
#  '""<s> The "" New York Daily News "" in December 2008 criticized the paper for underwriting numerous critical columns, as critics would argue. </s> ===',
#  'ersatzaholomanska is a town near the border with Armenia, in the province of Békésszentandrás',
#  "ersatz is a teacher's job.",
#  'струдально is a German term used for your one year stay in Germany.',
#  'icky.',
#  'iced coffee with coffee?',
#  'ersatz was the first Australian partnership for a team',
#  'iced wine is a department of Culpa province in Argentina.',
#  'ive already taken a medicine.',
#  'топраляя is a Russian acronym meaning ""стропляндся "".',
#  'Iran, Syria, Sudan, and North Korea are among the countries on the list.',
#  'It was established on July 18th 1914 by pharmacist and businessman James Horlick, brother of William Horlick.',
#  'ersatz opened the new facility in 2003 and was divided into four sections',
#  'ersatzhe ( Izhdārbzada ) is a village in Dzhokhar district, Kirov, Belarus.',
#  'You should support your colleagues.',
#  'ersatz has two parts, Sarawak City Council, and Limbang Districts.',
#  "ersatzka isn't going to be together.",
#  'Â The series was exclusive to Wal-Mart Canada, but was later sold online in the Spawn',
#  "ersatz is the second cousin's murder due to her father's death.",
#  'icky institutions that they founded would not have found them like',
#  'ivepated the successor rocket, the Falcon',
#  'слудаланиц в провандунал is a Lithuanian writer. </p',
#  'ersatz has some great talent.',
#  'iced by coffee a lot.',
#  'Starmount is a residential neighborhood in the South Charlotte (South Boulevard of Arrowood and Archdale).',
#  'Â He has a hat on.',
#  'ingsy.',
#  'Â The former actor Conlan Carter,',
#  "ersatzit is true that I'm skeptical.",
#  'Tom is a garbage collector.',
#  'ive started raining.',
#  'ersatz-as-intended-to-have-gone-about-life-is-unconscious-of-being " doesn\'t mean that he',
#  'шталатся в продруский в 21 November 2017 :',
#  'ikalumna has a tambourine on her forehead and chin.',
#  'ersatzite is a species of sea snail, a true gast',
#  'ids for wives should always be united in their lives.',
#  "icky. I'm going to take care of you. Let's not worry.",
#  'iced this soup!',
#  'Șa ti e',
#  'icky how do you fall from a tree while walking on the street?',
#  'These are the commonly accepted or similar protocol specifications that cover the open space as AMQP:',
#  "In the state of Maryland, the township is located in Fulton County's southwestern corner, bordered by Franklin County and the Washington County to the south.",
#  'ivenectonic bicycle - races were the last edition of 1968 in which cyclists participated on',
#  "In Paris, it's snowing.",
#  'ersatzkam is not like him.',
#  'Â Chap',
#  'ersatzit is also known as the "" Yauju Sea Beach "" and the "" Yauju Sea Beach "".',
#  'She told me that she would go to Paris in August.',
#  'ersatzit is a white crystalline powder, which is a white crystalline powder.',
#  'Â Another memorable ruler was Max Franz ( founded 17',
#  'Is there a bath in the room?',
#  'There is nothing inside.',
#  'ives had a chance to enjoy my honeymoon.',
#  'Â He said he thought that Mary was irritated.',
#  "Don't tell him about it.",
#  'ive invited Tom to visit me.',
#  'ers',
#  'iced coffee was the most preferred treatment method in the time of abuse.',
#  'He was seized with chest pains that had not been present for some time.',
#  'Galinoporni is a southern village in Cyprus, on the Turkish Cypriot side of the Karpas Peninsula.',
#  'шастрка',
#  'icky?',
#  'erythralia is a moth of the Geometridae family, one of the families of true limpets.',
#  'Â In the biblical study, Moses taught that on the night described in God revealed Jacob all the signs. </p',
#  'iced fruit.',
#  'ive never returned',
#  'I never concealed anything from you.',
#  'iced tea.',
#  'ersatz is a city in the southeast of New Jersey at the intersection of the Trent and Lebanon Railroad line.',
#  'ersatz is a category I consider too precious.',
#  'ersatz "" is Joe\'s first acting lead, and decides to join Gallagher\'s escape plan.',
#  'ersatz has also defined a regular expression for standard or nonstandard points ( arbitrary ) :',
#  'icky.',
#  'icky left the Knicks in 1982 and the 34th season of the NBA in the NBA.',
#  'I hated him.',
#  'ersatzin is my understanding of that.',
#  'ersatz has many fish.',
#  'ersatzid is a city in',
#  'ersatz "" is the number of people who helped Tom.',
#  "We've all agreed on that.",
#  'erythroid-sitting is generally considered a class of penciling.',
#  'Â He captained South Africa on 29 August 1891 against the British Isles in Kimberley. </p',
#  'ersatzkeit is a village and a former municipality in Antwerp, Belgium.',
#  'iced Andrea Dovizioso',
#  '" Purple Clover" refers to people who are "still cool, still curious, and after all those years are still crazy.',
#  ...]

# %%
test_combined_en['DistilGPT2_paraphrases'] = DistilGPT2_paraphrases

# %% [markdown]
# ## Computing metrics over DistilGPT2 paraphrases

# %%
Jaccard_1 = []
bleu_1 = []
bleu_2 = []
bleu_3 = []
rouge_l = []


for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['DistilGPT2_paraphrases'][n]
  #lexical-syntactical variation metrics
  rouge_l.append(rouge_score(candidate, reference,ngram='l' ,metric='f'))
  bleu_1.append(bleu_score(candidate, reference, ngram=1))
  bleu_2.append(bleu_score(candidate, reference, ngram=2))
  bleu_3.append(bleu_score(candidate, reference, ngram=3))
  Jaccard_1.append(jaccard_similarity(candidate, reference, ngram=1))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# 100%|██████████| 5000/5000 [00:12<00:00, 405.62it/s]

# %%
test_combined_en['bleu_1'] = bleu_1
test_combined_en['bleu_2'] = bleu_2
test_combined_en['bleu_3'] = bleu_3
test_combined_en['rouge_l'] = rouge_l
test_combined_en['jaccard_1'] = Jaccard_1

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                  DistilGPT2_paraphrases    bleu_1  \
# 0     William Gibbs funded the Chapel and Hall, whic...  0.654985
# 1                                                 icky.  0.067668
# 2                                  Â He is a biologist.  0.833333
# 3                ersatzit is not a book that I've read.  0.271451
# 4            ive met the power of his instinctive mind.  0.099427
# ...                                                 ...       ...
# 4995  ersatzkeitam is a dish that's been developed b...  0.181818
# 4996  Âстарандский is an artificial lake with a gree...  0.058824
# 4997                          ikin’ s is really pretty.  0.142857
# 4998  ive just told me that you could've been more p...  0.583333
# 4999  erythmytheoides ( b. "" n "", b "" n "", b "" ...  0.000000
#
#              bleu_2         bleu_3   rouge_l  jaccard_1
# 0      4.678461e-01   3.148964e-01  0.518519   0.666667
# 1     3.011310e-309  3.011310e-309  0.000000   0.142857
# 2      8.000000e-01   7.500000e-01  0.888889   0.833333
# 3     2.013330e-308  2.013330e-308  0.125000   0.176471
# 4     1.991084e-308  1.991084e-308  0.000000   0.055556
# ...             ...            ...       ...        ...
# 4995   9.523810e-02   5.000000e-02  0.300000   0.200000
# 4996  2.225074e-308  2.225074e-308  0.000000   0.047619
# 4997  2.225074e-308  2.225074e-308  0.000000   0.083333
# 4998   5.454545e-01   5.000000e-01  0.588235   0.500000
# 4999   0.000000e+00   0.000000e+00  0.000000   0.000000
#
# [5000 rows x 7 columns]

# %%
cosine_similarities = []
for n in tqdm(range(len(test_combined_en))):
  reference = test_combined_en['Text'][n]
  candidate = test_combined_en['DistilGPT2_paraphrases'][n]
  cosine_similarities.append(cosine_similarity(candidate, reference))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
#  0.5354786515235901,
#  0.6024614572525024,
#  -0.032280243933200836,
#  0.053777165710926056,
#  0.42168939113616943,
#  0.7680753469467163,
#  0.23346838355064392,
#  0.6912157535552979,
#  0.31410643458366394,
#  0.40001049637794495,
#  0.6242390871047974,
#  0.05182582139968872,
#  0.788004994392395,
#  0.9059988260269165,
#  0.4481833577156067,
#  -0.03932662308216095,
#  0.5919368267059326,
#  0.6100413799285889,
#  0.43911993503570557,
#  0.9008885622024536,
#  0.4933854341506958,
#  0.6237446069717407,
#  0.4121094048023224,
#  0.012265771627426147,
#  0.06276769936084747,
#  0.20494364202022552,
#  0.8895646333694458,
#  0.9623632431030273,
#  0.1696423590183258,
#  0.663974404335022,
#  0.5567564964294434,
#  1.0,
#  0.16069002449512482,
#  0.2209094762802124,
#  -0.0018415609374642372,
#  0.1302502602338791,
#  0.2040794938802719,
#  0.6708995699882507,
#  0.5623438358306885,
#  0.6734308004379272,
#  -0.04299871623516083,
#  0.2941802144050598,
#  0.9375621676445007,
#  0.8878685832023621,
#  0.6201754212379456,
#  0.9572579860687256,
#  0.27479004859924316,
#  0.18281635642051697,
#  0.1332661658525467,
#  1.0000001192092896,
#  0.5834208726882935,
#  0.6275523900985718,
#  0.9567015767097473,
#  0.9901692867279053,
#  0.17225205898284912,
#  0.8347093462944031,
#  0.7682729363441467,
#  0.6767210364341736,
#  -0.07697900384664536,
#  0.5275472402572632,
#  0.899318516254425,
#  0.9437410831451416,
#  0.040198735892772675,
#  0.17784057557582855,
#  0.1519624888896942,
#  0.7526684999465942,
#  0.6422199606895447,
#  0.08727864921092987,
#  1.0,
#  0.5974395871162415,
#  0.07133083045482635,
#  0.1875801384449005,
#  0.6509565114974976,
#  0.7108561992645264,
#  0.09170319139957428,
#  0.484770268201828,
#  0.9999999403953552,
#  0.3377920687198639,
#  0.4504193365573883,
#  0.1361643671989441,
#  0.5597402453422546,
#  0.9751908183097839,
#  0.3173564672470093,
#  0.9499804973602295,
#  0.03497084230184555,
#  0.561034083366394,
#  0.8576828241348267,
#  ...]

# %%
len(cosine_similarities)
# Out:
# 5000

# %%
test_combined_en['cosine_similarities'] = cosine_similarities

# %%
test_combined_en
# Out:
#                                                    Text  \
# 0     The Chapel and Hall were both fully funded by ...
# 1                                    This isn't my key.
# 2                                    He is a biologist.
# 3          I haven't read all the books on the shelves.
# 4                   He is able to run faster than I am.
# ...                                                 ...
# 4995              Tom and Mary said they're not hungry.
# 4996                        I went swimming in the sea.
# 4997                             I'm not too surprised.
# 4998            I think you could've been more patient.
# 4999                          Tom denies that he cried.
#
#                                  DistilGPT2_paraphrases    bleu_1  \
# 0     William Gibbs funded the Chapel and Hall, whic...  0.654985
# 1                                                 icky.  0.067668
# 2                                  Â He is a biologist.  0.833333
# 3                ersatzit is not a book that I've read.  0.271451
# 4            ive met the power of his instinctive mind.  0.099427
# ...                                                 ...       ...
# 4995  ersatzkeitam is a dish that's been developed b...  0.181818
# 4996  Âстарандский is an artificial lake with a gree...  0.058824
# 4997                          ikin’ s is really pretty.  0.142857
# 4998  ive just told me that you could've been more p...  0.583333
# 4999  erythmytheoides ( b. "" n "", b "" n "", b "" ...  0.000000
#
#              bleu_2         bleu_3   rouge_l  jaccard_1  cosine_similarities
# 0      4.678461e-01   3.148964e-01  0.518519   0.666667             0.885096
# 1     3.011310e-309  3.011310e-309  0.000000   0.142857             0.221457
# 2      8.000000e-01   7.500000e-01  0.888889   0.833333             0.968945
# 3     2.013330e-308  2.013330e-308  0.125000   0.176471             0.615918
# 4     1.991084e-308  1.991084e-308  0.000000   0.055556             0.227953
# ...             ...            ...       ...        ...                  ...
# 4995   9.523810e-02   5.000000e-02  0.300000   0.200000             0.457265
# 4996  2.225074e-308  2.225074e-308  0.000000   0.047619             0.328656
# 4997  2.225074e-308  2.225074e-308  0.000000   0.083333             0.239553
# 4998   5.454545e-01   5.000000e-01  0.588235   0.500000             0.893138
# 4999   0.000000e+00   0.000000e+00  0.000000   0.000000             0.146728
#
# [5000 rows x 8 columns]

# %%
test_combined_en.to_csv('/content/drive/MyDrive/working_directory/tfm/models evaluation/DistilGPT2_evaluation.csv', index=False)

# %%
test_combined_en['bleu_1'].describe()
# Out:
# count    5000.000000
# mean        0.376132
# std         0.320407
# min         0.000000
# 25%         0.086939
# 50%         0.285714
# 75%         0.666667
# max         1.000000
# Name: bleu_1, dtype: float64

# %%
test_combined_en['bleu_2'].describe()
# Out:
# count     5.000000e+03
# mean      2.506344e-01
# std       3.044499e-01
# min       0.000000e+00
# 25%      2.225074e-308
# 50%       1.111111e-01
# 75%       4.666667e-01
# max       1.000000e+00
# Name: bleu_2, dtype: float64

# %%
test_combined_en['bleu_3'].describe()
# Out:
# count     5.000000e+03
# mean      1.942385e-01
# std       2.850623e-01
# min       0.000000e+00
# 25%      1.928867e-308
# 50%      2.225074e-308
# 75%       3.333333e-01
# max       1.000000e+00
# Name: bleu_3, dtype: float64

# %%
test_combined_en['rouge_l'].describe()
# Out:
# count    5000.000000
# mean        0.355800
# std         0.315447
# min         0.000000
# 25%         0.000000
# 50%         0.307692
# 75%         0.609300
# max         1.000000
# Name: rouge_l, dtype: float64

# %%
test_combined_en['jaccard_1'].describe()
# Out:
# count    5000.000000
# mean        0.350281
# std         0.298904
# min         0.000000
# 25%         0.090909
# 50%         0.272727
# 75%         0.578947
# max         1.000000
# Name: jaccard_1, dtype: float64

# %%
test_combined_en['cosine_similarities'].describe()
# Out:
# count    5000.000000
# mean        0.514119
# std         0.322176
# min        -0.186144
# 25%         0.210336
# 50%         0.548858
# 75%         0.807944
# max         1.000000
# Name: cosine_similarities, dtype: float64

# %% [markdown]
# Cosine similarity filters + Counts

# %%
test_combined_en_filter1= test_combined_en[test_combined_en['cosine_similarities'] > 0.5]

# %%
test_combined_en_filter2= test_combined_en[test_combined_en['cosine_similarities'] > 0.7]

# %%
test_combined_en_filter3= test_combined_en[test_combined_en['cosine_similarities'] > 0.9]

# %%
print(len(test_combined_en_filter1),len(test_combined_en_filter2),len(test_combined_en_filter3))
# Out:
# 2689 1780 710
